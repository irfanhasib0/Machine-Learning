# %%
import numpy as np
import gym
from gym import wrappers
import tensorflow as tf
import json, sys, os
from os import path
import random
from collections import deque


env_to_use = 'Pendulum-v0'

# hyperparameters

h1_actor = 8
h2_actor = 8
h3_actor = 8
h1_critic = 8
h2_critic = 8
h3_critic = 8
gamma = 0.99
lr_actor = 1e-3
lr_critic = 1e-3
lr_decay = 1
l2_reg_actor = 1e-6
l2_reg_critic = 1e-6
dropout_actor = 0
dropout_critic = 0
num_episodes = 150
max_steps_ep = 10000
tau = 1e-2
train_every = 1
replay_memory_capacity = int(1e5)
minibatch_size = 1024
initial_noise_scale = 0.1
noise_decay = 0.99
exploration_mu = 0.0
exploration_theta = 0.15
exploration_sigma = 0.2

# game parameters
env = gym.make(env_to_use)
state_dim = np.prod(np.array(env.observation_space.shape))
action_dim = np.prod(np.array(env.action_space.shape))

# set seeds to 0
env.seed(0)
np.random.seed(0)
# Out:
# /home/irfan_hasib/.local/lib/python3.6/site-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)

# %%
replay_memory = deque(maxlen=replay_memory_capacity)

def add_to_memory(experience):
    replay_memory.append(experience)

def sample_from_memory(minibatch_size):
    return random.sample(replay_memory, minibatch_size)

# %%
import tensorflow as tf
class ANN():
    tf.reset_default_graph()
    state_ph  =  tf.placeholder(dtype=tf.float32, shape=[None,state_dim])
    action_ph = tf.placeholder(dtype=tf.float32, shape=[None,action_dim])
    reward_ph = tf.placeholder(dtype=tf.float32, shape=[None])
    next_state_ph = tf.placeholder(dtype=tf.float32, shape=[None,state_dim])
    is_not_terminal_ph = tf.placeholder(dtype=tf.float32, shape=[None])
    

    
    episodes = tf.Variable(0.0, trainable=False, name='episodes')
    episode_inc_op = episodes.assign_add(1)
    
    def __init__(self):
        with tf.variable_scope('actor'):
            self.actor_net_value = ANN.generate_actor_network(self,trainable = True, reuse = False)

        
        with tf.variable_scope('slow_target_actor', reuse=False):
            self.target_actor_net_value = tf.stop_gradient(ANN.generate_actor_network(self,trainable = False, reuse = False))

        with tf.variable_scope('critic') as scope:
            self.critic_net_value = ANN.generate_critic_network(self,trainable = True, reuse = False)
            self.q_value_for_actor_net = ANN.generate_critic_network(self,trainable = True, reuse = True,mode=2)

        
        with tf.variable_scope('slow_target_critic', reuse=False):
            self.target_critic_net_value = tf.stop_gradient(ANN.generate_critic_network(self,trainable = False, reuse = False,mode=3))
        
        
        self.actor_net_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope='actor')
        self.target_actor_net_vars = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='slow_target_actor')
        self.critic_net_vars = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope='critic')
        self.target_critic_net_vars = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='slow_target_critic')

        
    def predict_graph(self):
        return self.actor_net_value
    def generate_actor_network(self,trainable, reuse):
        hidden = tf.layers.dense(ANN.state_ph, h1_actor, activation = tf.nn.relu, trainable = trainable, name = 'dense', reuse = reuse)
        hidden_2 = tf.layers.dense(hidden, h2_actor, activation = tf.nn.relu, trainable = trainable, name = 'dense_1', reuse = reuse)
        hidden_3 = tf.layers.dense(hidden_2, h3_actor, activation = tf.nn.relu, trainable = trainable, name = 'dense_2', reuse = reuse)
        actions_unscaled = tf.layers.dense(hidden_3, action_dim, trainable = trainable, name = 'dense_3', reuse = reuse)
        actions = env.action_space.low + tf.nn.sigmoid(actions_unscaled)*(env.action_space.high - env.action_space.low) # bound the actions to the valid range
        return actions

   
    
    def generate_critic_network(self,trainable, reuse,mode=1):
        if mode==1:
            state_action = tf.concat([ANN.state_ph, ANN.action_ph], axis=1)
        if mode==2:
            state_action = tf.concat([ANN.state_ph,self.actor_net_value], axis=1)
        if mode==3:
            state_action = tf.concat([ANN.next_state_ph,self.target_actor_net_value], axis=1)
        hidden = tf.layers.dense(state_action, h1_critic, activation = tf.nn.relu, trainable = trainable, name = 'dense', reuse = reuse)
        hidden_2 = tf.layers.dense(hidden, h2_critic, activation = tf.nn.relu, trainable = trainable, name = 'dense_1', reuse = reuse)
        hidden_3 = tf.layers.dense(hidden_2, h3_critic, activation = tf.nn.relu, trainable = trainable, name = 'dense_2', reuse = reuse)
        q_values = tf.layers.dense(hidden_3, 1, trainable = trainable, name = 'dense_3', reuse = reuse)
        return q_values
    def train_graph(self):
        updated_q_values = tf.expand_dims(ANN.reward_ph, 1) + tf.expand_dims(ANN.is_not_terminal_ph, 1) * gamma * self.target_critic_net_value
        td_errors = updated_q_values - self.critic_net_value


        critic_loss = tf.reduce_mean(tf.square(td_errors))
        for var in self.critic_net_vars:
            if not 'bias' in var.name:
                critic_loss += l2_reg_critic * 0.5 * tf.nn.l2_loss(var)


        critic_train_op = tf.train.AdamOptimizer(lr_critic).minimize(critic_loss)
        actor_loss = -1*tf.reduce_mean(self.q_value_for_actor_net)
        for var in self.actor_net_vars:
            if not 'bias' in var.name:
                actor_loss += l2_reg_actor * 0.5 * tf.nn.l2_loss(var)

        actor_train_op = tf.train.AdamOptimizer(lr_actor).minimize(actor_loss, var_list=self.actor_net_vars)
        return actor_train_op,critic_train_op
        
    def update_wts_graph(self):
            update_slow_target_ops = []
            for i, target_actor_var in enumerate(self.target_actor_net_vars):
                update_slow_target_actor_op = target_actor_var.assign(tau*self.actor_net_vars[i]+(1-tau)*target_actor_var)
                update_slow_target_ops.append(update_slow_target_actor_op)

            for i, slow_target_var in enumerate(self.target_critic_net_vars):
                update_slow_target_critic_op = slow_target_var.assign(tau*self.critic_net_vars[i]+(1-tau)*slow_target_var)
                update_slow_target_ops.append(update_slow_target_critic_op)

            update_slow_targets_op = tf.group(*update_slow_target_ops, name='update_slow_targets')
            return update_slow_targets_op

# %%
Model=ANN()
actor_net_value=Model.predict_graph()
actor_train_op,critic_train_op=Model.train_graph()
update_wts_op=Model.update_wts_graph()

# %%
# initialize session
sess = tf.Session()	
sess.run(tf.global_variables_initializer())

# %%
#####################################################################################################
## Training

total_steps = 0
for ep in range(num_episodes):

    total_reward = 0
    steps_in_ep = 0

    
    noise_process = np.zeros(action_dim)
    noise_scale = (initial_noise_scale * noise_decay**ep) * (env.action_space.high - env.action_space.low)

    
    observation = env.reset()

    
    for t in range(max_steps_ep):

        action_for_state, = sess.run(actor_net_value, 
            feed_dict = {Model.state_ph: observation[None]})

        
        noise_process = exploration_theta*(exploration_mu - noise_process) + exploration_sigma*np.random.randn(action_dim)
        action_for_state += noise_scale*noise_process

       
        next_observation, reward, done, _info = env.step(action_for_state)
        total_reward += reward

        add_to_memory((observation, action_for_state, reward, next_observation, 
            0.0 if done else 1.0))

        
        if total_steps%train_every == 0 and len(replay_memory) >= minibatch_size:

           
            minibatch = sample_from_memory(minibatch_size)

            _, _ = sess.run([critic_train_op, actor_train_op], 
                feed_dict = {
                    Model.state_ph: np.asarray([elem[0] for elem in minibatch]),
                    Model.action_ph: np.asarray([elem[1] for elem in minibatch]),
                    Model.reward_ph: np.asarray([elem[2] for elem in minibatch]),
                    Model.next_state_ph: np.asarray([elem[3] for elem in minibatch]),
                    Model.is_not_terminal_ph: np.asarray([elem[4] for elem in minibatch]),
                    })


            _ = sess.run(update_wts_op)

        observation = next_observation
        total_steps += 1
        steps_in_ep += 1
        
        if done: 
            
            _ = sess.run(Model.episode_inc_op)
            break

    print('Episode %2i, Reward: %7.3f, Steps: %i, noise: %7.3f'%(ep,total_reward,steps_in_ep, noise_scale))


env.close()
# Out:
# Episode  0, Reward: -1359.159, Steps: 200, noise:   0.400
# Episode  1, Reward: -1447.255, Steps: 200, noise:   0.396
# Episode  2, Reward: -1279.135, Steps: 200, noise:   0.392
# Episode  3, Reward: -1494.842, Steps: 200, noise:   0.388
# Episode  4, Reward: -1348.619, Steps: 200, noise:   0.384
# Episode  5, Reward: -1550.526, Steps: 200, noise:   0.380
# Episode  6, Reward: -1524.732, Steps: 200, noise:   0.377
# Episode  7, Reward: -1290.683, Steps: 200, noise:   0.373
# Episode  8, Reward: -1431.669, Steps: 200, noise:   0.369
# Episode  9, Reward: -1774.093, Steps: 200, noise:   0.365
# Episode 10, Reward: -1651.753, Steps: 200, noise:   0.362
# Episode 11, Reward: -772.569, Steps: 200, noise:   0.358
# Episode 12, Reward: -889.412, Steps: 200, noise:   0.355
# Episode 13, Reward: -664.189, Steps: 200, noise:   0.351
# Episode 14, Reward: -636.565, Steps: 200, noise:   0.347
# Episode 15, Reward: -1170.935, Steps: 200, noise:   0.344
# Episode 16, Reward: -762.676, Steps: 200, noise:   0.341
# Episode 17, Reward: -1335.612, Steps: 200, noise:   0.337
# Episode 18, Reward: -1519.139, Steps: 200, noise:   0.334
# Episode 19, Reward: -905.229, Steps: 200, noise:   0.330
# Episode 20, Reward: -953.032, Steps: 200, noise:   0.327
# Episode 21, Reward: -1148.716, Steps: 200, noise:   0.324
# Episode 22, Reward: -1240.708, Steps: 200, noise:   0.321
# Episode 23, Reward: -1166.875, Steps: 200, noise:   0.317
# Episode 24, Reward: -1186.476, Steps: 200, noise:   0.314
# Episode 25, Reward: -1140.718, Steps: 200, noise:   0.311
# Episode 26, Reward: -1041.710, Steps: 200, noise:   0.308
# Episode 27, Reward: -749.414, Steps: 200, noise:   0.305
# Episode 28, Reward: -712.846, Steps: 200, noise:   0.302
# Episode 29, Reward: -751.542, Steps: 200, noise:   0.299
# Episode 30, Reward: -859.394, Steps: 200, noise:   0.296
# Episode 31, Reward: -863.365, Steps: 200, noise:   0.293
# Episode 32, Reward: -861.108, Steps: 200, noise:   0.290
# Episode 33, Reward: -888.478, Steps: 200, noise:   0.287
# Episode 34, Reward: -960.018, Steps: 200, noise:   0.284
# Episode 35, Reward: -860.122, Steps: 200, noise:   0.281
# Episode 36, Reward: -805.068, Steps: 200, noise:   0.279
# Episode 37, Reward: -505.708, Steps: 200, noise:   0.276
# Episode 38, Reward: -740.995, Steps: 200, noise:   0.273
# Episode 39, Reward: -739.992, Steps: 200, noise:   0.270
# Episode 40, Reward: -866.540, Steps: 200, noise:   0.268
# Episode 41, Reward: -860.406, Steps: 200, noise:   0.265
# Episode 42, Reward: -633.843, Steps: 200, noise:   0.262
# Episode 43, Reward: -632.581, Steps: 200, noise:   0.260
# Episode 44, Reward: -687.926, Steps: 200, noise:   0.257
# Episode 45, Reward: -624.156, Steps: 200, noise:   0.254
# Episode 46, Reward: -610.649, Steps: 200, noise:   0.252
# Episode 47, Reward: -499.188, Steps: 200, noise:   0.249
# Episode 48, Reward: -381.594, Steps: 200, noise:   0.247
# Episode 49, Reward: -409.507, Steps: 200, noise:   0.244
# Episode 50, Reward: -606.949, Steps: 200, noise:   0.242
# Episode 51, Reward: -502.810, Steps: 200, noise:   0.240
# Episode 52, Reward: -604.454, Steps: 200, noise:   0.237
# Episode 53, Reward: -380.148, Steps: 200, noise:   0.235
# Episode 54, Reward: -367.660, Steps: 200, noise:   0.232
# Episode 55, Reward: -233.199, Steps: 200, noise:   0.230
# Episode 56, Reward: -127.139, Steps: 200, noise:   0.228
# Episode 57, Reward: -246.629, Steps: 200, noise:   0.226
# Episode 58, Reward: -245.619, Steps: 200, noise:   0.223
# Episode 59, Reward: -115.204, Steps: 200, noise:   0.221
# Episode 60, Reward: -251.516, Steps: 200, noise:   0.219
# Episode 61, Reward: -124.559, Steps: 200, noise:   0.217
# Episode 62, Reward: -115.378, Steps: 200, noise:   0.215
# Episode 63, Reward: -750.896, Steps: 200, noise:   0.212
# Episode 64, Reward: -115.904, Steps: 200, noise:   0.210
# Episode 65, Reward: -120.415, Steps: 200, noise:   0.208
# Episode 66, Reward:  -3.277, Steps: 200, noise:   0.206
# Episode 67, Reward: -250.451, Steps: 200, noise:   0.204
# Episode 68, Reward: -237.857, Steps: 200, noise:   0.202
# Episode 69, Reward: -118.138, Steps: 200, noise:   0.200
# Episode 70, Reward: -127.022, Steps: 200, noise:   0.198
# Episode 71, Reward: -131.346, Steps: 200, noise:   0.196
# Episode 72, Reward: -231.285, Steps: 200, noise:   0.194
# Episode 73, Reward:  -1.856, Steps: 200, noise:   0.192
# Episode 74, Reward: -114.542, Steps: 200, noise:   0.190
# Episode 75, Reward:  -2.157, Steps: 200, noise:   0.188
# Episode 76, Reward: -116.438, Steps: 200, noise:   0.186
# Episode 77, Reward: -123.482, Steps: 200, noise:   0.184
# Episode 78, Reward: -123.633, Steps: 200, noise:   0.183
# Episode 79, Reward: -128.757, Steps: 200, noise:   0.181
# Episode 80, Reward: -293.181, Steps: 200, noise:   0.179
# Episode 81, Reward:  -2.161, Steps: 200, noise:   0.177
# Episode 82, Reward: -352.689, Steps: 200, noise:   0.175
# Episode 83, Reward: -132.475, Steps: 200, noise:   0.174
# Episode 84, Reward: -127.000, Steps: 200, noise:   0.172
# Episode 85, Reward: -124.538, Steps: 200, noise:   0.170
# Episode 86, Reward: -344.377, Steps: 200, noise:   0.169
# Episode 87, Reward: -121.650, Steps: 200, noise:   0.167
# Episode 88, Reward: -134.257, Steps: 200, noise:   0.165
# Episode 89, Reward: -120.712, Steps: 200, noise:   0.164
# Episode 90, Reward: -131.553, Steps: 200, noise:   0.162
# Episode 91, Reward: -135.027, Steps: 200, noise:   0.160
# Episode 92, Reward: -258.808, Steps: 200, noise:   0.159
# Episode 93, Reward: -144.882, Steps: 200, noise:   0.157
# Episode 94, Reward: -19.572, Steps: 200, noise:   0.156
# Episode 95, Reward: -251.755, Steps: 200, noise:   0.154
# Episode 96, Reward: -139.762, Steps: 200, noise:   0.152
# Episode 97, Reward: -132.610, Steps: 200, noise:   0.151
# Episode 98, Reward: -136.219, Steps: 200, noise:   0.149
# Episode 99, Reward: -230.814, Steps: 200, noise:   0.148
# Episode 100, Reward: -128.039, Steps: 200, noise:   0.146
# Episode 101, Reward: -129.800, Steps: 200, noise:   0.145
# Episode 102, Reward: -322.183, Steps: 200, noise:   0.143
# Episode 103, Reward: -249.565, Steps: 200, noise:   0.142
# Episode 104, Reward: -374.242, Steps: 200, noise:   0.141
# Episode 105, Reward: -137.628, Steps: 200, noise:   0.139
# Episode 106, Reward: -135.927, Steps: 200, noise:   0.138
# Episode 107, Reward: -246.280, Steps: 200, noise:   0.136
# Episode 108, Reward: -133.483, Steps: 200, noise:   0.135
# Episode 109, Reward: -244.229, Steps: 200, noise:   0.134
# Episode 110, Reward: -135.936, Steps: 200, noise:   0.132
# Episode 111, Reward: -131.615, Steps: 200, noise:   0.131
# Episode 112, Reward: -244.707, Steps: 200, noise:   0.130
# Episode 113, Reward: -123.506, Steps: 200, noise:   0.128
# Episode 114, Reward: -122.705, Steps: 200, noise:   0.127
# Episode 115, Reward: -219.174, Steps: 200, noise:   0.126
# Episode 116, Reward: -250.357, Steps: 200, noise:   0.125
# Episode 117, Reward: -130.168, Steps: 200, noise:   0.123
# Episode 118, Reward: -117.950, Steps: 200, noise:   0.122
# Episode 119, Reward: -127.994, Steps: 200, noise:   0.121
# Episode 120, Reward: -248.689, Steps: 200, noise:   0.120
# Episode 121, Reward: -121.924, Steps: 200, noise:   0.119
# Episode 122, Reward: -120.668, Steps: 200, noise:   0.117
# Episode 123, Reward: -247.812, Steps: 200, noise:   0.116
# Episode 124, Reward: -129.053, Steps: 200, noise:   0.115
# Episode 125, Reward: -250.626, Steps: 200, noise:   0.114
# Episode 126, Reward: -130.439, Steps: 200, noise:   0.113
# Episode 127, Reward: -129.004, Steps: 200, noise:   0.112
# Episode 128, Reward: -128.502, Steps: 200, noise:   0.111
# Episode 129, Reward: -239.673, Steps: 200, noise:   0.109
# Episode 130, Reward:  -1.220, Steps: 200, noise:   0.108
# Episode 131, Reward: -247.769, Steps: 200, noise:   0.107
# Episode 132, Reward: -128.722, Steps: 200, noise:   0.106
# Episode 133, Reward: -123.764, Steps: 200, noise:   0.105
# Episode 134, Reward: -290.740, Steps: 200, noise:   0.104
# Episode 135, Reward: -301.141, Steps: 200, noise:   0.103
# Episode 136, Reward: -121.415, Steps: 200, noise:   0.102
# Episode 137, Reward: -235.837, Steps: 200, noise:   0.101
# Episode 138, Reward: -126.665, Steps: 200, noise:   0.100
# Episode 139, Reward: -251.166, Steps: 200, noise:   0.099
# Episode 140, Reward: -258.278, Steps: 200, noise:   0.098
# Episode 141, Reward: -242.127, Steps: 200, noise:   0.097
# Episode 142, Reward: -314.953, Steps: 200, noise:   0.096
# Episode 143, Reward: -126.391, Steps: 200, noise:   0.095
# Episode 144, Reward: -138.597, Steps: 200, noise:   0.094
# Episode 145, Reward: -130.393, Steps: 200, noise:   0.093
# Episode 146, Reward:  -4.350, Steps: 200, noise:   0.092
# Episode 147, Reward: -126.142, Steps: 200, noise:   0.091
# Episode 148, Reward: -10.086, Steps: 200, noise:   0.090
# Episode 149, Reward: -237.241, Steps: 200, noise:   0.089

# %%
env.close()

# %%
import time

env=gym.make(env_to_use)
obs=env.reset()

for i in range(200):
    
    _action, = sess.run(actor_net_value, 
                    feed_dict = {Model.state_ph: obs[None]})
    obs,rew,done,info=env.step(_action)
    env.render()
    time.sleep(0.1)
env.close()
