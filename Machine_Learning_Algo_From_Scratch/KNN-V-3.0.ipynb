# %%
from xml.dom import minidom
import re
import pandas as pd
import sys
import pickle
import numpy as np
import time
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
ps = PorterStemmer()
sys.__stdout__=sys.stdout

# %%
def stem_regular_verb(word):
    if len(word)<=3:
        return word
    if word[-2:]=='es':
        if word[:-2] in verbs:
            word=word[:-2]

    elif word[-1:]=='s':
        if word[:-1] in verbs:
            word=word[:-1]
            
    elif word[-3:]=='ing':
        if word[:-3] in verbs:
            word=word[:-3]
        if word[:-4] in verbs:
            word=word[:-4]
        else:
            word=word[:-3]
    
    elif word[-2:]=='ed':
        if word[:-2] in verbs:
            word=word[:-2]
        elif word[:-1] in verbs:
            word=word[:-1]
    #word=stem_irregular(word)
    return word
def stem_simple(word):
    if word[-2:]=='es':
            word=word[:-2]   
    elif word[-1:]=='s':
            word=word[:-1]
    elif word[-3:]=='ing':
            word=word[:-3]
    
    elif word[-2:]=='ed':
            word=word[:-2]
    return word

def stem_irregular_verb(word):
        if word in past:
            ind=past.index(word)
            word=verb_root[ind]
        elif word in past_pp:
            ind=past_pp.index(word)
            word=verb_root[ind]
        return word
def remove_minor_words(wordmap,word_count,min_occurance):
    words=list(wordmap.keys())
    freq=list(wordmap.values())
    word_df=pd.DataFrame(words,index=list(wordmap.values()),columns=['words'])
    word_df=word_df.sort_index()
    word_df['freq']=wc
    word_df=word_df.sort_values('freq',ascending=False)
    mask=word_df['freq']<=min_occurance
    word_df=word_df[mask]
    ss_words=(list(word_df['words']))
    print('initial length of wordmap :',len(wordmap))
    for word in ss_words:
        del wordmap[word]
    _wordmap={}
    ind=0
    for word in wordmap.keys():
        _wordmap[word]=ind
        ind+=1
    print('reduced length of wordmap :',len(_wordmap))
    return _wordmap

def stem_word(word):
    temp=word
    word=stem_regular_verb(word)
    word=stem_irregular_verb(word)
    #word=ps.stem(word)
    if(len(word)<=1):
        return temp
    return word   
def remove_tags(doc):
    text=doc.lower()
    #text=re.sub('\n',' ',text)
    #text=re.sub('-',' ',text)
    #text=re.sub('[()?.@*#&!,$]','',text)
    #text=re.sub('[\']','',text)
    #text=re.sub('[^a-z0-9]',' ',text)
    #words=text.split(' ')
    text=re.sub('<[^<>]+>',' ',text)
    #text=re.sub('^\w+',' ',text)
    #words=text.split('\n')
    words=re.findall('\w+',text)
    return words
def pre_process(topics,max_doc,root):
    index=0
    labels=[]
    ln=0
    labeled_docs={}
    for topic in topics:
        print(topic)
        mydoc = minidom.parse(root+topic+'.xml')
        documents = mydoc.getElementsByTagName('row')
        doc_count=0
        docs=[]
        for doc in documents:
            doc=doc.attributes['Body'].value
            if len(doc)<5:
                continue
            words = remove_tags(doc)
            ln+=len(words)
            docs.append(words)
            labels.append(topic)
            doc_count+=1
            if doc_count>=max_doc:
                break
        labeled_docs[topic]=docs
    return labeled_docs,ln

# %%
root='Dataset/Training/'
root_test='Dataset/Test/'

f=open('Stopwords.txt')
s_words=f.read()
s_words=s_words.split('\n')
s_words.append('')

f=open('verbs.txt','r')
verbs=f.read()
f.close()
verbs=verbs.split('\n')

irr=pd.read_csv('irr_verbs.txt',delimiter=',',names=['root','past','past_par'])
verb_root=list(irr['root'])
past=list(irr['past'])
past_pp=list(irr['past_par'])

#topics=['3d_Printer','Coffee','Arduino','Astronomy','Biology']#,'Chess','Cooking','Law','Space','Windows_Phone','Wood_Working']
topics1=['3d_Printer','Anime','Arduino']#----------Tes topic set 1
topics2=['3d_Printer','Coffee','Chess']#-----------Topic set 2
topics3=['3d_Printer','Coffee','Chess','Astronomy','Law']#----------Topic set 3
#topics=['Arduino','Anime','Windows_Phone']
max_docs_train=600
max_docs_test=20
rm_minor_words=False
log=False
topics=topics2
root='Dataset/Training/'
train_docs,ln=pre_process(topics,max_docs_train,root)
test_docs,ln=pre_process(topics,max_docs_test,root_test)
print(ln)
# Out:
# 3d_Printer
# Coffee
# Chess
# 3d_Printer
# Coffee
# Chess
# 9983

# %%
def make_dictionary(topics,max_doc,all_docs):
    index=0
    wordmap={}
    word_count=[]
    for topic in topics:
        print(topic)
        doc_count=0
        docs=all_docs[topic]
        for doc in docs:
            for word in doc:
                if word in s_words or len(word)<=1:
                    continue
                word=stem_word(word)
                if word not in wordmap:
                    wordmap[word]=index
                    word_count.append(int(1))
                    index=index+1
                elif word in wordmap:
                    ind=wordmap[word]
                    word_count[ind]=int(word_count[ind])+1
    return wordmap,word_count
def vectorize_seq(topics,max_doc,wordmap,all_docs):
    n_row=len(topics)*(max_doc)
    vectors=np.zeros((n_row,len(wordmap)),dtype=np.float64)
    vct_label=[]
    row=0
    for topic in topics:
        print(topic)
        doc_count=0
        docs=all_docs[topic]
        for doc in docs:
            #if len(doc)<5:
            #    continue
            for word in doc:
                word=stem_word(word)
                if word in wordmap:
                    ind=wordmap[word]
                    vectors[row,ind]=vectors[row,ind]+1
            row=row+1
            vct_label.append(topic)
            word_list.append(doc)
    return vectors,vct_label

# %%
def eucl_dis(test_vect,vectors,vct_labels):
    h_dists=[]
    for row in range(len(vct_labels)):
        vect=vectors[row]
        dist=np.abs(vect-test_vect)
        dist=np.square(dist)
        dist=np.sum(dist)
        dist=np.sqrt(dist)
        label=vct_labels[row]
        h_dists.append([dist,label])
    return h_dists
def humm_dis(test_vector,vectors,vct_labels):
    h_dists=[]
    
    test_vect=np.array(test_vector>0,dtype=np.float64)
    vects=np.array(vectors>0,dtype=np.float64)
    #test_vect=test_vector
    #vects=vectors
    for row in range(len(vct_labels)):
        vect=vects[row]
        label=vct_labels[row]
        dist=np.abs(vect-test_vect)
        #dist=dist*[test_vect!=0]
        dist=np.sum(dist)
        h_dists.append([dist,label])
    return h_dists
def cos_dis(test_vect,vectors,vct_labels):
    h_dists=[]
    
    vectors_bin= np.array(vectors>0,dtype=np.float64)
    wc_vect=np.sum(vectors_bin,axis=0)
    no_docs=len(vectors)
    
    IDF=no_docs/(wc_vect+1)
    IDF=np.log(IDF)
    
    for row in range(len(vct_labels)):
        train_vect=vectors[row]
        
        train_label=vct_labels[row]
        
        train_total=np.sum(train_vect)
        test_total=np.sum(test_vect)
        
        TF_test=test_vect/test_total
        test_vec=TF_test*IDF
        
        temp=np.square(test_vec)
        temp=np.sum(temp)
        test_vec_mag=np.sqrt(temp)
        
        TF_train=train_vect/train_total
        train_vec=TF_train*IDF
        
        temp=np.square(train_vec)
        temp=np.sum(temp)
        train_vec_mag=np.sqrt(temp)
        
        X=np.sum(test_vec*train_vec)
        Y=train_vec_mag*test_vec_mag
        
        dist=X/Y
        h_dists.append([dist,train_label])
    return h_dists

# %%
def knn(nn,test_vect,vectors,vct_labels,method):
    if method=='euc':
        h_dists=eucl_dis(test_vect,vectors,vct_labels)
    if method=='hum':
        h_dists=humm_dis(test_vect,vectors,vct_labels)
    if method=='cos':
        h_dists=cos_dis(test_vect,vectors,vct_labels)
    h_df=pd.DataFrame(h_dists,columns=['dist','label'])
    
    if method=='euc' or method=='hum':
        h_df=h_df.sort_values('dist',ascending=True)
    if method=='cos':
        h_df=h_df.sort_values('dist',ascending=False)
    print(h_df.head(5))
    lb=h_df['label']
    lb=lb[:nn]
    print(lb.values)
    
    if k==1:
        lb=lb.mode()
        lb=lb.values[0]
        
    if k==3:
        if len(lb.unique())==k:
            lb=lb[:1]
        lb=lb.mode()
        lb=lb.values[0]
    if k==5:
        if len(lb.mode())>=2:
            lb=lb[:3]
            if len(lb.mode())>=2:
                lb=lb[:1]
        lb=lb.mode()
        lb=lb.values[0]
        
                        
    return(lb)

# %%
word_list=[]
min_occurance=1
print('Making dictionary :')
wordmap,wc=make_dictionary(topics,max_docs_train,train_docs)
if rm_minor_words==True:
    print('Removing minor words:')
    wordmap=remove_minor_words(wordmap,wc,min_occurance)
print('Vectorizing Sequence:')
vectors,vct_labels=vectorize_seq(topics,max_docs_train,wordmap,train_docs)
print(len(wordmap))
# Out:
# Making dictionary :
# 3d_Printer
# Coffee
# Chess
# Vectorizing Sequence:
# 3d_Printer
# Coffee
# Chess
# 11856

# %%
test_vector,true_lbs=vectorize_seq(topics,max_docs_test,wordmap,test_docs)
n=len(topics)*max_docs_test
methods=['cos','euc','hum']
k_val=[1,3,5]
#k_val=[5]
no_topics=len(topics)
tot_doc=no_topics*max_docs_train
tot_doc_test=no_topics*max_docs_test

acc_log=''
acc_log+='********************************************************************************************\n'
acc_log+=str(topics)+'\n'
acc_log+='stem : none , re : findall , minor_remove: 1\n'
acc_log+=str(['no_topic','train doc per topic','train_doc','test doc per topic','test_doc','word map'])+'\n'
acc_log+=str([no_topics,max_docs_train,tot_doc,max_docs_test,tot_doc_test,str(len(wordmap))])+'\n'
acc_log+='********************************************************************************************\n'
acc_log+=str(['k','method','accuracy','time'])+'\n'
for k in k_val:
    for method in methods:
        acc=0
        T=time.time()
        for i in range(len(test_vector)):
            true_lb=true_lbs[i]
            test_vect=test_vector[i,:]
            pred_lb=knn(k,test_vect,vectors,vct_labels,method)
            print(pred_lb,true_lb)
            if pred_lb==true_lb:
                acc=acc+1
                print(pred_lb,true_lb,acc,i+1)
        accuracy=acc/(n)
        T=time.time()-T
        print('accuray',accuracy)
        print('Time :',T)
        acc_log+=(str([k,method,accuracy,T])+'\n')

acc_log=re.sub('[\[\] ]','',acc_log)
if log==True:
    file=open('Report/backup_exp_mod.txt','a')
    file.write(acc_log)
    file.close()
    pass

#68.75% eucl 60 82.92
#53.33 humm 60  81.25
#87.08 cos 94.17
# Out:
# 3d_Printer
# Coffee
# Chess
#          dist       label
# 235  0.251219  3d_Printer
# 243  0.221500  3d_Printer
# 526  0.204949  3d_Printer
# 189  0.194417  3d_Printer
# 283  0.187959  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 1 1
#          dist       label
# 193  0.450189  3d_Printer
# 194  0.375348  3d_Printer
# 72   0.336178  3d_Printer
# 230  0.315082  3d_Printer
# 262  0.311563  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 2 2
#          dist       label
# 189  0.389045  3d_Printer
# 347  0.268768  3d_Printer
# 345  0.242946  3d_Printer
# 228  0.223566  3d_Printer
# 964  0.212590      Coffee
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 3 3
#          dist       label
# 407  0.290265  3d_Printer
# 410  0.178981  3d_Printer
# 482  0.177295  3d_Printer
# 288  0.140594  3d_Printer
# 163  0.130658  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 4 4
#          dist       label
# 545  0.199586  3d_Printer
# 283  0.188437  3d_Printer
# 522  0.180854  3d_Printer
# 243  0.180312  3d_Printer
# 529  0.167018  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 5 5
#          dist       label
# 533  0.235332  3d_Printer
# 213  0.207579  3d_Printer
# 535  0.181966  3d_Printer
# 449  0.167248  3d_Printer
# 470  0.165005  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 6 6
#           dist       label
# 1194  0.166884       Chess
# 210   0.131756  3d_Printer
# 533   0.117216  3d_Printer
# 103   0.107335  3d_Printer
# 469   0.100956  3d_Printer
# ['Chess']
# Chess 3d_Printer
#          dist       label
# 245  0.275193  3d_Printer
# 2    0.249413  3d_Printer
# 121  0.221179  3d_Printer
# 979  0.195507      Coffee
# 561  0.193531      Coffee
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 7 8
#          dist       label
# 314  0.427276  3d_Printer
# 412  0.230093  3d_Printer
# 546  0.176580  3d_Printer
# 535  0.172653  3d_Printer
# 528  0.157807  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 8 9
#          dist       label
# 533  0.297332  3d_Printer
# 534  0.274589  3d_Printer
# 316  0.177643  3d_Printer
# 469  0.166993  3d_Printer
# 205  0.166328  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 9 10
#          dist       label
# 190  0.275348  3d_Printer
# 43   0.220444  3d_Printer
# 124  0.208829  3d_Printer
# 7    0.194384  3d_Printer
# 101  0.193611  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 10 11
#          dist       label
# 299  0.353904  3d_Printer
# 316  0.281145  3d_Printer
# 465  0.217098  3d_Printer
# 348  0.190251  3d_Printer
# 352  0.187559  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 11 12
#          dist       label
# 43   0.310494  3d_Printer
# 6    0.259570  3d_Printer
# 55   0.238834  3d_Printer
# 159  0.212163  3d_Printer
# 238  0.210782  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 12 13
#          dist       label
# 260  0.212046  3d_Printer
# 185  0.191611  3d_Printer
# 243  0.187947  3d_Printer
# 235  0.173905  3d_Printer
# 128  0.164339  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 13 14
#          dist       label
# 189  0.312288  3d_Printer
# 228  0.265133  3d_Printer
# 235  0.248335  3d_Printer
# 193  0.233150  3d_Printer
# 230  0.229920  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 14 15
#          dist       label
# 299  0.253677  3d_Printer
# 316  0.209874  3d_Printer
# 225  0.201663  3d_Printer
# 55   0.197029  3d_Printer
# 556  0.189575  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 15 16
#          dist       label
# 412  0.346490  3d_Printer
# 511  0.213581  3d_Printer
# 415  0.194378  3d_Printer
# 265  0.192042  3d_Printer
# 235  0.184175  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 16 17
#          dist       label
# 189  0.185284  3d_Printer
# 157  0.140854  3d_Printer
# 228  0.132303  3d_Printer
# 51   0.131730  3d_Printer
# 3    0.116620  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 17 18
#          dist       label
# 528  0.334717  3d_Printer
# 274  0.308957  3d_Printer
# 317  0.221240  3d_Printer
# 412  0.201253  3d_Printer
# 535  0.196617  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 18 19
#          dist       label
# 316  0.233661  3d_Printer
# 243  0.171200  3d_Printer
# 56   0.169069  3d_Printer
# 235  0.156491  3d_Printer
# 526  0.127173  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 19 20
#           dist   label
# 931   0.353523  Coffee
# 580   0.347184  Coffee
# 1118  0.303571  Coffee
# 842   0.246344  Coffee
# 910   0.224202  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 20 21
#          dist   label
# 570  0.215172  Coffee
# 739  0.201853  Coffee
# 577  0.167359  Coffee
# 663  0.147380  Coffee
# 726  0.146164  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 21 22
#           dist   label
# 1080  0.389062  Coffee
# 936   0.277523  Coffee
# 1079  0.244801  Coffee
# 984   0.243945  Coffee
# 578   0.235607  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 22 23
#          dist   label
# 827  0.191831  Coffee
# 998  0.186666  Coffee
# 994  0.145794  Coffee
# 914  0.138526  Coffee
# 997  0.125319  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 23 24
#           dist   label
# 943   0.233858  Coffee
# 846   0.217726  Coffee
# 842   0.210026  Coffee
# 979   0.205036  Coffee
# 1142  0.200218  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 24 25
#           dist   label
# 792   0.224267  Coffee
# 943   0.216632  Coffee
# 996   0.209397  Coffee
# 846   0.207298  Coffee
# 1075  0.205162  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 25 26
#           dist   label
# 1025  0.295875  Coffee
# 781   0.276026  Coffee
# 1119  0.233282  Coffee
# 1027  0.229625  Coffee
# 910   0.220983  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 26 27
#           dist   label
# 673   0.375948  Coffee
# 1042  0.304079  Coffee
# 952   0.282586  Coffee
# 871   0.280022  Coffee
# 1123  0.248581  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 27 28
#           dist   label
# 567   0.308138  Coffee
# 762   0.195739  Coffee
# 1003  0.176915  Coffee
# 1075  0.154831  Coffee
# 645   0.154300  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 28 29
#           dist   label
# 1151  0.473256  Coffee
# 911   0.382098  Coffee
# 1122  0.317685  Coffee
# 1025  0.310614  Coffee
# 1153  0.298722  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 29 30
#           dist   label
# 1151  0.457650  Coffee
# 911   0.334649  Coffee
# 781   0.285055  Coffee
# 1153  0.269782  Coffee
# 931   0.154942  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 30 31
#          dist   label
# 799  0.452848  Coffee
# 595  0.417928  Coffee
# 783  0.343529  Coffee
# 628  0.333755  Coffee
# 927  0.317406  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 31 32
#           dist   label
# 1042  0.457862  Coffee
# 952   0.425458  Coffee
# 1015  0.404559  Coffee
# 607   0.393113  Coffee
# 716   0.375129  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 32 33
#           dist   label
# 935   0.406607  Coffee
# 1112  0.243764  Coffee
# 1075  0.236503  Coffee
# 1015  0.203787  Coffee
# 1034  0.196285  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 33 34
#           dist       label
# 865   0.243921      Coffee
# 616   0.133127      Coffee
# 1618  0.124759       Chess
# 997   0.115838      Coffee
# 252   0.102006  3d_Printer
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 34 35
#           dist   label
# 1023  0.349805  Coffee
# 732   0.323186  Coffee
# 730   0.234816  Coffee
# 731   0.206124  Coffee
# 801   0.201037  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 35 36
#           dist   label
# 799   0.349016  Coffee
# 783   0.338125  Coffee
# 1036  0.315282  Coffee
# 628   0.307387  Coffee
# 1094  0.304979  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 36 37
#           dist   label
# 1058  0.259916  Coffee
# 896   0.236026  Coffee
# 1062  0.235167  Coffee
# 893   0.202317  Coffee
# 1077  0.192934  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 37 38
#           dist   label
# 747   0.254686  Coffee
# 1061  0.196007  Coffee
# 711   0.158644  Coffee
# 746   0.150841  Coffee
# 578   0.149241  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 38 39
#           dist   label
# 1086  0.233571  Coffee
# 1058  0.203576  Coffee
# 1077  0.191853  Coffee
# 812   0.188264  Coffee
# 813   0.183790  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 39 40
#           dist  label
# 1342  0.263922  Chess
# 1219  0.238720  Chess
# 1248  0.230595  Chess
# 1161  0.208461  Chess
# 1313  0.202418  Chess
# ['Chess']
# Chess Chess
# Chess Chess 40 41
#           dist  label
# 1730  0.327128  Chess
# 1632  0.192235  Chess
# 1562  0.169380  Chess
# 1563  0.118922  Chess
# 1254  0.106377  Chess
# ['Chess']
# Chess Chess
# Chess Chess 41 42
#           dist   label
# 1179  0.218397   Chess
# 1727  0.214785   Chess
# 598   0.186606  Coffee
# 1676  0.180811   Chess
# 1170  0.134158   Chess
# ['Chess']
# Chess Chess
# Chess Chess 42 43
#           dist       label
# 940   0.226753      Coffee
# 6     0.214722  3d_Printer
# 1536  0.167088       Chess
# 1465  0.161649       Chess
# 1551  0.159330       Chess
# ['Coffee']
# Coffee Chess
#           dist  label
# 1742  0.319598  Chess
# 1549  0.255359  Chess
# 1426  0.244915  Chess
# 1580  0.240429  Chess
# 1585  0.234955  Chess
# ['Chess']
# Chess Chess
# Chess Chess 43 45
#           dist       label
# 690   0.175449      Coffee
# 1179  0.154608       Chess
# 414   0.137054  3d_Printer
# 1385  0.119298       Chess
# 312   0.112382  3d_Printer
# ['Coffee']
# Coffee Chess
#           dist  label
# 1388  0.225627  Chess
# 1251  0.212803  Chess
# 1254  0.206374  Chess
# 1299  0.174271  Chess
# 1300  0.153678  Chess
# ['Chess']
# Chess Chess
# Chess Chess 44 47
#           dist  label
# 1366  0.297613  Chess
# 1295  0.245645  Chess
# 1251  0.240047  Chess
# 1388  0.231359  Chess
# 1299  0.229678  Chess
# ['Chess']
# Chess Chess
# Chess Chess 45 48
#           dist  label
# 1281  0.217085  Chess
# 1577  0.210156  Chess
# 1676  0.167787  Chess
# 1717  0.155428  Chess
# 1228  0.154216  Chess
# ['Chess']
# Chess Chess
# Chess Chess 46 49
#           dist  label
# 1401  0.232531  Chess
# 1558  0.231296  Chess
# 1731  0.217662  Chess
# 1458  0.215491  Chess
# 1219  0.207081  Chess
# ['Chess']
# Chess Chess
# Chess Chess 47 50
#           dist  label
# 1555  0.346006  Chess
# 1257  0.275260  Chess
# 1368  0.262751  Chess
# 1567  0.252366  Chess
# 1740  0.249219  Chess
# ['Chess']
# Chess Chess
# Chess Chess 48 51
#           dist  label
# 1370  0.348681  Chess
# 1388  0.301169  Chess
# 1322  0.293948  Chess
# 1399  0.279941  Chess
# 1477  0.279639  Chess
# ['Chess']
# Chess Chess
# Chess Chess 49 52
#           dist  label
# 1388  0.396585  Chess
# 1399  0.369005  Chess
# 1251  0.366016  Chess
# 1366  0.345311  Chess
# 1322  0.344198  Chess
# ['Chess']
# Chess Chess
# Chess Chess 50 53
#           dist  label
# 1495  0.173128  Chess
# 1368  0.158825  Chess
# 1314  0.158232  Chess
# 1540  0.143982  Chess
# 1353  0.133212  Chess
# ['Chess']
# Chess Chess
# Chess Chess 51 54
#           dist       label
# 442   0.160416  3d_Printer
# 1732  0.132833       Chess
# 1722  0.131499       Chess
# 1638  0.130692       Chess
# 1328  0.127280       Chess
# ['3d_Printer']
# 3d_Printer Chess
#           dist  label
# 1455  0.272061  Chess
# 1483  0.252545  Chess
# 1443  0.251767  Chess
# 1317  0.170049  Chess
# 1186  0.163564  Chess
# ['Chess']
# Chess Chess
# Chess Chess 52 56
#           dist  label
# 1563  0.290255  Chess
# 1562  0.286608  Chess
# 1730  0.276452  Chess
# 1746  0.168901  Chess
# 1632  0.154727  Chess
# ['Chess']
# Chess Chess
# Chess Chess 53 57
#           dist  label
# 1603  0.291399  Chess
# 1724  0.198182  Chess
# 1465  0.190993  Chess
# 1640  0.182077  Chess
# 1206  0.165498  Chess
# ['Chess']
# Chess Chess
# Chess Chess 54 58
#           dist       label
# 1676  0.313907       Chess
# 1720  0.289470       Chess
# 1509  0.254787       Chess
# 1332  0.252646       Chess
# 392   0.246508  3d_Printer
# ['Chess']
# Chess Chess
# Chess Chess 55 59
#           dist  label
# 1487  0.296373  Chess
# 1692  0.280553  Chess
# 1465  0.224692  Chess
# 1369  0.224232  Chess
# 1515  0.207613  Chess
# ['Chess']
# Chess Chess
# Chess Chess 56 60
# accuray 0.9333333333333333
# Time : 69.06249451637268
#           dist       label
# 230  12.041595  3d_Printer
# 101  12.041595  3d_Printer
# 189  12.041595  3d_Printer
# 447  12.083046  3d_Printer
# 400  12.124356  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 1 1
#           dist       label
# 193  13.190906  3d_Printer
# 66   13.820275  3d_Printer
# 230  13.892444  3d_Printer
# 228  13.964240  3d_Printer
# 472  14.212670  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 2 2
#            dist       label
# 189   16.583124  3d_Printer
# 230   17.464249  3d_Printer
# 228   17.691806  3d_Printer
# 1599  17.944358       Chess
# 3     18.027756  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 3 3
#           dist   label
# 1526  8.660254   Chess
# 1593  8.717798   Chess
# 616   8.774964  Coffee
# 750   8.888194  Coffee
# 1607  8.888194   Chess
# ['Chess']
# Chess 3d_Printer
#          dist       label
# 290  7.280110  3d_Printer
# 421  7.416198  3d_Printer
# 529  7.416198  3d_Printer
# 446  7.483315  3d_Printer
# 355  7.483315  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 4 5
#          dist       label
# 261  6.928203  3d_Printer
# 398  6.928203  3d_Printer
# 444  7.071068  3d_Printer
# 394  7.071068  3d_Printer
# 391  7.071068  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 5 6
#           dist   label
# 1555  6.164414   Chess
# 750   6.164414  Coffee
# 1526  6.164414   Chess
# 1292  6.244998   Chess
# 1267  6.244998   Chess
# ['Chess']
# Chess 3d_Printer
#           dist       label
# 355   3.605551  3d_Printer
# 344   3.605551  3d_Printer
# 1271  3.872983       Chess
# 1276  3.872983       Chess
# 1290  3.872983       Chess
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 6 8
#           dist       label
# 412  18.275667  3d_Printer
# 314  18.681542  3d_Printer
# 546  18.788294  3d_Printer
# 187  18.947295  3d_Printer
# 231  19.000000  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 7 9
#          dist       label
# 290  7.483315  3d_Printer
# 473  7.483315  3d_Printer
# 205  7.549834  3d_Printer
# 162  7.549834  3d_Printer
# 529  7.615773  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 8 10
#          dist       label
# 7    5.830952  3d_Printer
# 101  5.916080  3d_Printer
# 161  6.082763  3d_Printer
# 521  6.164414  3d_Printer
# 205  6.244998  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 9 11
#            dist       label
# 299   10.583005  3d_Printer
# 230   10.677078  3d_Printer
# 529   10.816654  3d_Printer
# 1318  10.908712       Chess
# 24    11.000000  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 10 12
#           dist       label
# 43   18.439089  3d_Printer
# 44   19.000000  3d_Printer
# 36   19.052559  3d_Printer
# 185  19.078784  3d_Printer
# 96   19.183326  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 11 13
#           dist       label
# 440  17.521415  3d_Printer
# 36   17.720045  3d_Printer
# 44   17.720045  3d_Printer
# 260  17.748239  3d_Printer
# 231  17.804494  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 12 14
#           dist       label
# 228  16.155494  3d_Printer
# 189  16.155494  3d_Printer
# 193  16.613248  3d_Printer
# 66   16.643317  3d_Printer
# 230  16.643317  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 13 15
#            dist       label
# 206   10.295630  3d_Printer
# 423   10.535654  3d_Printer
# 101   10.535654  3d_Printer
# 1121  10.583005      Coffee
# 107   10.583005  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 14 16
#            dist       label
# 412   11.489125  3d_Printer
# 230   11.832160  3d_Printer
# 1599  11.958261       Chess
# 66    12.000000  3d_Printer
# 1695  12.000000       Chess
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 15 17
#            dist       label
# 1695  11.874342       Chess
# 230   11.874342  3d_Printer
# 344   11.958261  3d_Printer
# 1482  12.000000       Chess
# 75    12.000000  3d_Printer
# ['Chess']
# Chess 3d_Printer
#           dist       label
# 528  29.546573  3d_Printer
# 535  30.149627  3d_Printer
# 412  31.320920  3d_Printer
# 30   31.511903  3d_Printer
# 202  31.591138  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 16 19
#           dist       label
# 398   5.916080  3d_Printer
# 261   5.916080  3d_Printer
# 1121  6.000000      Coffee
# 1271  6.082763       Chess
# 1267  6.082763       Chess
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 17 20
#            dist   label
# 580   11.269428  Coffee
# 1118  11.357817  Coffee
# 641   11.489125  Coffee
# 704   12.165525  Coffee
# 790   12.288206  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 18 21
#            dist   label
# 704   13.747727  Coffee
# 641   13.820275  Coffee
# 1100  14.035669  Coffee
# 830   14.071247  Coffee
# 570   14.106736  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 19 22
#            dist   label
# 981   10.198039  Coffee
# 1079  10.198039  Coffee
# 949   10.344080  Coffee
# 917   10.344080  Coffee
# 744   10.392305  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 20 23
#           dist       label
# 1121  5.567764      Coffee
# 344   5.656854  3d_Printer
# 1097  5.656854      Coffee
# 750   5.744563      Coffee
# 949   5.744563      Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 21 24
#           dist   label
# 979   6.633250  Coffee
# 978   6.782330  Coffee
# 1294  7.141428   Chess
# 1276  7.141428   Chess
# 1267  7.141428   Chess
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 22 25
#           dist   label
# 863   6.164414  Coffee
# 979   6.244998  Coffee
# 609   6.403124  Coffee
# 1121  6.403124  Coffee
# 799   6.480741  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 23 26
#           dist  label
# 1676  7.483315  Chess
# 1278  7.549834  Chess
# 1271  7.549834  Chess
# 1296  7.549834  Chess
# 1267  7.549834  Chess
# ['Chess']
# Chess Coffee
#           dist   label
# 917   4.358899  Coffee
# 604   4.358899  Coffee
# 1121  4.358899  Coffee
# 799   4.472136  Coffee
# 1267  4.472136   Chess
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 24 28
#           dist   label
# 1121  8.660254  Coffee
# 979   8.660254  Coffee
# 949   8.660254  Coffee
# 853   8.660254  Coffee
# 1097  8.717798  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 25 29
#           dist   label
# 979   6.324555  Coffee
# 1121  6.480741  Coffee
# 949   6.480741  Coffee
# 1097  6.557439  Coffee
# 799   6.557439  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 26 30
#            dist   label
# 1151   9.848858  Coffee
# 1121  10.000000  Coffee
# 1267  10.049876   Chess
# 970   10.049876  Coffee
# 1296  10.049876   Chess
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 27 31
#            dist   label
# 595   37.656341  Coffee
# 819   41.484937  Coffee
# 1094  42.272923  Coffee
# 628   42.508823  Coffee
# 705   44.136153  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 28 32
#            dist   label
# 758   15.165751  Coffee
# 952   15.362291  Coffee
# 757   15.427249  Coffee
# 1102  15.491933  Coffee
# 759   15.556349  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 29 33
#            dist   label
# 1112  16.093477  Coffee
# 799   16.583124  Coffee
# 1096  16.613248  Coffee
# 609   16.673332  Coffee
# 1085  16.703293  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 30 34
#           dist       label
# 1676  5.477226       Chess
# 419   5.656854  3d_Printer
# 1271  5.744563       Chess
# 355   5.744563  3d_Printer
# 1267  5.744563       Chess
# ['Chess']
# Chess Coffee
#           dist   label
# 827   7.483315  Coffee
# 564   7.615773  Coffee
# 974   7.810250  Coffee
# 949   7.810250  Coffee
# 1096  7.810250  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 31 36
#           dist   label
# 799   3.741657  Coffee
# 1096  4.123106  Coffee
# 609   4.123106  Coffee
# 1121  4.358899  Coffee
# 949   4.358899  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 32 37
#           dist  label
# 1290  2.645751  Chess
# 1262  2.645751  Chess
# 1276  2.645751  Chess
# 1292  2.645751  Chess
# 1294  2.645751  Chess
# ['Chess']
# Chess Coffee
#          dist   label
# 747  7.211103  Coffee
# 744  7.280110  Coffee
# 743  7.483315  Coffee
# 949  7.483315  Coffee
# 963  7.615773  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 33 39
#           dist       label
# 1100  8.246211      Coffee
# 421   8.306624  3d_Printer
# 1676  8.306624       Chess
# 1121  8.306624      Coffee
# 1062  8.366600      Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 34 40
#           dist  label
# 1219  7.141428  Chess
# 1312  7.280110  Chess
# 1313  7.348469  Chess
# 1448  7.348469  Chess
# 1450  7.416198  Chess
# ['Chess']
# Chess Chess
# Chess Chess 35 41
#            dist  label
# 1219  17.435596  Chess
# 1256  17.435596  Chess
# 1229  17.464249  Chess
# 1448  17.521415  Chess
# 1269  17.549929  Chess
# ['Chess']
# Chess Chess
# Chess Chess 36 42
#           dist   label
# 1121  3.464102  Coffee
# 1269  3.464102   Chess
# 1434  3.605551   Chess
# 1271  3.605551   Chess
# 1267  3.605551   Chess
# ['Coffee']
# Coffee Chess
#           dist       label
# 344   6.782330  3d_Printer
# 1607  6.855655       Chess
# 1301  6.928203       Chess
# 1434  6.928203       Chess
# 1307  6.928203       Chess
# ['3d_Printer']
# 3d_Printer Chess
#            dist  label
# 1742  12.409674  Chess
# 1356  12.727922  Chess
# 1549  12.727922  Chess
# 1426  12.845233  Chess
# 1575  13.076697  Chess
# ['Chess']
# Chess Chess
# Chess Chess 37 45
#           dist   label
# 1121  4.690416  Coffee
# 1276  4.795832   Chess
# 1267  4.795832   Chess
# 1296  4.795832   Chess
# 1294  4.795832   Chess
# ['Coffee']
# Coffee Chess
#           dist  label
# 1296  6.708204  Chess
# 1262  6.855655  Chess
# 1278  7.000000  Chess
# 1271  7.000000  Chess
# 1276  7.000000  Chess
# ['Chess']
# Chess Chess
# Chess Chess 38 47
#           dist  label
# 1296  4.582576  Chess
# 1262  4.795832  Chess
# 1299  4.898979  Chess
# 1292  5.000000  Chess
# 1290  5.000000  Chess
# ['Chess']
# Chess Chess
# Chess Chess 39 48
#           dist       label
# 1262  3.162278       Chess
# 1267  3.162278       Chess
# 1334  3.162278       Chess
# 355   3.162278  3d_Printer
# 1271  3.162278       Chess
# ['Chess']
# Chess Chess
# Chess Chess 40 49
#           dist  label
# 1219  6.633250  Chess
# 1450  6.782330  Chess
# 1304  6.855655  Chess
# 1229  6.855655  Chess
# 1312  6.928203  Chess
# ['Chess']
# Chess Chess
# Chess Chess 41 50
#            dist  label
# 1567  31.208973  Chess
# 1257  31.464265  Chess
# 1203  31.480152  Chess
# 1372  31.591138  Chess
# 1368  31.606961  Chess
# ['Chess']
# Chess Chess
# Chess Chess 42 51
#            dist  label
# 1399  15.684387  Chess
# 1248  15.937377  Chess
# 1366  16.000000  Chess
# 1370  16.155494  Chess
# 1322  16.186414  Chess
# ['Chess']
# Chess Chess
# Chess Chess 43 52
#            dist  label
# 1457  45.354162  Chess
# 1388  46.432747  Chess
# 1477  46.561787  Chess
# 1441  46.626173  Chess
# 1162  46.658333  Chess
# ['Chess']
# Chess Chess
# Chess Chess 44 53
#           dist  label
# 1268  8.544004  Chess
# 1524  8.602325  Chess
# 1555  8.660254  Chess
# 1450  8.660254  Chess
# 1495  8.717798  Chess
# ['Chess']
# Chess Chess
# Chess Chess 45 54
#           dist   label
# 750   5.196152  Coffee
# 1548  5.291503   Chess
# 1434  5.291503   Chess
# 749   5.291503  Coffee
# 748   5.291503  Coffee
# ['Coffee']
# Coffee Chess
#           dist       label
# 344   5.000000  3d_Printer
# 1317  5.099020       Chess
# 1379  5.291503       Chess
# 1413  5.385165       Chess
# 1434  5.385165       Chess
# ['3d_Printer']
# 3d_Printer Chess
#            dist  label
# 1299  17.492856  Chess
# 1312  17.492856  Chess
# 1304  17.521415  Chess
# 1229  17.521415  Chess
# 1252  17.521415  Chess
# ['Chess']
# Chess Chess
# Chess Chess 46 57
#           dist  label
# 1603  6.164414  Chess
# 1413  6.324555  Chess
# 1301  6.324555  Chess
# 1754  6.403124  Chess
# 1640  6.403124  Chess
# ['Chess']
# Chess Chess
# Chess Chess 47 58
#            dist       label
# 1720  15.165751       Chess
# 1676  15.362291       Chess
# 1638  15.459625       Chess
# 392   15.524175  3d_Printer
# 391   15.588457  3d_Printer
# ['Chess']
# Chess Chess
# Chess Chess 48 59
#           dist  label
# 1608  7.681146  Chess
# 1434  7.810250  Chess
# 1547  7.810250  Chess
# 1667  7.874008  Chess
# 1599  7.874008  Chess
# ['Chess']
# Chess Chess
# Chess Chess 49 60
# accuray 0.8166666666666667
# Time : 12.950500726699829
#       dist       label
# 396   67.0  3d_Printer
# 205   68.0  3d_Printer
# 1445  68.0       Chess
# 355   68.0  3d_Printer
# 400   69.0  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 1 1
#       dist       label
# 230   59.0  3d_Printer
# 75    59.0  3d_Printer
# 1121  59.0      Coffee
# 27    60.0  3d_Printer
# 4     61.0  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 2 2
#       dist       label
# 27    79.0  3d_Printer
# 1276  79.0       Chess
# 1548  80.0       Chess
# 1121  80.0      Coffee
# 1262  81.0       Chess
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 3 3
#       dist       label
# 344   54.0  3d_Printer
# 1676  55.0       Chess
# 1292  56.0       Chess
# 1532  56.0       Chess
# 1533  56.0       Chess
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 4 4
#       dist       label
# 355   28.0  3d_Printer
# 1548  29.0       Chess
# 290   29.0  3d_Printer
# 1271  30.0       Chess
# 1262  30.0       Chess
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 5 5
#      dist       label
# 205  35.0  3d_Printer
# 261  35.0  3d_Printer
# 398  35.0  3d_Printer
# 355  35.0  3d_Printer
# 400  36.0  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 6 6
#       dist       label
# 35    29.0  3d_Printer
# 1292  30.0       Chess
# 1290  30.0       Chess
# 1278  30.0       Chess
# 1276  30.0       Chess
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 7 7
#       dist       label
# 355   10.0  3d_Printer
# 1294  12.0       Chess
# 1290  12.0       Chess
# 1278  12.0       Chess
# 1334  12.0       Chess
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 8 8
#       dist       label
# 314   91.0  3d_Printer
# 412   97.0  3d_Printer
# 355   98.0  3d_Printer
# 1599  98.0       Chess
# 477   98.0  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 9 9
#       dist       label
# 529   40.0  3d_Printer
# 290   40.0  3d_Printer
# 35    40.0  3d_Printer
# 473   40.0  3d_Printer
# 1490  40.0       Chess
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 10 10
#      dist       label
# 7    23.0  3d_Printer
# 161  24.0  3d_Printer
# 355  24.0  3d_Printer
# 261  24.0  3d_Printer
# 398  24.0  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 11 11
#      dist       label
# 396  58.0  3d_Printer
# 355  59.0  3d_Printer
# 444  59.0  3d_Printer
# 529  60.0  3d_Printer
# 495  60.0  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 12 12
#       dist       label
# 355  103.0  3d_Printer
# 162  103.0  3d_Printer
# 344  103.0  3d_Printer
# 6    103.0  3d_Printer
# 7    104.0  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 13 13
#      dist       label
# 27   85.0  3d_Printer
# 7    86.0  3d_Printer
# 344  87.0  3d_Printer
# 355  87.0  3d_Printer
# 260  88.0  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 14 14
#       dist       label
# 340   90.0  3d_Printer
# 1121  90.0      Coffee
# 529   90.0  3d_Printer
# 4     90.0  3d_Printer
# 230   90.0  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 15 15
#       dist       label
# 1121  53.0      Coffee
# 423   54.0  3d_Printer
# 446   54.0  3d_Printer
# 27    54.0  3d_Printer
# 421   55.0  3d_Printer
# ['Coffee']
# Coffee 3d_Printer
#       dist       label
# 1695  47.0       Chess
# 7     49.0  3d_Printer
# 1294  50.0       Chess
# 1296  50.0       Chess
# 1292  50.0       Chess
# ['Chess']
# Chess 3d_Printer
#       dist  label
# 1269  75.0  Chess
# 1402  76.0  Chess
# 1276  76.0  Chess
# 1271  76.0  Chess
# 1434  76.0  Chess
# ['Chess']
# Chess 3d_Printer
#       dist       label
# 529  115.0  3d_Printer
# 290  115.0  3d_Printer
# 314  117.0  3d_Printer
# 521  117.0  3d_Printer
# 412  117.0  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 16 19
#       dist       label
# 398   29.0  3d_Printer
# 261   29.0  3d_Printer
# 391   30.0  3d_Printer
# 449   30.0  3d_Printer
# 1121  30.0      Coffee
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 17 20
#      dist   label
# 718  73.0  Coffee
# 799  73.0  Coffee
# 853  74.0  Coffee
# 979  76.0  Coffee
# 609  76.0  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 18 21
#        dist   label
# 1121   97.0  Coffee
# 979    99.0  Coffee
# 1096   99.0  Coffee
# 799   100.0  Coffee
# 1097  100.0  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 19 22
#       dist   label
# 799   49.0  Coffee
# 917   50.0  Coffee
# 1121  50.0  Coffee
# 1276  51.0   Chess
# 1278  51.0   Chess
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 20 23
#       dist       label
# 1121  28.0      Coffee
# 344   29.0  3d_Printer
# 1097  29.0      Coffee
# 949   29.0      Coffee
# 750   30.0      Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 21 24
#       dist   label
# 979   32.0  Coffee
# 1271  33.0   Chess
# 1296  33.0   Chess
# 1292  33.0   Chess
# 1290  33.0   Chess
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 22 25
#       dist   label
# 1121  30.0  Coffee
# 609   30.0  Coffee
# 1097  31.0  Coffee
# 799   31.0  Coffee
# 949   31.0  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 23 26
#       dist       label
# 1676  32.0       Chess
# 1334  33.0       Chess
# 1294  33.0       Chess
# 344   33.0  3d_Printer
# 355   33.0  3d_Printer
# ['Chess']
# Chess Coffee
#       dist       label
# 917   16.0      Coffee
# 1121  16.0      Coffee
# 1097  17.0      Coffee
# 355   17.0  3d_Printer
# 949   17.0      Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 24 28
#       dist   label
# 853   46.0  Coffee
# 1121  46.0  Coffee
# 979   46.0  Coffee
# 949   47.0  Coffee
# 799   47.0  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 25 29
#       dist   label
# 979   27.0  Coffee
# 1121  29.0  Coffee
# 1296  30.0   Chess
# 1434  30.0   Chess
# 1267  30.0   Chess
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 26 30
#       dist   label
# 1121  49.0  Coffee
# 970   50.0  Coffee
# 1097  50.0  Coffee
# 1262  50.0   Chess
# 1267  50.0   Chess
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 27 31
#        dist       label
# 799   175.0      Coffee
# 377   180.0  3d_Printer
# 1121  180.0      Coffee
# 609   180.0      Coffee
# 1112  180.0      Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 28 32
#       dist   label
# 799   55.0  Coffee
# 917   56.0  Coffee
# 853   56.0  Coffee
# 1121  56.0  Coffee
# 1334  57.0   Chess
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 29 33
#       dist   label
# 660   72.0  Coffee
# 799   73.0  Coffee
# 1096  74.0  Coffee
# 1121  74.0  Coffee
# 979   74.0  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 30 34
#       dist  label
# 1676  20.0  Chess
# 1267  21.0  Chess
# 1296  21.0  Chess
# 1294  21.0  Chess
# 1292  21.0  Chess
# ['Chess']
# Chess Coffee
#       dist   label
# 1096  26.0  Coffee
# 799   27.0  Coffee
# 1121  28.0  Coffee
# 1097  29.0  Coffee
# 1262  29.0   Chess
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 31 36
#       dist   label
# 799   12.0  Coffee
# 1121  15.0  Coffee
# 609   15.0  Coffee
# 979   15.0  Coffee
# 1096  15.0  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 32 37
#       dist       label
# 1278   7.0       Chess
# 1271   7.0       Chess
# 1290   7.0       Chess
# 355    7.0  3d_Printer
# 1292   7.0       Chess
# ['Chess']
# Chess Coffee
#       dist   label
# 979   39.0  Coffee
# 747   39.0  Coffee
# 1121  39.0  Coffee
# 1271  40.0   Chess
# 1278  40.0   Chess
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 33 39
#       dist   label
# 1121  32.0  Coffee
# 1097  33.0  Coffee
# 949   33.0  Coffee
# 748   33.0  Coffee
# 979   34.0  Coffee
# ['Coffee']
# Coffee Coffee
# Coffee Coffee 34 40
#       dist  label
# 1219  36.0  Chess
# 1313  38.0  Chess
# 1312  38.0  Chess
# 1448  39.0  Chess
# 1450  40.0  Chess
# ['Chess']
# Chess Chess
# Chess Chess 35 41
#        dist  label
# 1219  186.0  Chess
# 1229  187.0  Chess
# 1317  190.0  Chess
# 1434  191.0  Chess
# 1252  191.0  Chess
# ['Chess']
# Chess Chess
# Chess Chess 36 42
#       dist   label
# 1269  12.0   Chess
# 1121  12.0  Coffee
# 1296  13.0   Chess
# 1271  13.0   Chess
# 1276  13.0   Chess
# ['Chess']
# Chess Chess
# Chess Chess 37 43
#       dist       label
# 1301  28.0       Chess
# 344   28.0  3d_Printer
# 1452  29.0       Chess
# 1274  29.0       Chess
# 1269  29.0       Chess
# ['Chess']
# Chess Chess
# Chess Chess 38 44
#       dist       label
# 1754  65.0       Chess
# 1413  66.0       Chess
# 1434  66.0       Chess
# 1301  66.0       Chess
# 344   66.0  3d_Printer
# ['Chess']
# Chess Chess
# Chess Chess 39 45
#       dist   label
# 1121  16.0  Coffee
# 1271  17.0   Chess
# 1296  17.0   Chess
# 1276  17.0   Chess
# 1294  17.0   Chess
# ['Coffee']
# Coffee Chess
#       dist       label
# 1262  35.0       Chess
# 1296  35.0       Chess
# 1290  37.0       Chess
# 27    37.0  3d_Printer
# 1271  37.0       Chess
# ['Chess']
# Chess Chess
# Chess Chess 40 47
#       dist       label
# 1262  14.0       Chess
# 1296  14.0       Chess
# 355   16.0  3d_Printer
# 1267  16.0       Chess
# 1271  16.0       Chess
# ['Chess']
# Chess Chess
# Chess Chess 41 48
#       dist  label
# 1292  10.0  Chess
# 1267  10.0  Chess
# 1296  10.0  Chess
# 1334  10.0  Chess
# 1294  10.0  Chess
# ['Chess']
# Chess Chess
# Chess Chess 42 49
#       dist  label
# 1219  35.0  Chess
# 1450  37.0  Chess
# 1229  38.0  Chess
# 1226  39.0  Chess
# 1312  39.0  Chess
# ['Chess']
# Chess Chess
# Chess Chess 43 50
#        dist  label
# 1389  101.0  Chess
# 1383  102.0  Chess
# 1502  102.0  Chess
# 1741  102.0  Chess
# 1743  103.0  Chess
# ['Chess']
# Chess Chess
# Chess Chess 44 51
#       dist  label
# 1450  77.0  Chess
# 1383  77.0  Chess
# 1608  78.0  Chess
# 1296  78.0  Chess
# 1292  78.0  Chess
# ['Chess']
# Chess Chess
# Chess Chess 45 52
#        dist  label
# 1260  189.0  Chess
# 1408  190.0  Chess
# 1253  190.0  Chess
# 1741  191.0  Chess
# 1390  191.0  Chess
# ['Chess']
# Chess Chess
# Chess Chess 46 53
#       dist  label
# 1269  38.0  Chess
# 1334  39.0  Chess
# 1292  39.0  Chess
# 1290  39.0  Chess
# 1495  39.0  Chess
# ['Chess']
# Chess Chess
# Chess Chess 47 54
#       dist  label
# 1548  22.0  Chess
# 1434  25.0  Chess
# 1267  25.0  Chess
# 1262  25.0  Chess
# 1296  25.0  Chess
# ['Chess']
# Chess Chess
# Chess Chess 48 55
#       dist       label
# 344   18.0  3d_Printer
# 1317  19.0       Chess
# 1413  20.0       Chess
# 1265  21.0       Chess
# 1274  21.0       Chess
# ['3d_Printer']
# 3d_Printer Chess
#        dist  label
# 1699  161.0  Chess
# 1312  163.0  Chess
# 1299  163.0  Chess
# 1229  164.0  Chess
# 1547  164.0  Chess
# ['Chess']
# Chess Chess
# Chess Chess 49 57
#       dist   label
# 1603  26.0   Chess
# 1301  26.0   Chess
# 1413  26.0   Chess
# 1121  27.0  Coffee
# 1265  27.0   Chess
# ['Chess']
# Chess Chess
# Chess Chess 50 58
#       dist   label
# 1555  78.0   Chess
# 1301  83.0   Chess
# 637   83.0  Coffee
# 1290  83.0   Chess
# 1296  83.0   Chess
# ['Chess']
# Chess Chess
# Chess Chess 51 59
#       dist       label
# 1434  43.0       Chess
# 1269  44.0       Chess
# 344   45.0  3d_Printer
# 1474  46.0       Chess
# 1720  46.0       Chess
# ['Chess']
# Chess Chess
# Chess Chess 52 60
# accuray 0.8666666666666667
# Time : 21.18623971939087
#          dist       label
# 235  0.251219  3d_Printer
# 243  0.221500  3d_Printer
# 526  0.204949  3d_Printer
# 189  0.194417  3d_Printer
# 283  0.187959  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 1 1
#          dist       label
# 193  0.450189  3d_Printer
# 194  0.375348  3d_Printer
# 72   0.336178  3d_Printer
# 230  0.315082  3d_Printer
# 262  0.311563  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 2 2
#          dist       label
# 189  0.389045  3d_Printer
# 347  0.268768  3d_Printer
# 345  0.242946  3d_Printer
# 228  0.223566  3d_Printer
# 964  0.212590      Coffee
# ['3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 3 3
#          dist       label
# 407  0.290265  3d_Printer
# 410  0.178981  3d_Printer
# 482  0.177295  3d_Printer
# 288  0.140594  3d_Printer
# 163  0.130658  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 4 4
#          dist       label
# 545  0.199586  3d_Printer
# 283  0.188437  3d_Printer
# 522  0.180854  3d_Printer
# 243  0.180312  3d_Printer
# 529  0.167018  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 5 5
#          dist       label
# 533  0.235332  3d_Printer
# 213  0.207579  3d_Printer
# 535  0.181966  3d_Printer
# 449  0.167248  3d_Printer
# 470  0.165005  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 6 6
#           dist       label
# 1194  0.166884       Chess
# 210   0.131756  3d_Printer
# 533   0.117216  3d_Printer
# 103   0.107335  3d_Printer
# 469   0.100956  3d_Printer
# ['Chess' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 7 7
#          dist       label
# 245  0.275193  3d_Printer
# 2    0.249413  3d_Printer
# 121  0.221179  3d_Printer
# 979  0.195507      Coffee
# 561  0.193531      Coffee
# ['3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 8 8
#          dist       label
# 314  0.427276  3d_Printer
# 412  0.230093  3d_Printer
# 546  0.176580  3d_Printer
# 535  0.172653  3d_Printer
# 528  0.157807  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 9 9
#          dist       label
# 533  0.297332  3d_Printer
# 534  0.274589  3d_Printer
# 316  0.177643  3d_Printer
# 469  0.166993  3d_Printer
# 205  0.166328  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 10 10
#          dist       label
# 190  0.275348  3d_Printer
# 43   0.220444  3d_Printer
# 124  0.208829  3d_Printer
# 7    0.194384  3d_Printer
# 101  0.193611  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 11 11
#          dist       label
# 299  0.353904  3d_Printer
# 316  0.281145  3d_Printer
# 465  0.217098  3d_Printer
# 348  0.190251  3d_Printer
# 352  0.187559  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 12 12
#          dist       label
# 43   0.310494  3d_Printer
# 6    0.259570  3d_Printer
# 55   0.238834  3d_Printer
# 159  0.212163  3d_Printer
# 238  0.210782  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 13 13
#          dist       label
# 260  0.212046  3d_Printer
# 185  0.191611  3d_Printer
# 243  0.187947  3d_Printer
# 235  0.173905  3d_Printer
# 128  0.164339  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 14 14
#          dist       label
# 189  0.312288  3d_Printer
# 228  0.265133  3d_Printer
# 235  0.248335  3d_Printer
# 193  0.233150  3d_Printer
# 230  0.229920  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 15 15
#          dist       label
# 299  0.253677  3d_Printer
# 316  0.209874  3d_Printer
# 225  0.201663  3d_Printer
# 55   0.197029  3d_Printer
# 556  0.189575  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 16 16
#          dist       label
# 412  0.346490  3d_Printer
# 511  0.213581  3d_Printer
# 415  0.194378  3d_Printer
# 265  0.192042  3d_Printer
# 235  0.184175  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 17 17
#          dist       label
# 189  0.185284  3d_Printer
# 157  0.140854  3d_Printer
# 228  0.132303  3d_Printer
# 51   0.131730  3d_Printer
# 3    0.116620  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 18 18
#          dist       label
# 528  0.334717  3d_Printer
# 274  0.308957  3d_Printer
# 317  0.221240  3d_Printer
# 412  0.201253  3d_Printer
# 535  0.196617  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 19 19
#          dist       label
# 316  0.233661  3d_Printer
# 243  0.171200  3d_Printer
# 56   0.169069  3d_Printer
# 235  0.156491  3d_Printer
# 526  0.127173  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 20 20
#           dist   label
# 931   0.353523  Coffee
# 580   0.347184  Coffee
# 1118  0.303571  Coffee
# 842   0.246344  Coffee
# 910   0.224202  Coffee
# ['Coffee' 'Coffee' 'Coffee']
# Coffee Coffee
# Coffee Coffee 21 21
#          dist   label
# 570  0.215172  Coffee
# 739  0.201853  Coffee
# 577  0.167359  Coffee
# 663  0.147380  Coffee
# 726  0.146164  Coffee
# ['Coffee' 'Coffee' 'Coffee']
# Coffee Coffee
# Coffee Coffee 22 22
#           dist   label
# 1080  0.389062  Coffee
# 936   0.277523  Coffee
# 1079  0.244801  Coffee
# 984   0.243945  Coffee
# 578   0.235607  Coffee
# ['Coffee' 'Coffee' 'Coffee']
# Coffee Coffee
# Coffee Coffee 23 23
#          dist   label
# 827  0.191831  Coffee
# 998  0.186666  Coffee
# 994  0.145794  Coffee
# 914  0.138526  Coffee
# 997  0.125319  Coffee
# ['Coffee' 'Coffee' 'Coffee']
# Coffee Coffee
# Coffee Coffee 24 24
#           dist   label
# 943   0.233858  Coffee
# 846   0.217726  Coffee
# 842   0.210026  Coffee
# 979   0.205036  Coffee
# 1142  0.200218  Coffee
# ['Coffee' 'Coffee' 'Coffee']
# Coffee Coffee
# Coffee Coffee 25 25
#           dist   label
# 792   0.224267  Coffee
# 943   0.216632  Coffee
# 996   0.209397  Coffee
# 846   0.207298  Coffee
# 1075  0.205162  Coffee
# ['Coffee' 'Coffee' 'Coffee']
# Coffee Coffee
# Coffee Coffee 26 26
#           dist   label
# 1025  0.295875  Coffee
# 781   0.276026  Coffee
# 1119  0.233282  Coffee
# 1027  0.229625  Coffee
# 910   0.220983  Coffee
# ['Coffee' 'Coffee' 'Coffee']
# Coffee Coffee
# Coffee Coffee 27 27
#           dist   label
# 673   0.375948  Coffee
# 1042  0.304079  Coffee
# 952   0.282586  Coffee
# 871   0.280022  Coffee
# 1123  0.248581  Coffee
# ['Coffee' 'Coffee' 'Coffee']
# Coffee Coffee
# Coffee Coffee 28 28
#           dist   label
# 567   0.308138  Coffee
# 762   0.195739  Coffee
# 1003  0.176915  Coffee
# 1075  0.154831  Coffee
# 645   0.154300  Coffee
# ['Coffee' 'Coffee' 'Coffee']
# Coffee Coffee
# Coffee Coffee 29 29
#           dist   label
# 1151  0.473256  Coffee
# 911   0.382098  Coffee
# 1122  0.317685  Coffee
# 1025  0.310614  Coffee
# 1153  0.298722  Coffee
# ['Coffee' 'Coffee' 'Coffee']
# Coffee Coffee
# Coffee Coffee 30 30
#           dist   label
# 1151  0.457650  Coffee
# 911   0.334649  Coffee
# 781   0.285055  Coffee
# 1153  0.269782  Coffee
# 931   0.154942  Coffee
# ['Coffee' 'Coffee' 'Coffee']
# Coffee Coffee
# Coffee Coffee 31 31
#          dist   label
# 799  0.452848  Coffee
# 595  0.417928  Coffee
# 783  0.343529  Coffee
# 628  0.333755  Coffee
# 927  0.317406  Coffee
# ['Coffee' 'Coffee' 'Coffee']
# Coffee Coffee
# Coffee Coffee 32 32
#           dist   label
# 1042  0.457862  Coffee
# 952   0.425458  Coffee
# 1015  0.404559  Coffee
# 607   0.393113  Coffee
# 716   0.375129  Coffee
# ['Coffee' 'Coffee' 'Coffee']
# Coffee Coffee
# Coffee Coffee 33 33
#           dist   label
# 935   0.406607  Coffee
# 1112  0.243764  Coffee
# 1075  0.236503  Coffee
# 1015  0.203787  Coffee
# 1034  0.196285  Coffee
# ['Coffee' 'Coffee' 'Coffee']
# Coffee Coffee
# Coffee Coffee 34 34
#           dist       label
# 865   0.243921      Coffee
# 616   0.133127      Coffee
# 1618  0.124759       Chess
# 997   0.115838      Coffee
# 252   0.102006  3d_Printer
# ['Coffee' 'Coffee' 'Chess']
# Coffee Coffee
# Coffee Coffee 35 35
#           dist   label
# 1023  0.349805  Coffee
# 732   0.323186  Coffee
# 730   0.234816  Coffee
# 731   0.206124  Coffee
# 801   0.201037  Coffee
# ['Coffee' 'Coffee' 'Coffee']
# Coffee Coffee
# Coffee Coffee 36 36
#           dist   label
# 799   0.349016  Coffee
# 783   0.338125  Coffee
# 1036  0.315282  Coffee
# 628   0.307387  Coffee
# 1094  0.304979  Coffee
# ['Coffee' 'Coffee' 'Coffee']
# Coffee Coffee
# Coffee Coffee 37 37
#           dist   label
# 1058  0.259916  Coffee
# 896   0.236026  Coffee
# 1062  0.235167  Coffee
# 893   0.202317  Coffee
# 1077  0.192934  Coffee
# ['Coffee' 'Coffee' 'Coffee']
# Coffee Coffee
# Coffee Coffee 38 38
#           dist   label
# 747   0.254686  Coffee
# 1061  0.196007  Coffee
# 711   0.158644  Coffee
# 746   0.150841  Coffee
# 578   0.149241  Coffee
# ['Coffee' 'Coffee' 'Coffee']
# Coffee Coffee
# Coffee Coffee 39 39
#           dist   label
# 1086  0.233571  Coffee
# 1058  0.203576  Coffee
# 1077  0.191853  Coffee
# 812   0.188264  Coffee
# 813   0.183790  Coffee
# ['Coffee' 'Coffee' 'Coffee']
# Coffee Coffee
# Coffee Coffee 40 40
#           dist  label
# 1342  0.263922  Chess
# 1219  0.238720  Chess
# 1248  0.230595  Chess
# 1161  0.208461  Chess
# 1313  0.202418  Chess
# ['Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 41 41
#           dist  label
# 1730  0.327128  Chess
# 1632  0.192235  Chess
# 1562  0.169380  Chess
# 1563  0.118922  Chess
# 1254  0.106377  Chess
# ['Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 42 42
#           dist   label
# 1179  0.218397   Chess
# 1727  0.214785   Chess
# 598   0.186606  Coffee
# 1676  0.180811   Chess
# 1170  0.134158   Chess
# ['Chess' 'Chess' 'Coffee']
# Chess Chess
# Chess Chess 43 43
#           dist       label
# 940   0.226753      Coffee
# 6     0.214722  3d_Printer
# 1536  0.167088       Chess
# 1465  0.161649       Chess
# 1551  0.159330       Chess
# ['Coffee' '3d_Printer' 'Chess']
# Coffee Chess
#           dist  label
# 1742  0.319598  Chess
# 1549  0.255359  Chess
# 1426  0.244915  Chess
# 1580  0.240429  Chess
# 1585  0.234955  Chess
# ['Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 44 45
#           dist       label
# 690   0.175449      Coffee
# 1179  0.154608       Chess
# 414   0.137054  3d_Printer
# 1385  0.119298       Chess
# 312   0.112382  3d_Printer
# ['Coffee' 'Chess' '3d_Printer']
# Coffee Chess
#           dist  label
# 1388  0.225627  Chess
# 1251  0.212803  Chess
# 1254  0.206374  Chess
# 1299  0.174271  Chess
# 1300  0.153678  Chess
# ['Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 45 47
#           dist  label
# 1366  0.297613  Chess
# 1295  0.245645  Chess
# 1251  0.240047  Chess
# 1388  0.231359  Chess
# 1299  0.229678  Chess
# ['Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 46 48
#           dist  label
# 1281  0.217085  Chess
# 1577  0.210156  Chess
# 1676  0.167787  Chess
# 1717  0.155428  Chess
# 1228  0.154216  Chess
# ['Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 47 49
#           dist  label
# 1401  0.232531  Chess
# 1558  0.231296  Chess
# 1731  0.217662  Chess
# 1458  0.215491  Chess
# 1219  0.207081  Chess
# ['Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 48 50
#           dist  label
# 1555  0.346006  Chess
# 1257  0.275260  Chess
# 1368  0.262751  Chess
# 1567  0.252366  Chess
# 1740  0.249219  Chess
# ['Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 49 51
#           dist  label
# 1370  0.348681  Chess
# 1388  0.301169  Chess
# 1322  0.293948  Chess
# 1399  0.279941  Chess
# 1477  0.279639  Chess
# ['Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 50 52
#           dist  label
# 1388  0.396585  Chess
# 1399  0.369005  Chess
# 1251  0.366016  Chess
# 1366  0.345311  Chess
# 1322  0.344198  Chess
# ['Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 51 53
#           dist  label
# 1495  0.173128  Chess
# 1368  0.158825  Chess
# 1314  0.158232  Chess
# 1540  0.143982  Chess
# 1353  0.133212  Chess
# ['Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 52 54
#           dist       label
# 442   0.160416  3d_Printer
# 1732  0.132833       Chess
# 1722  0.131499       Chess
# 1638  0.130692       Chess
# 1328  0.127280       Chess
# ['3d_Printer' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 53 55
#           dist  label
# 1455  0.272061  Chess
# 1483  0.252545  Chess
# 1443  0.251767  Chess
# 1317  0.170049  Chess
# 1186  0.163564  Chess
# ['Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 54 56
#           dist  label
# 1563  0.290255  Chess
# 1562  0.286608  Chess
# 1730  0.276452  Chess
# 1746  0.168901  Chess
# 1632  0.154727  Chess
# ['Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 55 57
#           dist  label
# 1603  0.291399  Chess
# 1724  0.198182  Chess
# 1465  0.190993  Chess
# 1640  0.182077  Chess
# 1206  0.165498  Chess
# ['Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 56 58
#           dist       label
# 1676  0.313907       Chess
# 1720  0.289470       Chess
# 1509  0.254787       Chess
# 1332  0.252646       Chess
# 392   0.246508  3d_Printer
# ['Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 57 59
#           dist  label
# 1487  0.296373  Chess
# 1692  0.280553  Chess
# 1465  0.224692  Chess
# 1369  0.224232  Chess
# 1515  0.207613  Chess
# ['Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 58 60
# accuray 0.9666666666666667
# Time : 71.3624677658081
#           dist       label
# 230  12.041595  3d_Printer
# 101  12.041595  3d_Printer
# 189  12.041595  3d_Printer
# 447  12.083046  3d_Printer
# 400  12.124356  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 1 1
#           dist       label
# 193  13.190906  3d_Printer
# 66   13.820275  3d_Printer
# 230  13.892444  3d_Printer
# 228  13.964240  3d_Printer
# 472  14.212670  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 2 2
#            dist       label
# 189   16.583124  3d_Printer
# 230   17.464249  3d_Printer
# 228   17.691806  3d_Printer
# 1599  17.944358       Chess
# 3     18.027756  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 3 3
#           dist   label
# 1526  8.660254   Chess
# 1593  8.717798   Chess
# 616   8.774964  Coffee
# 750   8.888194  Coffee
# 1607  8.888194   Chess
# ['Chess' 'Chess' 'Coffee']
# Chess 3d_Printer
#          dist       label
# 290  7.280110  3d_Printer
# 421  7.416198  3d_Printer
# 529  7.416198  3d_Printer
# 446  7.483315  3d_Printer
# 355  7.483315  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 4 5
#          dist       label
# 261  6.928203  3d_Printer
# 398  6.928203  3d_Printer
# 444  7.071068  3d_Printer
# 394  7.071068  3d_Printer
# 391  7.071068  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 5 6
#           dist   label
# 1555  6.164414   Chess
# ...
# ['3d_Printer' 'Chess' 'Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 37 44
#            dist  label
# 1742  12.409674  Chess
# 1356  12.727922  Chess
# 1549  12.727922  Chess
# 1426  12.845233  Chess
# 1575  13.076697  Chess
# ['Chess' 'Chess' 'Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 38 45
#           dist   label
# 1121  4.690416  Coffee
# 1276  4.795832   Chess
# 1267  4.795832   Chess
# 1296  4.795832   Chess
# 1294  4.795832   Chess
# ['Coffee' 'Chess' 'Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 39 46
#           dist  label
# 1296  6.708204  Chess
# 1262  6.855655  Chess
# 1278  7.000000  Chess
# 1271  7.000000  Chess
# 1276  7.000000  Chess
# ['Chess' 'Chess' 'Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 40 47
#           dist  label
# 1296  4.582576  Chess
# 1262  4.795832  Chess
# 1299  4.898979  Chess
# 1292  5.000000  Chess
# 1290  5.000000  Chess
# ['Chess' 'Chess' 'Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 41 48
#           dist       label
# 1262  3.162278       Chess
# 1267  3.162278       Chess
# 1334  3.162278       Chess
# 355   3.162278  3d_Printer
# 1271  3.162278       Chess
# ['Chess' 'Chess' 'Chess' '3d_Printer' 'Chess']
# Chess Chess
# Chess Chess 42 49
#           dist  label
# 1219  6.633250  Chess
# 1450  6.782330  Chess
# 1304  6.855655  Chess
# 1229  6.855655  Chess
# 1312  6.928203  Chess
# ['Chess' 'Chess' 'Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 43 50
#            dist  label
# 1567  31.208973  Chess
# 1257  31.464265  Chess
# 1203  31.480152  Chess
# 1372  31.591138  Chess
# 1368  31.606961  Chess
# ['Chess' 'Chess' 'Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 44 51
#            dist  label
# 1399  15.684387  Chess
# 1248  15.937377  Chess
# 1366  16.000000  Chess
# 1370  16.155494  Chess
# 1322  16.186414  Chess
# ['Chess' 'Chess' 'Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 45 52
#            dist  label
# 1457  45.354162  Chess
# 1388  46.432747  Chess
# 1477  46.561787  Chess
# 1441  46.626173  Chess
# 1162  46.658333  Chess
# ['Chess' 'Chess' 'Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 46 53
#           dist  label
# 1268  8.544004  Chess
# 1524  8.602325  Chess
# 1555  8.660254  Chess
# 1450  8.660254  Chess
# 1495  8.717798  Chess
# ['Chess' 'Chess' 'Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 47 54
#           dist   label
# 750   5.196152  Coffee
# 1548  5.291503   Chess
# 1434  5.291503   Chess
# 749   5.291503  Coffee
# 748   5.291503  Coffee
# ['Coffee' 'Chess' 'Chess' 'Coffee' 'Coffee']
# Coffee Chess
#           dist       label
# 344   5.000000  3d_Printer
# 1317  5.099020       Chess
# 1379  5.291503       Chess
# 1413  5.385165       Chess
# 1434  5.385165       Chess
# ['3d_Printer' 'Chess' 'Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 48 56
#            dist  label
# 1299  17.492856  Chess
# 1312  17.492856  Chess
# 1304  17.521415  Chess
# 1229  17.521415  Chess
# 1252  17.521415  Chess
# ['Chess' 'Chess' 'Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 49 57
#           dist  label
# 1603  6.164414  Chess
# 1413  6.324555  Chess
# 1301  6.324555  Chess
# 1754  6.403124  Chess
# 1640  6.403124  Chess
# ['Chess' 'Chess' 'Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 50 58
#            dist       label
# 1720  15.165751       Chess
# 1676  15.362291       Chess
# 1638  15.459625       Chess
# 392   15.524175  3d_Printer
# 391   15.588457  3d_Printer
# ['Chess' 'Chess' 'Chess' '3d_Printer' '3d_Printer']
# Chess Chess
# Chess Chess 51 59
#           dist  label
# 1608  7.681146  Chess
# 1434  7.810250  Chess
# 1547  7.810250  Chess
# 1667  7.874008  Chess
# 1599  7.874008  Chess
# ['Chess' 'Chess' 'Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 52 60
# accuray 0.8666666666666667
# Time : 13.108014583587646
#       dist       label
# 396   67.0  3d_Printer
# 205   68.0  3d_Printer
# 1445  68.0       Chess
# 355   68.0  3d_Printer
# 400   69.0  3d_Printer
# ['3d_Printer' '3d_Printer' 'Chess' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 1 1
#       dist       label
# 230   59.0  3d_Printer
# 75    59.0  3d_Printer
# 1121  59.0      Coffee
# 27    60.0  3d_Printer
# 4     61.0  3d_Printer
# ['3d_Printer' '3d_Printer' 'Coffee' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 2 2
#       dist       label
# 27    79.0  3d_Printer
# 1276  79.0       Chess
# 1548  80.0       Chess
# 1121  80.0      Coffee
# 1262  81.0       Chess
# ['3d_Printer' 'Chess' 'Chess' 'Coffee' 'Chess']
# Chess 3d_Printer
#       dist       label
# 344   54.0  3d_Printer
# 1676  55.0       Chess
# 1292  56.0       Chess
# 1532  56.0       Chess
# 1533  56.0       Chess
# ['3d_Printer' 'Chess' 'Chess' 'Chess' 'Chess']
# Chess 3d_Printer
#       dist       label
# 355   28.0  3d_Printer
# 1548  29.0       Chess
# 290   29.0  3d_Printer
# 1271  30.0       Chess
# 1262  30.0       Chess
# ['3d_Printer' 'Chess' '3d_Printer' 'Chess' 'Chess']
# Chess 3d_Printer
#      dist       label
# 205  35.0  3d_Printer
# 261  35.0  3d_Printer
# 398  35.0  3d_Printer
# 355  35.0  3d_Printer
# 400  36.0  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 3 6
#       dist       label
# 35    29.0  3d_Printer
# 1292  30.0       Chess
# 1290  30.0       Chess
# 1278  30.0       Chess
# 1276  30.0       Chess
# ['3d_Printer' 'Chess' 'Chess' 'Chess' 'Chess']
# Chess 3d_Printer
#       dist       label
# 355   10.0  3d_Printer
# 1294  12.0       Chess
# 1290  12.0       Chess
# 1278  12.0       Chess
# 1334  12.0       Chess
# ['3d_Printer' 'Chess' 'Chess' 'Chess' 'Chess']
# Chess 3d_Printer
#       dist       label
# 314   91.0  3d_Printer
# 412   97.0  3d_Printer
# 355   98.0  3d_Printer
# 1599  98.0       Chess
# 477   98.0  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer' 'Chess' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 4 9
#       dist       label
# 529   40.0  3d_Printer
# 290   40.0  3d_Printer
# 35    40.0  3d_Printer
# 473   40.0  3d_Printer
# 1490  40.0       Chess
# ['3d_Printer' '3d_Printer' '3d_Printer' '3d_Printer' 'Chess']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 5 10
#      dist       label
# 7    23.0  3d_Printer
# 161  24.0  3d_Printer
# 355  24.0  3d_Printer
# 261  24.0  3d_Printer
# 398  24.0  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 6 11
#      dist       label
# 396  58.0  3d_Printer
# 355  59.0  3d_Printer
# 444  59.0  3d_Printer
# 529  60.0  3d_Printer
# 495  60.0  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 7 12
#       dist       label
# 355  103.0  3d_Printer
# 162  103.0  3d_Printer
# 344  103.0  3d_Printer
# 6    103.0  3d_Printer
# 7    104.0  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 8 13
#      dist       label
# 27   85.0  3d_Printer
# 7    86.0  3d_Printer
# 344  87.0  3d_Printer
# 355  87.0  3d_Printer
# 260  88.0  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 9 14
#       dist       label
# 340   90.0  3d_Printer
# 1121  90.0      Coffee
# 529   90.0  3d_Printer
# 4     90.0  3d_Printer
# 230   90.0  3d_Printer
# ['3d_Printer' 'Coffee' '3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 10 15
#       dist       label
# 1121  53.0      Coffee
# 423   54.0  3d_Printer
# 446   54.0  3d_Printer
# 27    54.0  3d_Printer
# 421   55.0  3d_Printer
# ['Coffee' '3d_Printer' '3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 11 16
#       dist       label
# 1695  47.0       Chess
# 7     49.0  3d_Printer
# 1294  50.0       Chess
# 1296  50.0       Chess
# 1292  50.0       Chess
# ['Chess' '3d_Printer' 'Chess' 'Chess' 'Chess']
# Chess 3d_Printer
#       dist  label
# 1269  75.0  Chess
# 1402  76.0  Chess
# 1276  76.0  Chess
# 1271  76.0  Chess
# 1434  76.0  Chess
# ['Chess' 'Chess' 'Chess' 'Chess' 'Chess']
# Chess 3d_Printer
#       dist       label
# 529  115.0  3d_Printer
# 290  115.0  3d_Printer
# 314  117.0  3d_Printer
# 521  117.0  3d_Printer
# 412  117.0  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 12 19
#       dist       label
# 398   29.0  3d_Printer
# 261   29.0  3d_Printer
# 391   30.0  3d_Printer
# 449   30.0  3d_Printer
# 1121  30.0      Coffee
# ['3d_Printer' '3d_Printer' '3d_Printer' '3d_Printer' 'Coffee']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 13 20
#      dist   label
# 718  73.0  Coffee
# 799  73.0  Coffee
# 853  74.0  Coffee
# 979  76.0  Coffee
# 609  76.0  Coffee
# ['Coffee' 'Coffee' 'Coffee' 'Coffee' 'Coffee']
# Coffee Coffee
# Coffee Coffee 14 21
#        dist   label
# 1121   97.0  Coffee
# 979    99.0  Coffee
# 1096   99.0  Coffee
# 799   100.0  Coffee
# 1097  100.0  Coffee
# ['Coffee' 'Coffee' 'Coffee' 'Coffee' 'Coffee']
# Coffee Coffee
# Coffee Coffee 15 22
#       dist   label
# 799   49.0  Coffee
# 917   50.0  Coffee
# 1121  50.0  Coffee
# 1276  51.0   Chess
# 1278  51.0   Chess
# ['Coffee' 'Coffee' 'Coffee' 'Chess' 'Chess']
# Coffee Coffee
# Coffee Coffee 16 23
#       dist       label
# 1121  28.0      Coffee
# 344   29.0  3d_Printer
# 1097  29.0      Coffee
# 949   29.0      Coffee
# 750   30.0      Coffee
# ['Coffee' '3d_Printer' 'Coffee' 'Coffee' 'Coffee']
# Coffee Coffee
# Coffee Coffee 17 24
#       dist   label
# 979   32.0  Coffee
# 1271  33.0   Chess
# 1296  33.0   Chess
# 1292  33.0   Chess
# 1290  33.0   Chess
# ['Coffee' 'Chess' 'Chess' 'Chess' 'Chess']
# Chess Coffee
#       dist   label
# 1121  30.0  Coffee
# 609   30.0  Coffee
# 1097  31.0  Coffee
# 799   31.0  Coffee
# 949   31.0  Coffee
# ['Coffee' 'Coffee' 'Coffee' 'Coffee' 'Coffee']
# Coffee Coffee
# Coffee Coffee 18 26
#       dist       label
# 1676  32.0       Chess
# 1334  33.0       Chess
# 1294  33.0       Chess
# 344   33.0  3d_Printer
# 355   33.0  3d_Printer
# ['Chess' 'Chess' 'Chess' '3d_Printer' '3d_Printer']
# Chess Coffee
#       dist       label
# 917   16.0      Coffee
# 1121  16.0      Coffee
# 1097  17.0      Coffee
# 355   17.0  3d_Printer
# 949   17.0      Coffee
# ['Coffee' 'Coffee' 'Coffee' '3d_Printer' 'Coffee']
# Coffee Coffee
# Coffee Coffee 19 28
#       dist   label
# 853   46.0  Coffee
# 1121  46.0  Coffee
# 979   46.0  Coffee
# 949   47.0  Coffee
# 799   47.0  Coffee
# ['Coffee' 'Coffee' 'Coffee' 'Coffee' 'Coffee']
# Coffee Coffee
# Coffee Coffee 20 29
#       dist   label
# 979   27.0  Coffee
# 1121  29.0  Coffee
# 1296  30.0   Chess
# 1434  30.0   Chess
# 1267  30.0   Chess
# ['Coffee' 'Coffee' 'Chess' 'Chess' 'Chess']
# Chess Coffee
#       dist   label
# 1121  49.0  Coffee
# 970   50.0  Coffee
# 1097  50.0  Coffee
# 1262  50.0   Chess
# 1267  50.0   Chess
# ['Coffee' 'Coffee' 'Coffee' 'Chess' 'Chess']
# Coffee Coffee
# Coffee Coffee 21 31
#        dist       label
# 799   175.0      Coffee
# 377   180.0  3d_Printer
# 1121  180.0      Coffee
# 609   180.0      Coffee
# 1112  180.0      Coffee
# ['Coffee' '3d_Printer' 'Coffee' 'Coffee' 'Coffee']
# Coffee Coffee
# Coffee Coffee 22 32
#       dist   label
# 799   55.0  Coffee
# 917   56.0  Coffee
# 853   56.0  Coffee
# 1121  56.0  Coffee
# 1334  57.0   Chess
# ['Coffee' 'Coffee' 'Coffee' 'Coffee' 'Chess']
# Coffee Coffee
# Coffee Coffee 23 33
#       dist   label
# 660   72.0  Coffee
# 799   73.0  Coffee
# 1096  74.0  Coffee
# 1121  74.0  Coffee
# 979   74.0  Coffee
# ['Coffee' 'Coffee' 'Coffee' 'Coffee' 'Coffee']
# Coffee Coffee
# Coffee Coffee 24 34
#       dist  label
# 1676  20.0  Chess
# 1267  21.0  Chess
# 1296  21.0  Chess
# 1294  21.0  Chess
# 1292  21.0  Chess
# ['Chess' 'Chess' 'Chess' 'Chess' 'Chess']
# Chess Coffee
#       dist   label
# 1096  26.0  Coffee
# 799   27.0  Coffee
# 1121  28.0  Coffee
# 1097  29.0  Coffee
# 1262  29.0   Chess
# ['Coffee' 'Coffee' 'Coffee' 'Coffee' 'Chess']
# Coffee Coffee
# Coffee Coffee 25 36
#       dist   label
# 799   12.0  Coffee
# 1121  15.0  Coffee
# 609   15.0  Coffee
# 979   15.0  Coffee
# 1096  15.0  Coffee
# ['Coffee' 'Coffee' 'Coffee' 'Coffee' 'Coffee']
# Coffee Coffee
# Coffee Coffee 26 37
#       dist       label
# 1278   7.0       Chess
# 1271   7.0       Chess
# 1290   7.0       Chess
# 355    7.0  3d_Printer
# 1292   7.0       Chess
# ['Chess' 'Chess' 'Chess' '3d_Printer' 'Chess']
# Chess Coffee
#       dist   label
# 979   39.0  Coffee
# 747   39.0  Coffee
# 1121  39.0  Coffee
# 1271  40.0   Chess
# 1278  40.0   Chess
# ['Coffee' 'Coffee' 'Coffee' 'Chess' 'Chess']
# Coffee Coffee
# Coffee Coffee 27 39
#       dist   label
# 1121  32.0  Coffee
# 1097  33.0  Coffee
# 949   33.0  Coffee
# 748   33.0  Coffee
# 979   34.0  Coffee
# ['Coffee' 'Coffee' 'Coffee' 'Coffee' 'Coffee']
# Coffee Coffee
# Coffee Coffee 28 40
#       dist  label
# 1219  36.0  Chess
# 1313  38.0  Chess
# 1312  38.0  Chess
# 1448  39.0  Chess
# 1450  40.0  Chess
# ['Chess' 'Chess' 'Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 29 41
#        dist  label
# 1219  186.0  Chess
# 1229  187.0  Chess
# 1317  190.0  Chess
# 1434  191.0  Chess
# 1252  191.0  Chess
# ['Chess' 'Chess' 'Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 30 42
#       dist   label
# 1269  12.0   Chess
# 1121  12.0  Coffee
# 1296  13.0   Chess
# 1271  13.0   Chess
# 1276  13.0   Chess
# ['Chess' 'Coffee' 'Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 31 43
#       dist       label
# 1301  28.0       Chess
# 344   28.0  3d_Printer
# 1452  29.0       Chess
# 1274  29.0       Chess
# 1269  29.0       Chess
# ['Chess' '3d_Printer' 'Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 32 44
#       dist       label
# 1754  65.0       Chess
# 1413  66.0       Chess
# 1434  66.0       Chess
# 1301  66.0       Chess
# 344   66.0  3d_Printer
# ['Chess' 'Chess' 'Chess' 'Chess' '3d_Printer']
# Chess Chess
# Chess Chess 33 45
#       dist   label
# 1121  16.0  Coffee
# 1271  17.0   Chess
# 1296  17.0   Chess
# 1276  17.0   Chess
# 1294  17.0   Chess
# ['Coffee' 'Chess' 'Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 34 46
#       dist       label
# 1262  35.0       Chess
# 1296  35.0       Chess
# 1290  37.0       Chess
# 27    37.0  3d_Printer
# 1271  37.0       Chess
# ['Chess' 'Chess' 'Chess' '3d_Printer' 'Chess']
# Chess Chess
# Chess Chess 35 47
#       dist       label
# 1262  14.0       Chess
# 1296  14.0       Chess
# 355   16.0  3d_Printer
# 1267  16.0       Chess
# 1271  16.0       Chess
# ['Chess' 'Chess' '3d_Printer' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 36 48
#       dist  label
# 1292  10.0  Chess
# 1267  10.0  Chess
# 1296  10.0  Chess
# 1334  10.0  Chess
# 1294  10.0  Chess
# ['Chess' 'Chess' 'Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 37 49
#       dist  label
# 1219  35.0  Chess
# 1450  37.0  Chess
# 1229  38.0  Chess
# 1226  39.0  Chess
# 1312  39.0  Chess
# ['Chess' 'Chess' 'Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 38 50
#        dist  label
# 1389  101.0  Chess
# 1383  102.0  Chess
# 1502  102.0  Chess
# 1741  102.0  Chess
# 1743  103.0  Chess
# ['Chess' 'Chess' 'Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 39 51
#       dist  label
# 1450  77.0  Chess
# 1383  77.0  Chess
# 1608  78.0  Chess
# 1296  78.0  Chess
# 1292  78.0  Chess
# ['Chess' 'Chess' 'Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 40 52
#        dist  label
# 1260  189.0  Chess
# 1408  190.0  Chess
# 1253  190.0  Chess
# 1741  191.0  Chess
# 1390  191.0  Chess
# ['Chess' 'Chess' 'Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 41 53
#       dist  label
# 1269  38.0  Chess
# 1334  39.0  Chess
# 1292  39.0  Chess
# 1290  39.0  Chess
# 1495  39.0  Chess
# ['Chess' 'Chess' 'Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 42 54
#       dist  label
# 1548  22.0  Chess
# 1434  25.0  Chess
# 1267  25.0  Chess
# 1262  25.0  Chess
# 1296  25.0  Chess
# ['Chess' 'Chess' 'Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 43 55
#       dist       label
# 344   18.0  3d_Printer
# 1317  19.0       Chess
# 1413  20.0       Chess
# 1265  21.0       Chess
# 1274  21.0       Chess
# ['3d_Printer' 'Chess' 'Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 44 56
#        dist  label
# 1699  161.0  Chess
# 1312  163.0  Chess
# 1299  163.0  Chess
# 1229  164.0  Chess
# 1547  164.0  Chess
# ['Chess' 'Chess' 'Chess' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 45 57
#       dist   label
# 1603  26.0   Chess
# 1301  26.0   Chess
# 1413  26.0   Chess
# 1121  27.0  Coffee
# 1265  27.0   Chess
# ['Chess' 'Chess' 'Chess' 'Coffee' 'Chess']
# Chess Chess
# Chess Chess 46 58
#       dist   label
# 1555  78.0   Chess
# 1301  83.0   Chess
# 637   83.0  Coffee
# 1290  83.0   Chess
# 1296  83.0   Chess
# ['Chess' 'Chess' 'Coffee' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 47 59
#       dist       label
# 1434  43.0       Chess
# 1269  44.0       Chess
# 344   45.0  3d_Printer
# 1474  46.0       Chess
# 1720  46.0       Chess
# ['Chess' 'Chess' '3d_Printer' 'Chess' 'Chess']
# Chess Chess
# Chess Chess 48 60
# accuray 0.8
# Time : 21.148943424224854

# %%
print(acc_log)
# Out:
# ********************************************************************************************
# '3d_Printer','Coffee','Chess'
# stem:none,re:findall,minor_remove:1
# 'no_topic','traindocpertopic','train_doc','testdocpertopic','test_doc','wordmap'
# 3,600,1800,20,60,'11856'
# ********************************************************************************************
# 'k','method','accuracy','time'
# 1,'cos',0.9333333333333333,69.06249451637268
# 1,'euc',0.8166666666666667,12.950500726699829
# 1,'hum',0.8666666666666667,21.18623971939087
# 3,'cos',0.9666666666666667,71.3624677658081
# 3,'euc',0.9166666666666666,13.120611190795898
# 3,'hum',0.8333333333333334,20.8431134223938
# 5,'cos',0.9833333333333333,71.53325533866882
# 5,'euc',0.8666666666666667,13.108014583587646
# 5,'hum',0.8,21.148943424224854

# %%
st='i am hasib 3dprinter 4kjl <p> </pl>'
st=re.sub('<[^<>]+>',' ',st)
s=re.findall('\w+',st)
print(s)

# %%
file=open('Report/backup_exp_mod.txt','a')
file.write(acc_log)
file.close()
print(acc_log)
# Out:
# ********************************************************************************************
# '3d_Printer','Coffee','Chess'
# stem:none,re:findall,minor_remove:1
# 'no_topic','traindocpertopic','train_doc','testdocpertopic','test_doc','wordmap'
# 3,600,1800,60,180,'6840'
# ********************************************************************************************
# 'k','method','accuracy','time'
# 1,'cos',0.9666666666666667,156.64800596237183
# 1,'euc',0.8722222222222222,34.75269603729248
# 1,'hum',0.7611111111111111,46.06392431259155
# 3,'cos',0.9777777777777777,156.8795576095581
# 3,'euc',0.8666666666666667,35.0779230594635
# 3,'hum',0.7722222222222223,47.27083206176758
# 5,'cos',0.9888888888888889,154.8922655582428
# 5,'euc',0.85,34.25516963005066
# 5,'hum',0.7444444444444445,46.71774506568909

# %%
raw='I am hasib\n,i "am" a student() so? @i do& my-duties! porp. and' 
#text=re.sub('\n',' ',raw)
text=raw.lower()
text=re.sub('[^a-z0-9]',' ',text)
#text=re.sub('-',' ',text)
#text=re.sub('[\'"]','',text)
#text=re.sub('[()?.@*#&!,$+]','',text)
#print(text.split(' '))
