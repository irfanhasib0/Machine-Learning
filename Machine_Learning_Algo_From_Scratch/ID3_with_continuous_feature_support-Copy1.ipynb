# %% [markdown]
# ### ID3 Implemented from scratch with python
# ** some basic pandas and nupmpy utility functions are used

# %% [markdown]
# ### Utility functions
# 1. get_possible_labels
# 2. get_target_label_count
# 3. get_most_common
# 4. get_df_with_label

# %%
import pandas as pd
import sys
import numpy as np
import csv
sys.__stdout__=sys.stdout

def get_attr_names(df):
    return list(df.columns.values)

def get_possible_labels(examples,attr_name):     #getting possible labels of a attribute
    attr_column=examples[attr_name]
    labels=[]
    for m in attr_column:
        if m not in labels:
            labels.append(m)
    return(labels)
    #return examples[attr_name].unique()

def get_target_label_counts(target_attr,target_labels): #getting target label counts of a dataset
    counts={}
    for label in target_labels:
        counts[label]=0
    for j in target_attr.index:
            target_val=target_attr[j]
            for label in target_labels:
                if target_val==label:
                    counts[label]=counts[label]+1
    return counts
    #return dict(target_attr.value_counts())
    
def get_most_common(counts):
    most_common=''
    max_count=0
    for kk,vv in counts.items():
        if int(vv)>max_count:
               most_common=kk
               max_count=vv
    return most_common
    
def get_df_with_label(examples,target_attr,attr_name,label):                        
    attr_attr=examples.loc[:,attr_name]                                  
    ret=[]
    for index in attr_attr.index:
        if attr_attr[index]!=label:
            ret.append(index)
    examplesVi=examples.drop(ret,axis=0)
    target_attrVi=target_attr.drop(ret)
    return examplesVi,target_attrVi

# %% [markdown]
# ### Data discretization block
# 1. get_thersholds
# 2. get_best_Split
# 3. relabel attributes
# 4. Discretize

# %%
def get_thrsholds(df,attr_name,target_attr):
        df[target_name]=target_attr
        df_1=df.sort_values(attr_name,axis=0)               #Sorting value
        target_attr_1=df_1[target_name]
        prev_value=target_attr_1[target_attr_1.index.values[0]] #saving first value as previous value
        thrs=[]                                                 #initializing variables
        thrs_val=[]
        summ=[]
        i=0
        #print(df_1)
        for index in (target_attr_1.index):
            thrs.append(index)                                        #saving values until any change in labels
            if target_attr_1.loc[index]!=prev_value and len(thrs)>=2: #Comparing value with previous value
                summ.append(thrs[:-1])                                #Saving the first group
                temp=thrs[-1]
                thrs=[]                                                 
                thrs.append(temp)
                val=df.loc[index,attr_name]                           #getting value of the threshold point 
                if val not in(thrs_val):                              #checking duplicate
                    thrs_val.append(val)                                
                
                prev_value=target_attr_1.loc[index]                   #
        summ.append(thrs)
        return(summ,thrs_val)                                       #returning threshold values and index
                
        #df get_splitted_gain


def best_split(df,attr_name,target_attr,thrs_val):
        df_left=df
        df_right=df
        wg_ent_sum=0
        total_items=(len(df))
        max_gain=0
        best_thr=0
        tg_label_count=get_target_label_counts(target_attr,target_labels)   #getting target labels counts
        ent_s=entropy(tg_label_count)
        print(len(thrs_val))
        if len(thrs_val)>200:
            thrs_val[0]=np.mean(thrs_val)
            thrs_val=thrs_val[:1]
        for val in thrs_val:                                                ####iteration over each threshold value
            df_left=df
            df_right=df
            #val=thrs_val[0]
            #for index,row in df.iterrows():                                 ####spliting for a threshold value
            filt_left=df_left[attr_name]>=val
            filt_right=df_right[attr_name]<val
            df_left=df_left[filt_left]
            df_right=df_right[filt_right]
            df_list=[df_left,df_right]
            wg_ent_sum=0
            for sub_df in df_list:                                          #ierating over splited df
                target_attrVi=sub_df[target_name]
                tg_label_count=get_target_label_counts(target_attrVi,target_labels)
                ent=entropy(tg_label_count)
                no_items=len(target_attrVi)
                wg_ent_sum+=(no_items/total_items)*ent                      ####Getting weighted sum for splited data
            #print(ent_s,wg_ent_sum)
            gain=ent_s-wg_ent_sum                                           ####Getting gain
            if gain>max_gain:
                max_gain=gain
                best_thr=val                                                ####Getting thresh value with max gain
            #print(gain,val,best_thr)
        return best_thr
        
def relabel_attr(df,attr_name,best_thr):                                    
    new_df=[]
    for index,row in df.iterrows():
        #print(df.loc[index,attr_name])
        if (df.loc[index,attr_name]>best_thr):                          #Labeling values greater than threshold with descriptive string
                new_df.append(attr_name+'>='+str(best_thr))
        if (df.loc[index,attr_name]<=best_thr):                         #Labeling values less than threshold with descriptive string
                new_df.append(attr_name+'<'+str(best_thr))
    return new_df

def discretize(df,attr_names,target_attr):
    new_dict={}
    max_label=25
    for attr_name in attr_names:
        lb=get_possible_labels(df,attr_name)
        if(len(lb)>max_label) and df.dtypes[attr_name] !='object':
            print(attr_name)
            summ,thrs_val=get_thrsholds(df,attr_name,target_attr)
            best_thr=best_split(df,attr_name,target_attr,thrs_val)
            new_attr=relabel_attr(df,attr_name,best_thr)
            new_dict[attr_name]=new_attr
        else:
            labels=get_possible_labels(df,attr_name)
            lb_num=len(labels)
            if lb_num<=max_label:
                new_dict[attr_name]=list(df[attr_name])
    #new_dict[target_name]=list(df.loc[:,target_name])
    new_df=pd.DataFrame(new_dict)
    return(new_df)

# %% [markdown]
# ### ID3 Funtions
# 1. Entropy
# 2. Gain
# 3. ID3
# 4. build tree
# 5. predict

# %%
def entropy(counts):
    total=0
    ent=0
    counts=list(counts.values())
    total=np.sum(counts)
    if total==0:
        return ent
    for val in counts:
        p=val/total
        if p!=0:
            ent-=1*p*np.log2(p)
    return ent

def gain(examples,attr_name,target_attr,target_labels):

    tg_label_count=get_target_label_counts(target_attr,target_labels)            #Getting label(+/-/others) count for dataset/subset
    ent_s=entropy(tg_label_count)                                                #Getting entropy for the dataset/subset
    total_items=len(examples)                                                      #getting total items count in attrumn(attribute)
    gain=0
    split_info=0
    labels=get_possible_labels(examples,attr_name)                                  #Getting possible labels for the attribute
    for i in range(len(labels)):
        _,target_attrVi=get_df_with_label(examples,target_attr,attr_name,labels[i]) #extract subset with label given
        tg_label_count=get_target_label_counts(target_attrVi,target_labels)         #Getting label(+/-/others) count for dataset/subset                                                                    #Running iteration over splitted labels

        ent=entropy(tg_label_count)                                                 #Getting entropy of each split
        no_of_items=len(target_attrVi)                                                 #weighted sum of entropies of splits
        ratio=no_of_items/total_items
        gain=gain+ent*(ratio)

        
        if ratio!=0:
            split_info-=(ratio*np.log2(ratio))                           #Getting weighted sum of split info
            
    gain=ent_s-gain                                                                #Getting information gain               
    if split_info!=0:
        gain_ratio=gain/split_info                                          
    #print('Log ....',attr_name,ent_s,gain)
    return split_info,gain





def ID3(examples,target_attr,attr_names):
    global summary,res
    tg_label_count=get_target_label_counts(target_attr,target_labels)              ###Getting target label counts
    total=len(target_attr)
    for label,count in tg_label_count.items():                                     ###Check purity=1 for all target label
        if count==total:
           return label
    most_common=get_most_common(tg_label_count)
    if len(attr_names)==0:                                                          ###Check for empty dataset                  
            return most_common
    max_gain=-1                                                                     ###Getting attribute with highest gain
    attr_name=''
    for i in range(len(attr_names)):                                                 
        _,gain_value= gain(examples,attr_names[i],target_attr,target_labels)
        if gain_value>max_gain:
            max_gain=gain_value
            attr_name=attr_names[i]
    print('attr_name',attr_name)
    labels=get_possible_labels(examples,attr_name)                                      ###Getting possible labels for bes attribute
    print('labels',labels)
    for label in labels:
        examplesVi,target_attrVi=get_df_with_label(examples,target_attr,attr_name,label)###Getting new subset of dataset
        examplesVi=examplesVi.drop(attr_name,axis=1)                            
        res.append(attr_name)                                                           ###returning attr_name,label pair
        res.append(label)
        attr_names=get_attr_names(examplesVi)
        if len(attr_names)==0:# len(target_attrVi)>=2:                                    ###Checking for empty datasets                                                                                         #Getting most common label
            return most_common
        else:
            ret=ID3(examplesVi,target_attrVi,attr_names)                                ###Calling ID3
            if ret !=None:
                res.append(target_name)
                res.append(ret)
                summary.append(res)
                res=[]
    return 


#print('ret',summary)

# %%
def build_tree(summary):
    root=summary[0][0]
    for k in range(len(summary)):
        if summary[k][0]==root:
            temp=summary[k]
        if summary[k][0]!=root:
            #print(temp)
            for t in range(len(temp)):
                if temp[t]==summary[k][0]:
                    temp=temp[:t]
                    break
            summary[k]=temp+summary[k]
        print(summary[k])

def predict(test_df,test_target,summary):
    acc=0
    for kk in range(len(test_df)):
         test=test_df.loc[kk,:]
         #print('..............',kk)
         for i in range(len(summary)):
            m=len(summary[i])                   #Taking a rule
            for j in range(int(m/2)):
                attr=summary[i][2*j]            #Taking a attr
                lb=summary[i][2*j+1]            #Taking corresponding label
                #print('attr',attr,'lb',lb)
                if attr!=target_name:           #last node is not reached
                   if test[attr] != lb:         #Checking test data having same label 
                        break                   #if not break and go for next rule
            if attr == target_name:             #if test data satisfy have all the attr>> label in rule
                pred_label=lb                          #setting result according to rule
                true_label=test_target[kk]
                #print(kk,'rule',i,test_target[kk],'res',res)
                if true_label==pred_label:        #Checking results validity from true label
                    acc=acc+1
                    tp[pred_label]+=1
                #break
                if true_label!=pred_label:
                     tn[pred_label]+=1
                     fp[true_label]+=1
                break                           
            if attr==target_name:
                break
    accuracy=acc/len(test_df)*100
    
    for label in target_labels:
            try:recall[label]=tp[label]/(tp[label]+tn[label])
            except:0
            try:precision[label]=tp[label]/(tp[label]+fp[label])
            except:0
            print(label,'precision',precision[label],'recall',recall[label])
    
    print('Summary : ','correct:',acc, 'total :',len(test_df),'accuracy :',acc/len(test_df)*100,'%')
    return accuracy

# %% [markdown]
# ### Main Loop

# %%
#names=['A','B','C','D','E','F','G','H','I','J']
#df=pd.read_csv('Dataset/iris.csv',delimiter=',' )#,names=names)
df=pd.read_csv('Dataset/titanic.csv',delimiter=',' )#,names=names)
df=df.drop(['Ticket','Cabin'],axis=1)


#df=df.sample(frac=1).reset_index(drop=True)
#print(df.head(10))
#input()
df=df.fillna(df.mean())
#df=df.replace(np.NaN,0)
#df=df.drop('day',axis=1#df=df.drop('Ticket',axis=1)

summary=[]
res=[]
attr_names=get_attr_names(df)
target_name=attr_names[-1]
target_attr=df[target_name]
target_labels=get_possible_labels(df,target_name)

tg_label_count=get_target_label_counts(target_attr,target_labels)
most_common=get_most_common(tg_label_count)

fp={}
tn={}
tp={}
precision={}
recall={}
for label in target_labels:
    fp[label]=0
    tn[label]=0
    tp[label]=0
    recall[label]=0
    precision[label]=0

df=df.drop(target_name,axis=1)
attr_names=attr_names[:-1]
#df=discretize(df,attr_names,target_attr)
for attr in attr_names:
    if df[attr].dtype!=object:
        temp=pd.qcut(df[attr],4,duplicates="drop")
        df[attr]=temp
attr_names=get_attr_names(df)
print(attr_names,target_labels)
print(df.head(100))
input('Press Enter to continue:')
split=int(0.80*len(df))
#split=0
test_df=df.loc[split:,:]
test_target=target_attr.loc[split:]
test_df=test_df.reset_index(drop=True)
test_target=test_target.reset_index(drop=True)
#split=len(df)
df=df.loc[:split,:]
target_attr=target_attr.loc[:split]

#for attr_name in attr_names:
#    split_info,gain_value= gain(df,attr_name,target_attr,target_labels)
#    print(attr_name,split_info)
#    input()

ID3(df,target_attr,attr_names)
build_tree(summary)
accuracy=predict(test_df,test_target,summary)
print(len(summary))
input('Press Enter for reduced error pruning')
accuracy=0
max_i=0
max_acc=0
max_summary=''

for i in range(len(summary)):
        temp_rule=summary[i]
        if (len(summary[i])>4):
            temp=summary[i][-2:]
            summary[i]=summary[i][:-4]
            summary[i]=summary[i]+temp
        print(summary[i])
        if accuracy>=max_acc:
            max_acc=accuracy
            max_summary=summary
            max_i=i
        accuracy=predict(test_df,test_target,summary)
        print(accuracy)
        summary[i]=temp_rule
print('summary',max_summary)
print('i ',max_i)
print('max_accuracy',max_acc)
#i  8
#max_accuracy 66.76300578034682
# Out:
# ['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare'] ['S', 'C', 'Q', nan]
#          Survived        Pclass     Sex             Age          SibSp  \
# 0   (-0.001, 1.0]    (2.0, 3.0]    male   (0.419, 22.0]  (-0.001, 1.0]
# 1   (-0.001, 1.0]  (0.999, 2.0]  female    (35.0, 80.0]  (-0.001, 1.0]
# 2   (-0.001, 1.0]    (2.0, 3.0]  female  (22.0, 29.699]  (-0.001, 1.0]
# 3   (-0.001, 1.0]  (0.999, 2.0]  female  (29.699, 35.0]  (-0.001, 1.0]
# 4   (-0.001, 1.0]    (2.0, 3.0]    male  (29.699, 35.0]  (-0.001, 1.0]
# ..            ...           ...     ...             ...            ...
# 95  (-0.001, 1.0]    (2.0, 3.0]    male  (22.0, 29.699]  (-0.001, 1.0]
# 96  (-0.001, 1.0]  (0.999, 2.0]    male    (35.0, 80.0]  (-0.001, 1.0]
# 97  (-0.001, 1.0]  (0.999, 2.0]    male  (22.0, 29.699]  (-0.001, 1.0]
# 98  (-0.001, 1.0]  (0.999, 2.0]  female  (29.699, 35.0]  (-0.001, 1.0]
# 99  (-0.001, 1.0]  (0.999, 2.0]    male  (29.699, 35.0]  (-0.001, 1.0]
#
#             Parch             Fare
# 0   (-0.001, 6.0]   (-0.001, 7.91]
# 1   (-0.001, 6.0]  (31.0, 512.329]
# 2   (-0.001, 6.0]   (7.91, 14.454]
# 3   (-0.001, 6.0]  (31.0, 512.329]
# 4   (-0.001, 6.0]   (7.91, 14.454]
# ..            ...              ...
# 95  (-0.001, 6.0]   (7.91, 14.454]
# 96  (-0.001, 6.0]  (31.0, 512.329]
# 97  (-0.001, 6.0]  (31.0, 512.329]
# 98  (-0.001, 6.0]   (14.454, 31.0]
# 99  (-0.001, 6.0]   (14.454, 31.0]
#
# [100 rows x 7 columns]
# Press Enter to continue:
# attr_name Fare
# labels [Interval(-0.001, 7.91, closed='right'), Interval(31.0, 512.329, closed='right'), Interval(7.91, 14.454, closed='right'), Interval(14.454, 31.0, closed='right')]
# attr_name Sex
# labels ['male', 'female']
# attr_name Age
# labels [Interval(0.419, 22.0, closed='right'), Interval(22.0, 29.699, closed='right'), Interval(35.0, 80.0, closed='right'), Interval(29.699, 35.0, closed='right')]
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Pclass
# labels [Interval(2.0, 3.0, closed='right')]
# attr_name SibSp
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Pclass
# labels [Interval(2.0, 3.0, closed='right'), Interval(0.999, 2.0, closed='right')]
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name SibSp
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Pclass
# labels [Interval(2.0, 3.0, closed='right'), Interval(0.999, 2.0, closed='right')]
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name SibSp
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Pclass
# labels [Interval(2.0, 3.0, closed='right')]
# attr_name SibSp
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Age
# labels [Interval(0.419, 22.0, closed='right'), Interval(22.0, 29.699, closed='right'), Interval(35.0, 80.0, closed='right'), Interval(29.699, 35.0, closed='right')]
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Pclass
# labels [Interval(2.0, 3.0, closed='right')]
# attr_name SibSp
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Pclass
# labels [Interval(2.0, 3.0, closed='right')]
# attr_name SibSp
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Pclass
# labels [Interval(0.999, 2.0, closed='right'), Interval(2.0, 3.0, closed='right')]
# attr_name SibSp
# labels [Interval(-0.001, 1.0, closed='right'), Interval(1.0, 8.0, closed='right')]
# attr_name Age
# labels [Interval(35.0, 80.0, closed='right'), Interval(29.699, 35.0, closed='right'), Interval(22.0, 29.699, closed='right'), Interval(0.419, 22.0, closed='right')]
# attr_name Sex
# labels ['female', 'male']
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Sex
# labels ['female', 'male']
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Sex
# labels ['male', 'female']
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Sex
# labels ['female', 'male']
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Age
# labels [Interval(0.419, 22.0, closed='right'), Interval(22.0, 29.699, closed='right'), Interval(35.0, 80.0, closed='right'), Interval(29.699, 35.0, closed='right')]
# attr_name Sex
# labels ['male', 'female']
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Sex
# labels ['male', 'female']
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Sex
# labels ['female', 'male']
# attr_name Age
# labels [Interval(22.0, 29.699, closed='right'), Interval(0.419, 22.0, closed='right'), Interval(35.0, 80.0, closed='right'), Interval(29.699, 35.0, closed='right')]
# attr_name Pclass
# labels [Interval(2.0, 3.0, closed='right'), Interval(0.999, 2.0, closed='right')]
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name SibSp
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name SibSp
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name SibSp
# labels [Interval(-0.001, 1.0, closed='right'), Interval(1.0, 8.0, closed='right')]
# attr_name Pclass
# labels [Interval(2.0, 3.0, closed='right'), Interval(0.999, 2.0, closed='right')]
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Pclass
# labels [Interval(2.0, 3.0, closed='right'), Interval(0.999, 2.0, closed='right')]
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name SibSp
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Pclass
# labels [Interval(2.0, 3.0, closed='right'), Interval(0.999, 2.0, closed='right')]
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name SibSp
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Age
# labels [Interval(29.699, 35.0, closed='right'), Interval(22.0, 29.699, closed='right'), Interval(0.419, 22.0, closed='right'), Interval(35.0, 80.0, closed='right')]
# attr_name Pclass
# labels [Interval(2.0, 3.0, closed='right'), Interval(0.999, 2.0, closed='right')]
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name SibSp
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Pclass
# labels [Interval(2.0, 3.0, closed='right'), Interval(0.999, 2.0, closed='right')]
# attr_name SibSp
# labels [Interval(-0.001, 1.0, closed='right'), Interval(1.0, 8.0, closed='right')]
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name SibSp
# labels [Interval(-0.001, 1.0, closed='right'), Interval(1.0, 8.0, closed='right')]
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Pclass
# labels [Interval(2.0, 3.0, closed='right'), Interval(0.999, 2.0, closed='right')]
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name SibSp
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Pclass
# labels [Interval(0.999, 2.0, closed='right'), Interval(2.0, 3.0, closed='right')]
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name SibSp
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Pclass
# labels [Interval(2.0, 3.0, closed='right'), Interval(0.999, 2.0, closed='right')]
# attr_name Age
# labels [Interval(0.419, 22.0, closed='right'), Interval(29.699, 35.0, closed='right'), Interval(22.0, 29.699, closed='right'), Interval(35.0, 80.0, closed='right')]
# attr_name Sex
# labels ['male', 'female']
# attr_name SibSp
# labels [Interval(1.0, 8.0, closed='right'), Interval(-0.001, 1.0, closed='right')]
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name SibSp
# labels [Interval(-0.001, 1.0, closed='right'), Interval(1.0, 8.0, closed='right')]
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Sex
# labels ['female', 'male']
# attr_name SibSp
# labels [Interval(-0.001, 1.0, closed='right'), Interval(1.0, 8.0, closed='right')]
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name SibSp
# labels [Interval(-0.001, 1.0, closed='right'), Interval(1.0, 8.0, closed='right')]
# attr_name Sex
# labels ['male', 'female']
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Sex
# labels ['male', 'female']
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Sex
# labels ['female', 'male']
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name SibSp
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Sex
# labels ['female', 'male']
# attr_name Age
# labels [Interval(0.419, 22.0, closed='right'), Interval(35.0, 80.0, closed='right'), Interval(22.0, 29.699, closed='right'), Interval(29.699, 35.0, closed='right')]
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name SibSp
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name SibSp
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Age
# labels [Interval(29.699, 35.0, closed='right'), Interval(35.0, 80.0, closed='right'), Interval(22.0, 29.699, closed='right'), Interval(0.419, 22.0, closed='right')]
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name SibSp
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name SibSp
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# attr_name Survived
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name SibSp
# labels [Interval(-0.001, 1.0, closed='right')]
# attr_name Parch
# labels [Interval(-0.001, 6.0, closed='right')]
# ['Fare', Interval(-0.001, 7.91, closed='right'), 'Sex', 'male', 'Age', Interval(0.419, 22.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(-0.001, 7.91, closed='right'), 'Sex', 'male', 'Age', Interval(22.0, 29.699, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(-0.001, 7.91, closed='right'), 'Sex', 'male', 'Pclass', Interval(0.999, 2.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(-0.001, 7.91, closed='right'), 'Sex', 'male', 'Age', Interval(35.0, 80.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(-0.001, 7.91, closed='right'), 'Sex', 'male', 'Pclass', Interval(0.999, 2.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(-0.001, 7.91, closed='right'), 'Sex', 'male', 'Age', Interval(29.699, 35.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(-0.001, 7.91, closed='right'), 'Sex', 'female', 'Age', Interval(0.419, 22.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(-0.001, 7.91, closed='right'), 'Age', Interval(22.0, 29.699, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'Q']
# ['Fare', Interval(-0.001, 7.91, closed='right'), 'Age', Interval(35.0, 80.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(-0.001, 7.91, closed='right'), 'Age', Interval(29.699, 35.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(31.0, 512.329, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Age', Interval(35.0, 80.0, closed='right'), 'Sex', 'female', 'Survived', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'C']
# ['Fare', Interval(31.0, 512.329, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Age', Interval(35.0, 80.0, closed='right'), 'Sex', 'male', 'Survived', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(31.0, 512.329, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Age', Interval(29.699, 35.0, closed='right'), 'Sex', 'female', 'Survived', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(31.0, 512.329, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Sex', 'male', 'Embarked', 'S']
# ['Fare', Interval(31.0, 512.329, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Age', Interval(22.0, 29.699, closed='right'), 'Sex', 'male', 'Survived', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'C']
# ['Fare', Interval(31.0, 512.329, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Sex', 'female', 'Survived', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'C']
# ['Fare', Interval(31.0, 512.329, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Age', Interval(0.419, 22.0, closed='right'), 'Sex', 'female', 'Survived', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(31.0, 512.329, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Sex', 'male', 'Survived', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(31.0, 512.329, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'SibSp', Interval(1.0, 8.0, closed='right'), 'Age', Interval(0.419, 22.0, closed='right'), 'Sex', 'male', 'Embarked', 'S']
# ['Fare', Interval(31.0, 512.329, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'Sex', 'female', 'Survived', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(31.0, 512.329, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'Age', Interval(22.0, 29.699, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(31.0, 512.329, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'Age', Interval(35.0, 80.0, closed='right'), 'Sex', 'male', 'Survived', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(31.0, 512.329, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'Sex', 'female', 'Embarked', 'S']
# ['Fare', Interval(31.0, 512.329, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'Age', Interval(29.699, 35.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(31.0, 512.329, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Sex', 'female', 'Age', Interval(22.0, 29.699, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Sex', 'female', 'Age', Interval(22.0, 29.699, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Sex', 'female', 'Age', Interval(0.419, 22.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Sex', 'female', 'Pclass', Interval(0.999, 2.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Sex', 'female', 'SibSp', Interval(1.0, 8.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Sex', 'female', 'Age', Interval(35.0, 80.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Sex', 'female', 'Pclass', Interval(0.999, 2.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Sex', 'female', 'Age', Interval(29.699, 35.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Sex', 'female', 'Pclass', Interval(0.999, 2.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Sex', 'male', 'Age', Interval(29.699, 35.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Age', Interval(22.0, 29.699, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(7.91, 14.454, closed='right'), 'SibSp', Interval(1.0, 8.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(7.91, 14.454, closed='right'), 'SibSp', Interval(1.0, 8.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Age', Interval(0.419, 22.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Age', Interval(35.0, 80.0, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Age', Interval(0.419, 22.0, closed='right'), 'Sex', 'male', 'SibSp', Interval(1.0, 8.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Age', Interval(0.419, 22.0, closed='right'), 'Sex', 'male', 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Age', Interval(0.419, 22.0, closed='right'), 'Sex', 'female', 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Age', Interval(0.419, 22.0, closed='right'), 'SibSp', Interval(1.0, 8.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Age', Interval(29.699, 35.0, closed='right'), 'Sex', 'female', 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'SibSp', Interval(1.0, 8.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Sex', 'male', 'Embarked', 'S']
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Age', Interval(22.0, 29.699, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Sex', 'male', 'Survived', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Sex', 'female', 'Survived', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'SibSp', Interval(1.0, 8.0, closed='right'), 'Sex', 'male', 'Survived', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Sex', 'female', 'Survived', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Age', Interval(35.0, 80.0, closed='right'), 'Sex', 'female', 'Embarked', 'S']
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Sex', 'male', 'Survived', Interval(-0.001, 1.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'Sex', 'female', 'Age', Interval(0.419, 22.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Age', Interval(35.0, 80.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Age', Interval(22.0, 29.699, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Age', Interval(29.699, 35.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Sex', 'male', 'Age', Interval(29.699, 35.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Age', Interval(35.0, 80.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Age', Interval(22.0, 29.699, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S']
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Age', Interval(0.419, 22.0, closed='right'), 'Embarked', 'S']
# S precision 0.9185185185185185 recall 0.7654320987654321
# C precision 0.13333333333333333 recall 0.25
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 65
# Press Enter for reduced error pruning
# ['Fare', Interval(-0.001, 7.91, closed='right'), 'Sex', 'male', 'Age', Interval(0.419, 22.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.9185185185185185 recall 0.7654320987654321
# C precision 0.13333333333333333 recall 0.25
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(-0.001, 7.91, closed='right'), 'Sex', 'male', 'Age', Interval(22.0, 29.699, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.9185185185185185 recall 0.7654320987654321
# C precision 0.13333333333333333 recall 0.25
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(-0.001, 7.91, closed='right'), 'Sex', 'male', 'Embarked', 'S']
# S precision 0.9185185185185185 recall 0.7654320987654321
# C precision 0.13333333333333333 recall 0.25
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(-0.001, 7.91, closed='right'), 'Sex', 'male', 'Age', Interval(35.0, 80.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.9185185185185185 recall 0.7654320987654321
# C precision 0.13333333333333333 recall 0.25
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(-0.001, 7.91, closed='right'), 'Sex', 'male', 'Embarked', 'S']
# S precision 0.9185185185185185 recall 0.7654320987654321
# C precision 0.13333333333333333 recall 0.25
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(-0.001, 7.91, closed='right'), 'Sex', 'male', 'Age', Interval(29.699, 35.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.9185185185185185 recall 0.7654320987654321
# C precision 0.13333333333333333 recall 0.25
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(-0.001, 7.91, closed='right'), 'Sex', 'female', 'Age', Interval(0.419, 22.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.9185185185185185 recall 0.7654320987654321
# C precision 0.13333333333333333 recall 0.25
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(-0.001, 7.91, closed='right'), 'Age', Interval(22.0, 29.699, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'Q']
# S precision 0.9185185185185185 recall 0.7654320987654321
# C precision 0.13333333333333333 recall 0.25
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(-0.001, 7.91, closed='right'), 'Embarked', 'S']
# S precision 0.9185185185185185 recall 0.7654320987654321
# C precision 0.13333333333333333 recall 0.25
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(-0.001, 7.91, closed='right'), 'Embarked', 'S']
# S precision 0.9185185185185185 recall 0.7654320987654321
# C precision 0.13333333333333333 recall 0.25
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(31.0, 512.329, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Age', Interval(35.0, 80.0, closed='right'), 'Sex', 'female', 'Survived', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'C']
# S precision 0.9185185185185185 recall 0.7654320987654321
# C precision 0.13333333333333333 recall 0.25
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(31.0, 512.329, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Age', Interval(35.0, 80.0, closed='right'), 'Sex', 'male', 'Survived', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.9185185185185185 recall 0.7654320987654321
# C precision 0.13333333333333333 recall 0.25
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(31.0, 512.329, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Age', Interval(29.699, 35.0, closed='right'), 'Sex', 'female', 'Survived', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.9185185185185185 recall 0.7654320987654321
# C precision 0.13333333333333333 recall 0.25
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(31.0, 512.329, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.9204938271604939 recall 0.7655030800821355
# C precision 0.13111111111111112 recall 0.251063829787234
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 132 total : 179 accuracy : 73.74301675977654 %
# 73.74301675977654
# ['Fare', Interval(31.0, 512.329, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Age', Interval(22.0, 29.699, closed='right'), 'Sex', 'male', 'Survived', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'C']
# S precision 0.9203703703703704 recall 0.7654986522911051
# C precision 0.13125 recall 0.250996015936255
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(31.0, 512.329, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Sex', 'female', 'Survived', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'C']
# S precision 0.9202614379084967 recall 0.765494744472635
# C precision 0.13137254901960785 recall 0.250936329588015
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(31.0, 512.329, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Age', Interval(0.419, 22.0, closed='right'), 'Sex', 'female', 'Survived', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.920164609053498 recall 0.765491270112975
# C precision 0.13148148148148148 recall 0.2508833922261484
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(31.0, 512.329, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Sex', 'male', 'Survived', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.9200779727095516 recall 0.7654881608822576
# C precision 0.13157894736842105 recall 0.2508361204013378
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(31.0, 512.329, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'SibSp', Interval(1.0, 8.0, closed='right'), 'Age', Interval(0.419, 22.0, closed='right'), 'Embarked', 'S']
# S precision 0.92 recall 0.7654853620955316
# C precision 0.13166666666666665 recall 0.2507936507936508
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(31.0, 512.329, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'Sex', 'female', 'Survived', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.9199294532627866 recall 0.7654828294687408
# C precision 0.13174603174603175 recall 0.25075528700906347
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(31.0, 512.329, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'Embarked', 'S']
# S precision 0.9198653198653198 recall 0.7654805267581956
# C precision 0.1318181818181818 recall 0.2507204610951009
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(31.0, 512.329, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'Age', Interval(35.0, 80.0, closed='right'), 'Sex', 'male', 'Survived', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.9198067632850242 recall 0.7654784240150094
# C precision 0.1318840579710145 recall 0.25068870523415976
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(31.0, 512.329, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'Embarked', 'S']
# S precision 0.9197530864197531 recall 0.7654764962753661
# C precision 0.13194444444444445 recall 0.25065963060686014
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(31.0, 512.329, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'Embarked', 'S']
# S precision 0.9197037037037037 recall 0.7654747225647349
# C precision 0.132 recall 0.25063291139240507
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(31.0, 512.329, closed='right'), 'Embarked', 'S']
# S precision 0.9196581196581196 recall 0.7654730851316102
# C precision 0.13205128205128205 recall 0.25060827250608275
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Sex', 'female', 'Age', Interval(22.0, 29.699, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.9196159122085048 recall 0.7654715688513359
# C precision 0.13209876543209875 recall 0.2505854800936768
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Sex', 'female', 'Age', Interval(22.0, 29.699, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.9195767195767196 recall 0.7654701607575424
# C precision 0.13214285714285715 recall 0.2505643340857788
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Sex', 'female', 'Age', Interval(0.419, 22.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.9195402298850575 recall 0.7654688496704232
# C precision 0.13218390804597702 recall 0.25054466230936817
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Sex', 'female', 'Pclass', Interval(0.999, 2.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.9195061728395062 recall 0.7654676258992805
# C precision 0.1322222222222222 recall 0.2505263157894737
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Sex', 'female', 'Embarked', 'S']
# S precision 0.9194743130227001 recall 0.7654664810025861
# C precision 0.13225806451612904 recall 0.2505091649694501
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Sex', 'female', 'Age', Interval(35.0, 80.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.9194444444444444 recall 0.7654654075929852
# C precision 0.13229166666666667 recall 0.2504930966469428
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Sex', 'female', 'Embarked', 'S']
# S precision 0.9194163860830528 recall 0.7654643991777238
# C precision 0.13232323232323231 recall 0.25047801147227533
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Sex', 'female', 'Age', Interval(29.699, 35.0, closed='right'), 'Embarked', 'S']
# S precision 0.9193899782135077 recall 0.7654634500272084
# C precision 0.1323529411764706 recall 0.2504638218923933
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Sex', 'female', 'Pclass', Interval(0.999, 2.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.9193650793650794 recall 0.7654625550660793
# C precision 0.13238095238095238 recall 0.25045045045045045
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Sex', 'male', 'Age', Interval(29.699, 35.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.9193415637860082 recall 0.7654617097824225
# C precision 0.13240740740740742 recall 0.2504378283712785
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Embarked', 'S']
# S precision 0.9193193193193193 recall 0.7654609101516919
# C precision 0.13243243243243244 recall 0.2504258943781942
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Age', Interval(22.0, 29.699, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.9192982456140351 recall 0.7654601525726343
# C precision 0.1324561403508772 recall 0.2504145936981758
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Embarked', 'S']
# S precision 0.9192782526115859 recall 0.7654594338130635
# C precision 0.13247863247863248 recall 0.25040387722132473
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.9192592592592592 recall 0.7654587509637625
# C precision 0.1325 recall 0.2503937007874016
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Embarked', 'S']
# S precision 0.9192411924119241 recall 0.7654581013991274
# C precision 0.13252032520325202 recall 0.250384024577573
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Age', Interval(0.419, 22.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.9192239858906526 recall 0.7654574827434278
# C precision 0.13253968253968254 recall 0.25037481259370314
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Embarked', 'S']
# S precision 0.919207579672696 recall 0.7654568928417731
# C precision 0.1325581395348837 recall 0.25036603221083453
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Age', Interval(35.0, 80.0, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.9191919191919192 recall 0.7654563297350343
# C precision 0.13257575757575757 recall 0.2503576537911302
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(7.91, 14.454, closed='right'), 'Embarked', 'S']
# S precision 0.9191769547325103 recall 0.7654557916381083
# C precision 0.1325925925925926 recall 0.25034965034965034
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Age', Interval(0.419, 22.0, closed='right'), 'Sex', 'male', 'SibSp', Interval(1.0, 8.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.9191626409017714 recall 0.7654552769210138
# C precision 0.13260869565217392 recall 0.2503419972640219
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Age', Interval(0.419, 22.0, closed='right'), 'Sex', 'male', 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.9191489361702128 recall 0.7654547840924005
# C precision 0.1326241134751773 recall 0.250334672021419
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Age', Interval(0.419, 22.0, closed='right'), 'Sex', 'female', 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.9191358024691358 recall 0.7654543117851176
# C precision 0.1326388888888889 recall 0.2503276539973788
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Age', Interval(0.419, 22.0, closed='right'), 'SibSp', Interval(1.0, 8.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.9191232048374905 recall 0.7654538587435478
# C precision 0.1326530612244898 recall 0.2503209242618742
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Age', Interval(29.699, 35.0, closed='right'), 'Sex', 'female', 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.9191111111111111 recall 0.7654534238124614
# C precision 0.13266666666666665 recall 0.25031446540880503
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Embarked', 'S']
# S precision 0.9190994916485112 recall 0.7654530059271804
# C precision 0.1326797385620915 recall 0.25030826140567203
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Embarked', 'S']
# S precision 0.9190883190883191 recall 0.765452604104876
# C precision 0.1326923076923077 recall 0.2503022974607013
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Age', Interval(22.0, 29.699, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Sex', 'male', 'Survived', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.919077568134172 recall 0.7654522174368525
# C precision 0.13270440251572327 recall 0.25029655990510086
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Sex', 'female', 'Survived', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.9190672153635117 recall 0.7654518450816863
# C precision 0.13271604938271606 recall 0.25029103608847497
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'SibSp', Interval(1.0, 8.0, closed='right'), 'Sex', 'male', 'Survived', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.919057239057239 recall 0.7654514862591139
# C precision 0.13272727272727272 recall 0.2502857142857143
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Sex', 'female', 'Survived', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.919047619047619 recall 0.7654511402445742
# C precision 0.13273809523809524 recall 0.250280583613917
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Age', Interval(35.0, 80.0, closed='right'), 'Embarked', 'S']
# S precision 0.9190383365821962 recall 0.7654508063643252
# C precision 0.1327485380116959 recall 0.25027563395810365
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Sex', 'male', 'Survived', Interval(-0.001, 1.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.919029374201788 recall 0.7654504839910647
# C precision 0.13275862068965516 recall 0.2502708559046587
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'Sex', 'female', 'Age', Interval(0.419, 22.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.9190207156308852 recall 0.7654501725399979
# C precision 0.1327683615819209 recall 0.25026624068157616
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Age', Interval(35.0, 80.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.9190123456790124 recall 0.7654498714652956
# C precision 0.13277777777777777 recall 0.25026178010471206
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Embarked', 'S']
# S precision 0.9190042501517911 recall 0.765449580256903
# C precision 0.13278688524590163 recall 0.25025746652935116
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Embarked', 'S']
# S precision 0.9189964157706093 recall 0.7654492984376555
# C precision 0.13279569892473117 recall 0.2502532928064843
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Sex', 'male', 'Age', Interval(29.699, 35.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.9189888300999413 recall 0.7654490255606698
# C precision 0.1328042328042328 recall 0.2502492522432702
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Age', Interval(35.0, 80.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.9189814814814815 recall 0.7654487612069797
# C precision 0.1328125 recall 0.25024533856722275
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Age', Interval(22.0, 29.699, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Embarked', 'S']
# S precision 0.918974358974359 recall 0.7654485049833887
# C precision 0.13282051282051283 recall 0.25024154589371983
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# ['Fare', Interval(14.454, 31.0, closed='right'), 'Embarked', 'S']
# S precision 0.9189674523007856 recall 0.7654482565205197
# C precision 0.13282828282828282 recall 0.25023786869647957
# Q precision 0.07692307692307693 recall 1.0
# nan precision 0.0 recall 0
# Summary :  correct: 129 total : 179 accuracy : 72.06703910614524 %
# 72.06703910614524
# summary [['Fare', Interval(-0.001, 7.91, closed='right'), 'Sex', 'male', 'Age', Interval(0.419, 22.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S'], ['Fare', Interval(-0.001, 7.91, closed='right'), 'Sex', 'male', 'Age', Interval(22.0, 29.699, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S'], ['Fare', Interval(-0.001, 7.91, closed='right'), 'Sex', 'male', 'Pclass', Interval(0.999, 2.0, closed='right'), 'Embarked', 'S'], ['Fare', Interval(-0.001, 7.91, closed='right'), 'Sex', 'male', 'Age', Interval(35.0, 80.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S'], ['Fare', Interval(-0.001, 7.91, closed='right'), 'Sex', 'male', 'Pclass', Interval(0.999, 2.0, closed='right'), 'Embarked', 'S'], ['Fare', Interval(-0.001, 7.91, closed='right'), 'Sex', 'male', 'Age', Interval(29.699, 35.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S'], ['Fare', Interval(-0.001, 7.91, closed='right'), 'Sex', 'female', 'Age', Interval(0.419, 22.0, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S'], ['Fare', Interval(-0.001, 7.91, closed='right'), 'Age', Interval(22.0, 29.699, closed='right'), 'Survived', Interval(-0.001, 1.0, closed='right'), 'Pclass', Interval(2.0, 3.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'Q'], ['Fare', Interval(-0.001, 7.91, closed='right'), 'Age', Interval(35.0, 80.0, closed='right'), 'Embarked', 'S'], ['Fare', Interval(-0.001, 7.91, closed='right'), 'Age', Interval(29.699, 35.0, closed='right'), 'Embarked', 'S'], ['Fare', Interval(31.0, 512.329, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Age', Interval(35.0, 80.0, closed='right'), 'Sex', 'female', 'Survived', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'C'], ['Fare', Interval(31.0, 512.329, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Age', Interval(35.0, 80.0, closed='right'), 'Sex', 'male', 'Survived', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S'], ['Fare', Interval(31.0, 512.329, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Age', Interval(29.699, 35.0, closed='right'), 'Sex', 'female', 'Survived', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'S'], ['Fare', Interval(31.0, 512.329, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Sex', 'male', 'Embarked', 'S'], ['Fare', Interval(31.0, 512.329, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'SibSp', Interval(-0.001, 1.0, closed='right'), 'Age', Interval(22.0, 29.699, closed='right'), 'Sex', 'male', 'Survived', Interval(-0.001, 1.0, closed='right'), 'Parch', Interval(-0.001, 6.0, closed='right'), 'Embarked', 'C'], ['Fare', Interval(31.0, 512.329, closed='right'), 'Pclass', Interval(0.999, 2.0, closed='right'), 'SibSp', Inte ...
# i  14
# max_accuracy 73.74301675977654

# %%
for node in summary:
    for edge in node:
        print(edge,end=' ')
    print('')
# Out:
# Fare (-0.001, 7.91] Sex male Age (0.419, 22.0] Survived (-0.001, 1.0] Pclass (2.0, 3.0] SibSp (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (-0.001, 7.91] Sex male Age (22.0, 29.699] Pclass (2.0, 3.0] Survived (-0.001, 1.0] SibSp (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (-0.001, 7.91] Sex male Pclass (0.999, 2.0] Embarked S
# Fare (-0.001, 7.91] Sex male Age (35.0, 80.0] Pclass (2.0, 3.0] Survived (-0.001, 1.0] SibSp (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (-0.001, 7.91] Sex male Pclass (0.999, 2.0] Embarked S
# Fare (-0.001, 7.91] Sex male Age (29.699, 35.0] Survived (-0.001, 1.0] Pclass (2.0, 3.0] SibSp (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (-0.001, 7.91] Sex female Age (0.419, 22.0] Survived (-0.001, 1.0] Pclass (2.0, 3.0] SibSp (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (-0.001, 7.91] Age (22.0, 29.699] Survived (-0.001, 1.0] Pclass (2.0, 3.0] SibSp (-0.001, 1.0] Parch (-0.001, 6.0] Embarked Q
# Fare (-0.001, 7.91] Age (35.0, 80.0] Embarked S
# Fare (-0.001, 7.91] Age (29.699, 35.0] Embarked S
# Fare (31.0, 512.329] Pclass (0.999, 2.0] SibSp (-0.001, 1.0] Age (35.0, 80.0] Sex female Survived (-0.001, 1.0] Parch (-0.001, 6.0] Embarked C
# Fare (31.0, 512.329] Pclass (0.999, 2.0] SibSp (-0.001, 1.0] Age (35.0, 80.0] Sex male Survived (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (31.0, 512.329] Pclass (0.999, 2.0] SibSp (-0.001, 1.0] Age (29.699, 35.0] Sex female Survived (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (31.0, 512.329] Pclass (0.999, 2.0] SibSp (-0.001, 1.0] Sex male Embarked S
# Fare (31.0, 512.329] Pclass (0.999, 2.0] SibSp (-0.001, 1.0] Age (22.0, 29.699] Sex male Survived (-0.001, 1.0] Parch (-0.001, 6.0] Embarked C
# Fare (31.0, 512.329] Pclass (0.999, 2.0] SibSp (-0.001, 1.0] Sex female Survived (-0.001, 1.0] Parch (-0.001, 6.0] Embarked C
# Fare (31.0, 512.329] Pclass (0.999, 2.0] SibSp (-0.001, 1.0] Age (0.419, 22.0] Sex female Survived (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (31.0, 512.329] Pclass (0.999, 2.0] SibSp (-0.001, 1.0] Sex male Survived (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (31.0, 512.329] Pclass (0.999, 2.0] SibSp (1.0, 8.0] Age (0.419, 22.0] Sex male Embarked S
# Fare (31.0, 512.329] Pclass (0.999, 2.0] Sex female Survived (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (31.0, 512.329] Pclass (0.999, 2.0] Age (22.0, 29.699] Embarked S
# Fare (31.0, 512.329] Pclass (0.999, 2.0] Age (35.0, 80.0] Sex male Survived (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (31.0, 512.329] Pclass (0.999, 2.0] Sex female Embarked S
# Fare (31.0, 512.329] Pclass (0.999, 2.0] Age (29.699, 35.0] Embarked S
# Fare (31.0, 512.329] Pclass (2.0, 3.0] Embarked S
# Fare (7.91, 14.454] Sex female Age (22.0, 29.699] Pclass (2.0, 3.0] Survived (-0.001, 1.0] SibSp (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (7.91, 14.454] Sex female Age (22.0, 29.699] Pclass (0.999, 2.0] Survived (-0.001, 1.0] SibSp (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (7.91, 14.454] Sex female Age (0.419, 22.0] SibSp (-0.001, 1.0] Pclass (2.0, 3.0] Survived (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (7.91, 14.454] Sex female Pclass (0.999, 2.0] Survived (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (7.91, 14.454] Sex female SibSp (1.0, 8.0] Embarked S
# Fare (7.91, 14.454] Sex female Age (35.0, 80.0] Pclass (2.0, 3.0] Survived (-0.001, 1.0] SibSp (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (7.91, 14.454] Sex female Pclass (0.999, 2.0] Embarked S
# Fare (7.91, 14.454] Sex female Age (29.699, 35.0] Pclass (2.0, 3.0] Embarked S
# Fare (7.91, 14.454] Sex female Pclass (0.999, 2.0] Survived (-0.001, 1.0] SibSp (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (7.91, 14.454] Sex male Age (29.699, 35.0] Pclass (2.0, 3.0] Survived (-0.001, 1.0] SibSp (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (7.91, 14.454] Pclass (0.999, 2.0] Embarked S
# Fare (7.91, 14.454] Age (22.0, 29.699] Pclass (2.0, 3.0] SibSp (-0.001, 1.0] Survived (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (7.91, 14.454] SibSp (1.0, 8.0] Embarked S
# Fare (7.91, 14.454] Pclass (0.999, 2.0] SibSp (-0.001, 1.0] Survived (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (7.91, 14.454] SibSp (1.0, 8.0] Embarked S
# Fare (7.91, 14.454] Age (0.419, 22.0] Pclass (2.0, 3.0] Survived (-0.001, 1.0] SibSp (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (7.91, 14.454] Pclass (0.999, 2.0] Embarked S
# Fare (7.91, 14.454] Age (35.0, 80.0] Pclass (0.999, 2.0] Survived (-0.001, 1.0] SibSp (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (7.91, 14.454] Pclass (2.0, 3.0] Embarked S
# Fare (14.454, 31.0] Pclass (2.0, 3.0] Age (0.419, 22.0] Sex male SibSp (1.0, 8.0] Survived (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (14.454, 31.0] Pclass (2.0, 3.0] Age (0.419, 22.0] Sex male SibSp (-0.001, 1.0] Survived (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (14.454, 31.0] Pclass (2.0, 3.0] Age (0.419, 22.0] Sex female SibSp (-0.001, 1.0] Survived (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (14.454, 31.0] Pclass (2.0, 3.0] Age (0.419, 22.0] SibSp (1.0, 8.0] Survived (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (14.454, 31.0] Pclass (2.0, 3.0] Age (29.699, 35.0] Sex female SibSp (-0.001, 1.0] Survived (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (14.454, 31.0] Pclass (2.0, 3.0] SibSp (1.0, 8.0] Embarked S
# Fare (14.454, 31.0] Pclass (2.0, 3.0] Sex male Embarked S
# Fare (14.454, 31.0] Pclass (2.0, 3.0] Age (22.0, 29.699] SibSp (-0.001, 1.0] Sex male Survived (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (14.454, 31.0] Pclass (2.0, 3.0] Sex female Survived (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (14.454, 31.0] Pclass (2.0, 3.0] SibSp (1.0, 8.0] Sex male Survived (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (14.454, 31.0] Pclass (2.0, 3.0] Sex female Survived (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (14.454, 31.0] Pclass (2.0, 3.0] Age (35.0, 80.0] Sex female Embarked S
# Fare (14.454, 31.0] Pclass (2.0, 3.0] Sex male Survived (-0.001, 1.0] SibSp (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (14.454, 31.0] Pclass (0.999, 2.0] Sex female Age (0.419, 22.0] Survived (-0.001, 1.0] SibSp (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (14.454, 31.0] Age (35.0, 80.0] Survived (-0.001, 1.0] SibSp (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (14.454, 31.0] Age (22.0, 29.699] Embarked S
# Fare (14.454, 31.0] Age (29.699, 35.0] Embarked S
# Fare (14.454, 31.0] Sex male Age (29.699, 35.0] Survived (-0.001, 1.0] SibSp (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (14.454, 31.0] Age (35.0, 80.0] Survived (-0.001, 1.0] SibSp (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (14.454, 31.0] Age (22.0, 29.699] Survived (-0.001, 1.0] SibSp (-0.001, 1.0] Parch (-0.001, 6.0] Embarked S
# Fare (14.454, 31.0] Age (0.419, 22.0] Embarked S
