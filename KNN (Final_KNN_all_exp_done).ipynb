# %%
from xml.dom import minidom
import re
import pandas as pd
import sys
import pickle
import numpy as np
import time
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
ps = PorterStemmer()
sys.__stdout__=sys.stdout

# %%
f=open('Stopwords.txt')
s_words=f.read()
s_words=s_words.split('\n')
s_words.append('')

pickle_read = open("wordmap_all_600.pickle","rb")
all_words=pickle.load(pickle_read)
pickle_read.close()
all_words=list(all_words.keys())

f=open('verbs.txt','r')
verbs=f.read()
f.close()
verbs=verbs.split('\n')

irr=pd.read_csv('irr_verbs.txt',delimiter=',',names=['root','past','past_par'])
verb_root=list(irr['root'])
past=list(irr['past'])
past_pp=list(irr['past_par'])


def stem_regular_verb(word):
    if len(word)<=3:
        return word
    if word[-2:]=='es':
        if word[:-2] in verbs:
            word=word[:-2]
        elif word[:-2] in all_words:
            word=word[:-2]
    
    elif word[-1:]=='s':
        if word[:-1] in verbs:
            word=word[:-1]
        elif word[:-1] in all_words:
            word=word[:-1]
    
    elif word[-3:]=='ing':
        if word[:-3] in verbs:
            word=word[:-3]
        if word[:-4] in verbs:
            word=word[:-4]
        else:
            word=word[:-3]
    
    elif word[-2:]=='ed':
        if word[:-2] in verbs:
            word=word[:-2]
        elif word[:-1] in verbs:
            word=word[:-1]
    #word=stem_irregular(word)
    return word
def stem_simple(word):
    if word[-2:]=='es':
            word=word[:-2]   
    elif word[-1:]=='s':
            word=word[:-1]
    elif word[-3:]=='ing':
            word=word[:-3]
    
    elif word[-2:]=='ed':
            word=word[:-2]
    return word

def stem_irregular_verb(word):
        if word in past:
            ind=past.index(word)
            word=verb_root[ind]
        elif word in past_pp:
            ind=past_pp.index(word)
            word=verb_root[ind]
        return word
def stem_word(word):
    temp=word
    #word=stem_regular_verb(word)
    #word=stem_irregular_verb(word)
    #word=ps.stem(word)
    if(len(word)<=1):
        return temp
    return word

# %%
def remove_tags(doc):
    text=doc.lower()
    #text=re.sub('\n',' ',text)
    #text=re.sub('-',' ',text)
    #text=re.sub('[()?.@*#&!,$]','',text)
    #text=re.sub('[\']','',text)
    #text=re.sub('[^a-z0-9]',' ',text)
    #words=doc.split(' ')
    text=re.sub('<[^<>]+>',' ',text)
    words=re.findall('\w+',text)
    return words

def make_dictionary(topics,max_doc,root):
    index=0
    wordmap={}
    word_count=[]
    for topic in topics:
        print(topic)
        mydoc = minidom.parse(root+topic+'.xml')
        docs = mydoc.getElementsByTagName('row')
        doc_count=0
        for doc in docs:
            doc=doc.attributes['Body'].value
            if len(doc)<5:
                continue
            words = remove_tags(doc)
            for word in words:
                if word in s_words or len(word)<=1:
                    continue
                word=stem_word(word)
                if word not in wordmap:
                    wordmap[word]=index
                    word_count.append(int(1))
                    index=index+1
                elif word in wordmap:
                    ind=wordmap[word]
                    word_count[ind]=int(word_count[ind])+1
            doc_count=doc_count+1
            if doc_count>=max_doc:
                break
    return wordmap,word_count
def remove_minor_words(wordmap,word_count,min_occurance):
    words=list(wordmap.keys())
    freq=list(wordmap.values())
    word_df=pd.DataFrame(words,index=list(wordmap.values()),columns=['words'])
    word_df=word_df.sort_index()
    word_df['freq']=wc
    word_df=word_df.sort_values('freq',ascending=False)
    mask=word_df['freq']<=min_occurance
    word_df=word_df[mask]
    
    ss_words=(list(word_df['words']))
    print('initial length of wordmap :',len(wordmap))
    for word in ss_words:
        del wordmap[word]
    
    _wordmap={}
    ind=0
    for word in wordmap.keys():
        _wordmap[word]=ind
        ind+=1
    print('reduced length of wordmap :',len(_wordmap))
    return _wordmap

def vectorize_seq(topics,max_doc,wordmap,root):
    n_row=len(topics)*(max_doc)
    vectors=np.zeros((n_row,len(wordmap)),dtype=np.float64)
    vct_label=[]
    row=0
    for topic in topics:
        print(topic)
        mydoc = minidom.parse(root+topic+'.xml')
        docs = mydoc.getElementsByTagName('row')
        doc_count=0
        for doc in docs:

            #vector = [0]*(len(wordmap)+2)
            doc=doc.attributes['Body'].value
            if len(doc)<5:
                continue
            words = remove_tags(doc)
            for word in words:
                word=stem_word(word)
                if word in wordmap:
                    ind=wordmap[word]
                    vectors[row,ind]=vectors[row,ind]+1
            row=row+1
            vct_label.append(topic)
            word_list.append(words)
            doc_count=doc_count+1
            if doc_count>=max_doc:
                break
    return vectors,vct_label

# %%
def eucl_dis(test_vect,vectors,vct_labels):
    h_dists=[]
    for row in range(len(vct_labels)):
        vect=vectors[row]
        dist=np.abs(vect-test_vect)
        dist=np.square(dist)
        dist=np.sum(dist)
        dist=np.sqrt(dist)
        label=vct_labels[row]
        h_dists.append([dist,label])
    return h_dists
def humm_dis(test_vector,vectors,vct_labels):
    h_dists=[]
    
    test_vect=np.array(test_vector>0,dtype=np.float64)
    vects=np.array(vectors>0,dtype=np.float64)
    #test_vect=test_vector
    #vects=vectors
    for row in range(len(vct_labels)):
        vect=vects[row]
        label=vct_labels[row]
        dist=np.abs(vect-test_vect)
        #dist=dist*[test_vect!=0]
        dist=np.sum(dist)
        h_dists.append([dist,label])
    return h_dists
def cos_dis(test_vect,vectors,vct_labels):
    h_dists=[]
    
    vectors_bin= np.array(vectors>0,dtype=np.float64)
    wc_vect=np.sum(vectors_bin,axis=0)
    no_docs=len(vectors)
    
    IDF=no_docs/(wc_vect+1)
    IDF=np.log(IDF)
    
    for row in range(len(vct_labels)):
        train_vect=vectors[row]
        
        train_label=vct_labels[row]
        
        train_total=np.sum(train_vect)
        test_total=np.sum(test_vect)
        
        TF_test=test_vect/test_total
        test_vec=TF_test*IDF
        
        temp=np.square(test_vec)
        temp=np.sum(temp)
        test_vec_mag=np.sqrt(temp)
        
        TF_train=train_vect/train_total
        train_vec=TF_train*IDF
        
        temp=np.square(train_vec)
        temp=np.sum(temp)
        train_vec_mag=np.sqrt(temp)
        
        X=np.sum(test_vec*train_vec)
        Y=train_vec_mag*test_vec_mag
        
        dist=X/Y
        h_dists.append([dist,train_label])
    return h_dists

# %%
def knn(nn,test_vect,vectors,vct_labels,method):
    if method=='euc':
        h_dists=eucl_dis(test_vect,vectors,vct_labels)
    if method=='hum':
        h_dists=humm_dis(test_vect,vectors,vct_labels)
    if method=='cos':
        h_dists=cos_dis(test_vect,vectors,vct_labels)
    h_df=pd.DataFrame(h_dists,columns=['dist','label'])
    
    if method=='euc' or method=='hum':
        h_df=h_df.sort_values('dist',ascending=True)
    if method=='cos':
        h_df=h_df.sort_values('dist',ascending=False)
    print(h_df.head(5))
    lb=h_df['label']
    lb=lb[:nn]
    print(lb.values)
    
    if k==1:
        lb=lb.mode()
        lb=lb.values[0]
        
    if k==3:
        if len(lb.unique())==k:
            lb=lb[:1]
        lb=lb.mode()
        lb=lb.values[0]
    if k==5:
        if len(lb.mode())>=2:
            lb=lb[:3]
            if len(lb.mode())>=2:
                lb=lb[:1]
        lb=lb.mode()
        lb=lb.values[0]
        
                        
    return(lb)

# %%
root='Dataset/Training/'
root_test='Dataset/Test/'
f=open('Stopwords.txt')
s_words=f.read()
s_words=s_words.split('\n')
s_words.append('')

#topics=['3d_Printer','Coffee','Arduino','Astronomy','Biology']#,'Chess','Cooking','Law','Space','Windows_Phone','Wood_Working']
#topics=['3d_Printer','Coffee','Chess','Astronomy','Law','Space']#,,'Cooking',,,'Windows_Phone','Wood_Working']
#topics=['3d_Printer','Coffee','Arduino','Astronomy','Biology','Chess','Cooking','Law','Space','Windows_Phone','Wood_Working']

#topics=['Anime']
#topics=['3d_Printer','Coffee','Chess']
topics=['3d_Printer','Anime','Arduino']
#topics=['3d_Printer','Coffee','Law']
 
#wordmap=make_dictionary(topics,100,root)
#vectors=vectorize_seq(topics,100,wordmap,root)
word_list=[]
write_backup=1
max_docs_train=200
min_occurance=int(max_docs_train/200)
if write_backup==1:
    print('Making dictionary :')
    wordmap,wc=make_dictionary(topics,max_docs_train,root)
    #print('Removing minor words:')
    #wordmap=remove_minor_words(wordmap,wc,min_occurance)
    print('Vectorizing Sequence:')
    vectors,vct_labels=vectorize_seq(topics,max_docs_train,wordmap,root)
    #pickle_out = open("wordmap_all_200.pickle","wb")
    #pickle.dump(wordmap, pickle_out)
    #pickle_out.close()
    #pickle_out = open("vectors_test.pickle","wb")
    #pickle.dump(vectors, pickle_out)
    #pickle_out.close()

read_backup=0
if read_backup==1:
    print('Reading backup')
    pickle_read = open("wordmap_500.pickle","rb")
    wordmap=pickle.load(pickle_read)
    pickle_read.close()

    pickle_read = open("vectors_500.pickle","rb")
    vectors=pickle.load(pickle_read)
    pickle_read.close()

#words=list(wordmap.keys())
#freq=list(wordmap.values())
#word_df=pd.DataFrame({'words':words,'freq':freq})
#word_df=word_df.sort_values('freq',ascending=False)
# Out:
# Making dictionary :
# 3d_Printer
# Anime
# Arduino
# Vectorizing Sequence:
# 3d_Printer
# Anime
# Arduino

# %%
print(len(wordmap))
#  7850
#  6978
# Out:
# 7387

# %%
#words=list(wordmap.keys())
#freq=list(wordmap.values())
#word_df=pd.DataFrame(words,index=list(wordmap.values()))
#word_df=word_df.sort_index()
#word_df['freq']=wc
#word_df=word_df.sort_values('freq',ascending=False)
#print(word_df[0:50])
#print(len(vectors))

# %%
max_docs_test=20
test_vector,true_lbs=vectorize_seq(topics,max_docs_test,wordmap,root_test)

n=len(topics)*max_docs_test
methods=['cos','euc','hum']
k_val=[1,3,5]
#k_val=[5]

log=True
no_topics=len(topics)
tot_doc=no_topics*max_docs_train
tot_doc_test=no_topics*max_docs_test

acc_log=''
acc_log+='********************************************************************************************\n'
acc_log+=str(topics)+'\n'
acc_log+='stem : none , re : findall , minor_remove: 3\n'
acc_log+=str(['no_topic','train doc per topic','train_doc','test doc per topic','test_doc','word map'])+'\n'
acc_log+=str([no_topics,max_docs_train,tot_doc,max_docs_test,tot_doc_test,str(len(wordmap))])+'\n'
acc_log+='********************************************************************************************\n'
acc_log+=str(['k','method','accuracy','time'])+'\n'
for k in k_val:
    for method in methods:
        acc=0
        T=time.time()
        for i in range(n):
            true_lb=true_lbs[i]
            test_vect=test_vector[i,:]
            pred_lb=knn(k,test_vect,vectors,vct_labels,method)
            print(pred_lb,true_lb)
            if pred_lb==true_lb:
                acc=acc+1
                print(pred_lb,true_lb,acc,i+1)
        accuracy=acc/(n)
        T=time.time()-T
        print('accuray',accuracy)
        print('Time :',T)
        acc_log+=(str([k,method,accuracy,T])+'\n')

acc_log=re.sub('[\[\] ]','',acc_log)
if log==True:
    file=open('Report/backup_exp.txt','a')
    file.write(acc_log)
    file.close()
    pass

#68.75% eucl 60 82.92
#53.33 humm 60  81.25
#87.08 cos 94.17
# Out:
# 3d_Printer
# Anime
# Arduino
#          dist       label
# 189  0.225432  3d_Printer
# 193  0.179125  3d_Printer
# 188  0.159965  3d_Printer
# 56   0.155992  3d_Printer
# 69   0.141279  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 1 1
#          dist       label
# 193  0.426594  3d_Printer
# 194  0.354216  3d_Printer
# 72   0.317425  3d_Printer
# 66   0.285391  3d_Printer
# 189  0.253207  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 2 2
#          dist       label
# 189  0.524929  3d_Printer
# 3    0.273876  3d_Printer
# 58   0.168516  3d_Printer
# 15   0.145811  3d_Printer
# 188  0.119664  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 3 3
#          dist       label
# 168  0.138601  3d_Printer
# 163  0.125119  3d_Printer
# 349  0.086176       Anime
# 444  0.082315     Arduino
# 572  0.070871     Arduino
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 4 4
#          dist       label
# 187  0.161287  3d_Printer
# 197  0.144485  3d_Printer
# 128  0.134534  3d_Printer
# 186  0.122045  3d_Printer
# 199  0.102268  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 5 5
#          dist       label
# 8    0.206863  3d_Printer
# 14   0.183565  3d_Printer
# 413  0.172785     Arduino
# 40   0.171978  3d_Printer
# 166  0.163585  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 6 6
#          dist       label
# 498  0.130564     Arduino
# 161  0.126380  3d_Printer
# 103  0.117780  3d_Printer
# 25   0.111583  3d_Printer
# 455  0.107473     Arduino
# ['Arduino']
# Arduino 3d_Printer
#          dist       label
# 2    0.241420  3d_Printer
# 121  0.202272  3d_Printer
# 187  0.145652  3d_Printer
# 128  0.128087  3d_Printer
# 481  0.107274     Arduino
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 7 8
#          dist       label
# 138  0.161086  3d_Printer
# 128  0.149231  3d_Printer
# 187  0.149169  3d_Printer
# 562  0.139423     Arduino
# 69   0.127343  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 8 9
#          dist       label
# 34   0.141068  3d_Printer
# 37   0.136804  3d_Printer
# 40   0.129595  3d_Printer
# 430  0.114322     Arduino
# 13   0.111584  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 9 10
#          dist       label
# 190  0.283032  3d_Printer
# 43   0.216289  3d_Printer
# 178  0.181656  3d_Printer
# 124  0.178614  3d_Printer
# 77   0.175068  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 10
arduino
# ['Arduino']
# Arduino Arduino
# Arduino Arduino 40 44
#          dist    label
# 547  0.339039  Arduino
# 424  0.273653  Arduino
# 416  0.246858  Arduino
# 425  0.215391  Arduino
# 420  0.168674  Arduino
# ['Arduino']
# Arduino Arduino
# Arduino Arduino 41 45
#          dist       label
# 413  0.260201     Arduino
# 161  0.172516  3d_Printer
# 452  0.135375     Arduino
# 466  0.135345     Arduino
# 581  0.124312     Arduino
# ['Arduino']
# Arduino Arduino
# Arduino Arduino 42 46
#          dist    label
# 460  0.218513  Arduino
# 244  0.182299    Anime
# 412  0.176288  Arduino
# 418  0.138027  Arduino
# 488  0.124109  Arduino
# ['Arduino']
# Arduino Arduino
# Arduino Arduino 43 47
#          dist    label
# 592  0.316164  Arduino
# 568  0.272468  Arduino
# 578  0.239395  Arduino
# 540  0.215341  Arduino
# 557  0.187568  Arduino
# ['Arduino']
# Arduino Arduino
# Arduino Arduino 44 48
#          dist    label
# 473  0.135203  Arduino
# 475  0.129124  Arduino
# 494  0.117766  Arduino
# 527  0.116528  Arduino
# 525  0.111650  Arduino
# ['Arduino']
# Arduino Arduino
# Arduino Arduino 45 49
#          dist    label
# 540  0.298026  Arduino
# 578  0.285745  Arduino
# 534  0.268240  Arduino
# 555  0.209410  Arduino
# 562  0.186592  Arduino
# ['Arduino']
# Arduino Arduino
# Arduino Arduino 46 50
#          dist    label
# 506  0.300748  Arduino
# 592  0.202894  Arduino
# 563  0.183170  Arduino
# 508  0.172738  Arduino
# 523  0.171494  Arduino
# ['Arduino']
# Arduino Arduino
# Arduino Arduino 47 51
#          dist    label
# 530  0.267793  Arduino
# 592  0.240009  Arduino
# 529  0.231500  Arduino
# 596  0.230443  Arduino
# 462  0.221413  Arduino
# ['Arduino']
# Arduino Arduino
# Arduino Arduino 48 52
#          dist    label
# 418  0.187758  Arduino
# 569  0.177891  Arduino
# 419  0.166791  Arduino
# 586  0.165377  Arduino
# 589  0.158479  Arduino
# ['Arduino']
# Arduino Arduino
# Arduino Arduino 49 53
#          dist    label
# 557  0.234404  Arduino
# 437  0.216535  Arduino
# 594  0.192811  Arduino
# 575  0.158549  Arduino
# 593  0.141940  Arduino
# ['Arduino']
# Arduino Arduino
# Arduino Arduino 50 54
#          dist       label
# 521  0.296104     Arduino
# 84   0.144952  3d_Printer
# 496  0.144815     Arduino
# 542  0.142848     Arduino
# 466  0.123445     Arduino
# ['Arduino']
# Arduino Arduino
# Arduino Arduino 51 55
#          dist    label
# 592  0.411331  Arduino
# 568  0.315411  Arduino
# 578  0.284296  Arduino
# 557  0.277911  Arduino
# 591  0.236111  Arduino
# ['Arduino']
# Arduino Arduino
# Arduino Arduino 52 56
#          dist    label
# 427  0.279380  Arduino
# 593  0.246084  Arduino
# 557  0.244417  Arduino
# 570  0.230584  Arduino
# 511  0.213447  Arduino
# ['Arduino']
# Arduino Arduino
# Arduino Arduino 53 57
#          dist    label
# 592  0.440161  Arduino
# 568  0.366861  Arduino
# 591  0.347411  Arduino
# 594  0.286207  Arduino
# 557  0.246286  Arduino
# ['Arduino']
# Arduino Arduino
# Arduino Arduino 54 58
#          dist    label
# 547  0.264254  Arduino
# 510  0.089009  Arduino
# 424  0.088871  Arduino
# 428  0.088152  Arduino
# 344  0.086826    Anime
# ['Arduino']
# Arduino Arduino
# Arduino Arduino 55 59
#          dist    label
# 558  0.248187  Arduino
# 460  0.206120  Arduino
# 419  0.172599  Arduino
# 422  0.134365  Arduino
# 563  0.107085  Arduino
# ['Arduino']
# Arduino Arduino
# Arduino Arduino 56 60
# accuray 0.9333333333333333
# Time : 19.126810312271118
#           dist       label
# 189  11.224972  3d_Printer
# 66   11.269428  3d_Printer
# 101  11.445523  3d_Printer
# 64   11.489125  3d_Printer
# 23   11.532563  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 1 1
#           dist       label
# 193  11.704700  3d_Printer
# 66   12.409674  3d_Printer
# 189  13.076697  3d_Printer
# 72   13.190906  3d_Printer
# 195  13.228757  3d_Printer
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 2 2
#           dist       label
# 189  14.177447  3d_Printer
# 3    15.652476  3d_Printer
# 106  15.811388  3d_Printer
# 15   15.874508  3d_Printer
# 355  15.905974       Anime
# ['3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 3 3
3d_Printer
# ['Anime']
# Anime Anime
# Anime Anime 28 37
#          dist       label
# 365  7.071068       Anime
# 117  7.348469  3d_Printer
# 355  7.348469       Anime
# 268  7.416198       Anime
# 378  7.416198       Anime
# ['Anime']
# Anime Anime
# Anime Anime 29 38
#           dist       label
# 306  14.177447       Anime
# 117  14.456832  3d_Printer
# 355  14.525839       Anime
# 337  14.525839       Anime
# 571  14.525839     Arduino
# ['Anime']
# Anime Anime
# Anime Anime 30 39
#          dist       label
# 355  4.358899       Anime
# 378  4.690416       Anime
# 162  4.690416  3d_Printer
# 119  4.690416  3d_Printer
# 268  4.690416       Anime
# ['Anime']
# Anime Anime
# Anime Anime 31 40
#          dist       label
# 355  6.244998       Anime
# 162  6.480741  3d_Printer
# 378  6.480741       Anime
# 119  6.480741  3d_Printer
# 528  6.557439     Arduino
# ['Anime']
# Anime Arduino
#          dist       label
# 545  5.916080     Arduino
# 355  6.082763       Anime
# 415  6.082763     Arduino
# 4    6.244998  3d_Printer
# 528  6.244998     Arduino
# ['Arduino']
# Arduino Arduino
# Arduino Arduino 32 42
#           dist    label
# 539  18.165902  Arduino
# 397  18.303005    Anime
# 409  18.493242  Arduino
# 538  18.493242  Arduino
# 580  18.547237  Arduino
# ['Arduino']
# Arduino Arduino
# Arduino Arduino 33 43
#          dist       label
# 355  3.741657       Anime
# 119  4.123106  3d_Printer
# 378  4.123106       Anime
# 162  4.123106  3d_Printer
# 528  4.242641     Arduino
# ['Anime']
# Anime Arduino
#           dist    label
# 416  23.558438  Arduino
# 547  23.643181  Arduino
# 420  23.853721  Arduino
# 581  24.166092  Arduino
# 571  24.392622  Arduino
# ['Arduino']
# Arduino Arduino
# Arduino Arduino 34 45
#          dist    label
# 413  7.874008  Arduino
# 452  7.937254  Arduino
# 415  8.062258  Arduino
# 581  8.124038  Arduino
# 355  8.185353    Anime
# ['Arduino']
# Arduino Arduino
# Arduino Arduino 35 46
#          dist       label
# 355  3.741657       Anime
# 162  4.123106  3d_Printer
# 378  4.123106       Anime
# 119  4.123106  3d_Printer
# 571  4.242641     Arduino
# ['Anime']
# Anime Arduino
#           dist    label
# 578  13.820275  Arduino
# 409  14.212670  Arduino
# 540  14.247807  Arduino
# 557  14.282857  Arduino
# 568  14.282857  Arduino
# ['Arduino']
# Arduino Arduino
# Arduino Arduino 36 48
#          dist       label
# 7    5.916080  3d_Printer
# 528  5.916080     Arduino
# 355  5.916080       Anime
# 378  6.164414       Anime
# 119  6.164414  3d_Printer
# ['3d_Printer']
# 3d_Printer Arduino
#           dist    label
# 540  11.874342  Arduino
# 578  12.041595  Arduino
# 415  12.083046  Arduino
# 528  12.165525  Arduino
# 580  12.165525  Arduino
# ['Arduino']
# Arduino Arduino
# Arduino Arduino 37 50
#          dist    label
# 533  9.055385  Arduino
# 572  9.110434  Arduino
# 478  9.219544  Arduino
# 415  9.273618  Arduino
# 445  9.273618  Arduino
# ['Arduino']
# Arduino Arduino
# Arduino Arduino 38 51
#           dist    label
# 592  32.264532  Arduino
# 568  32.542280  Arduino
# 462  33.406586  Arduino
# 578  33.496268  Arduino
# 570  33.630343  Arduino
# ['Arduino']
# Arduino Arduino
# Arduino Arduino 39 52
#           dist       label
# 419  12.767145     Arduino
# 412  13.000000     Arduino
# 538  13.000000     Arduino
# 586  13.076697     Arduino
# 5    13.076697  3d_Printer
# ['Arduino']
# Arduino Arduino
# Arduino Arduino 40 53
#          dist    label
# 415  6.557439  Arduino
# 528  6.557439  Arduino
# 355  6.708204    Anime
# 437  6.708204  Arduino
# 571  6.708204  Arduino
# ['Arduino']
# Arduino Arduino
# Arduino Arduino 41 54
#           dist       label
# 140  20.074860  3d_Printer
# 84   20.099751  3d_Printer
# 586  20.124612     Arduino
# 0    20.149442  3d_Printer
# 117  20.174241  3d_Printer
# ['3d_Printer']
# 3d_Printer Arduino
#           dist    label
# 592  26.589472  Arduino
# 568  29.546573  Arduino
# 557  30.315013  Arduino
# 578  31.080541  Arduino
# 575  31.320920  Arduino
# ['Arduino']
# Arduino Arduino
# Arduino Arduino
0  3d_Printer
# ['Anime']
# Anime Anime
# Anime Anime 23 35
#      dist    label
# 355  28.0    Anime
# 268  29.0    Anime
# 271  29.0    Anime
# 365  29.0    Anime
# 524  31.0  Arduino
# ['Anime']
# Anime Anime
# Anime Anime 24 36
#      dist       label
# 355  26.0       Anime
# 306  28.0       Anime
# 162  29.0  3d_Printer
# 119  29.0  3d_Printer
# 378  29.0       Anime
# ['Anime']
# Anime Anime
# Anime Anime 25 37
#      dist       label
# 355  27.0       Anime
# 378  28.0       Anime
# 365  28.0       Anime
# 117  29.0  3d_Printer
# 162  30.0  3d_Printer
# ['Anime']
# Anime Anime
# Anime Anime 26 38
#       dist       label
# 306  109.0       Anime
# 117  111.0  3d_Printer
# 355  111.0       Anime
# 378  112.0       Anime
# 268  112.0       Anime
# ['Anime']
# Anime Anime
# Anime Anime 27 39
#      dist       label
# 355  19.0       Anime
# 545  22.0     Arduino
# 365  22.0       Anime
# 162  22.0  3d_Printer
# 268  22.0       Anime
# ['Anime']
# Anime Anime
# Anime Anime 28 40
#      dist       label
# 355  13.0       Anime
# 35   15.0  3d_Printer
# 378  16.0       Anime
# 539  16.0     Arduino
# 162  16.0  3d_Printer
# ['Anime']
# Anime Arduino
#      dist       label
# 415  33.0     Arduino
# 355  34.0       Anime
# 545  35.0     Arduino
# 528  36.0     Arduino
# 4    36.0  3d_Printer
# ['Arduino']
# Arduino Arduino
# Arduino Arduino 29 42
#      dist    label
# 539  75.0  Arduino
# 355  78.0    Anime
# 538  78.0  Arduino
# 524  79.0  Arduino
# 528  80.0  Arduino
# ['Arduino']
# Arduino Arduino
# Arduino Arduino 30 43
#      dist       label
# 355  14.0       Anime
# 119  17.0  3d_Printer
# 162  17.0  3d_Printer
# 378  17.0       Anime
# 528  18.0     Arduino
# ['Anime']
# Anime Arduino
#       dist       label
# 571  113.0     Arduino
# 581  116.0     Arduino
# 355  117.0       Anime
# 528  117.0     Arduino
# 119  118.0  3d_Printer
# ['Arduino']
# Arduino Arduino
# Arduino Arduino 31 45
#      dist       label
# 355  43.0       Anime
# 35   43.0  3d_Printer
# 415  44.0     Arduino
# 581  44.0     Arduino
# 528  45.0     Arduino
# ['Anime']
# Anime Arduino
#      dist       label
# 355  14.0       Anime
# 412  15.0     Arduino
# 35   16.0  3d_Printer
# 119  17.0  3d_Printer
# 27   17.0  3d_Printer
# ['Anime']
# Anime Arduino
#      dist    label
# 415  67.0  Arduino
# 528  68.0  Arduino
# 355  68.0    Anime
# 545  69.0  Arduino
# 571  70.0  Arduino
# ['Arduino']
# Arduino Arduino
# Arduino Arduino 32 48
#      dist       label
# 355  29.0       Anime
# 528  31.0     Arduino
# 7    31.0  3d_Printer
# 162  32.0  3d_Printer
# 545  32.0     Arduino
# ['Anime']
# Anime Arduino
#      dist    label
# 355  35.0    Anime
# 528  35.0  Arduino
# 539  36.0  Arduino
# 415  36.0  Arduino
# 571  37.0  Arduino
# ['Anime']
# Anime Arduino
#      dist       label
# 533  38.0     Arduino
# 355  39.0       Anime
# 539  40.0     Arduino
# 412  40.0     Arduino
# 35   41.0  3d_Printer
# ['Arduino']
# Arduino Arduino
# Arduino Arduino 33 51
#      dist    label
# 355  60.0    Anime
# 545  61.0  Arduino
# 539  61.0  Arduino
# 524  61.0  Arduino
# 528  62.0  Arduino
# ['Anime']
# Anime Arduino
#      dist    label
# 355  67.0    Anime
# 533  68.0  Arduino
# 586  68.0  Arduino
# 412  68.0  Arduino
# 571  69.0  Arduino
# ['Anime']
# Anime Arduino
#      dist       label
# 355  25.0       Anime
# 528  25.0     Arduino
# 415  26.0     Arduino
# 571  27.0     Arduino
# 117  27.0  3d_Printer
# ['Anime']
# Anime Arduino
#      dist       label
# 355  97.0       Anime
# 268  98.0       Anime
# 528  99.0     Arduino
# 538  99.0     Arduino
# 117  99.0  3d_Printer
# ['Anime']
# Anime Arduino
#      dist    label
# 578  85.0  Arduino
# 533  86.0  Arduino
# 355  87.0    Anime
# 528  87.0  Arduino
# 580  87.0  Arduino
# ['Arduino']
# Arduino Arduino
# Arduino Arduino 34 56
#      dist    label
# 355  43.0    Anime
# 539  44.0  Arduino
# 306  45.0    Anime
# 528  45.0  Arduino
# 538  45.0  Arduino
# ['Anime']
# Anime Arduino
#       dist    label
# 539  132.0  Arduino
# 568  133.0  Arduino
# 538  133.0  Arduino
# 355  133.0    Anime
# 571  133.0  Arduino
# ['Arduino']
# Arduino Arduino
# Arduino Arduino 35 58
#      dist       label
# 355  48.0       Anime
# 571  50.0     Arduino
# 545  51.0     Arduino
# 162  51.0  3d_Printer
# 119  51.0  3d_Printer
# ['Anime']
# Anime Arduino
#      dist       label
# 355  28.0       Anime
# 571  30.0     Arduino
# 35   30.0  3d_Printer
# 528  30.0     Arduino
# 27   31.0  3d_Printer
# ['Anime']
# Anime Arduino
# accuray 0.5833333333333334
# Time : 5.831116199493408
#          dist       label
# 189  0.225432  3d_Printer
# 193  0.179125  3d_Printer
# 188  0.159965  3d_Printer
# 56   0.155992  3d_Printer
# 69   0.141279  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 1 1
#          dist       label
# 193  0.426594  3d_Printer
# 194  0.354216  3d_Printer
# 72   0.317425  3d_Printer
# 66   0.285391  3d_Printer
# 189  0.253207  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 2 2
#          dist       label
# 189  0.524929  3d_Printer
# 3    0.273876  3d_Printer
# 58   0.168516  3d_Printer
# 15   0.145811  3d_Printer
# 188  0.119664  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 3 3
#          dist       label
# 168  0.138601  3d_Printer
# 163  0.125119  3d_Printer
# 349  0.086176       Anime
# 444  0.082315     Arduino
# 572  0.070871     Arduino
# ['3d_Printer' '3d_Printer' 'Anime']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 4 4
#          dist       label
# 187  0.161287  3d_Printer
# 197  0.144485  3d_Printer
# 128  0.134534  3d_Printer
# 186  0.122045  3d_Printer
# 199  0.102268  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 5 5
#          dist       label
# 8    0.206863  3d_Printer
# 14   0.183565  3d_Printer
# 413  0.172785     Arduino
# 40   0.171978  3d_Printer
# 166  0.163585  3d_Printer
# ['3d_Printer' '3d_Printer' 'Arduino']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 6 6
#          dist       label
# 498  0.130564     Arduino
# 161  0.126380  3d_Printer
# 103  0.117780  3d_Printer
# 25   0.111583  3d_Printer
# 455  0.107473     Arduino
# ['Arduino' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 7 7
#          dist       label
# 2    0.241420  3d_Printer
# 121  0.202272  3d_Printer
# 187  0.145652  3d_Printer
# 128  0.128087  3d_Printer
# 481  0.107274     Arduino
# ['3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 8 8
#          dist       label
# 138  0.161086  3d_Printer
# 128  0.149231  3d_Printer
# 187  0.149169  3d_Printer
# 562  0.139423     Arduino
# 69   0.127343  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 9 9
#          dist       label
# 34   0.141068  3d_Printer
# 37   0.136804  3d_Printer
# 40   0.129595  3d_Printer
# 430  0.114322     Arduino
# 13   0.111584  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 10 10
#          dist       label
# 190  0.283032  3d_Printer
# 43   0.216289  3d_Printer
# 178  0.181656  3d_Printer
# 124  0.178614  3d_Printer
# 77   0.175068  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 11
Anime
# ['Anime' 'Anime' 'Anime']
# Anime Anime
# Anime Anime 27 28
#          dist       label
# 215  0.141729       Anime
# 13   0.134921  3d_Printer
# 509  0.129653     Arduino
# 582  0.108813     Arduino
# 311  0.107781       Anime
# ['Anime' '3d_Printer' 'Arduino']
# Anime Anime
# Anime Anime 28 29
#          dist       label
# 238  0.383189       Anime
# 320  0.329850       Anime
# 112  0.084741  3d_Printer
# 282  0.077685       Anime
# 51   0.062747  3d_Printer
# ['Anime' 'Anime' '3d_Printer']
# Anime Anime
# Anime Anime 29 30
#          dist  label
# 214  0.183648  Anime
# 328  0.178539  Anime
# 205  0.119573  Anime
# 206  0.114024  Anime
# 311  0.105270  Anime
# ['Anime' 'Anime' 'Anime']
# Anime Anime
# Anime Anime 30 31
#          dist  label
# 214  0.176609  Anime
# 328  0.170595  Anime
# 269  0.108918  Anime
# 305  0.102739  Anime
# 262  0.089097  Anime
# ['Anime' 'Anime' 'Anime']
# Anime Anime
# Anime Anime 31 32
#          dist    label
# 320  0.271239    Anime
# 238  0.211677    Anime
# 545  0.079227  Arduino
# 275  0.077061    Anime
# 378  0.072653    Anime
# ['Anime' 'Anime' 'Arduino']
# Anime Anime
# Anime Anime 32 33
#          dist    label
# 514  0.210891  Arduino
# 299  0.130883    Anime
# 273  0.130084    Anime
# 478  0.127203  Arduino
# 593  0.125032  Arduino
# ['Arduino' 'Anime' 'Anime']
# Anime Anime
# Anime Anime 33 34
#          dist       label
# 343  0.130570       Anime
# 338  0.120173       Anime
# 230  0.102398       Anime
# 109  0.100466  3d_Printer
# 363  0.094005       Anime
# ['Anime' 'Anime' 'Anime']
# Anime Anime
# Anime Anime 34 35
#          dist       label
# 307  0.179596       Anime
# 251  0.149322       Anime
# 31   0.141663  3d_Printer
# 253  0.121851       Anime
# 303  0.120502       Anime
# ['Anime' 'Anime' '3d_Printer']
# Anime Anime
# Anime Anime 35 36
#          dist  label
# 276  0.249496  Anime
# 389  0.188726  Anime
# 390  0.169448  Anime
# 251  0.138471  Anime
# 212  0.121440  Anime
# ['Anime' 'Anime' 'Anime']
# Anime Anime
# Anime Anime 36 37
#          dist       label
# 348  0.305686       Anime
# 377  0.187900       Anime
# 53   0.142485  3d_Printer
# 365  0.130894       Anime
# 345  0.120412       Anime
# ['Anime' 'Anime' '3d_Printer']
# Anime Anime
# Anime Anime 37 38
#          dist       label
# 388  0.101395       Anime
# 13   0.101212  3d_Printer
# 362  0.097099       Anime
# 294  0.082502       Anime
# 306  0.081524       Anime
# ['Anime' '3d_Printer' 'Anime']
# Anime Anime
# Anime Anime 38 39
#          dist       label
# 75   0.086323  3d_Printer
# 17   0.081260  3d_Printer
# 382  0.078110       Anime
# 402  0.074258     Arduino
# 381  0.068930       Anime
# ['3d_Printer' '3d_Printer' 'Anime']
# 3d_Printer Anime
#          dist    label
# 527  0.186445  Arduino
# 592  0.146080  Arduino
# 507  0.126735  Arduino
# 568  0.110856  Arduino
# 578  0.102501  Arduino
# ['Arduino' 'Arduino' 'Arduino']
# Arduino Arduino
# Arduino Arduino 39 41
#          dist    label
# 545  0.176734  Arduino
# 365  0.114810    Anime
# 520  0.113106  Arduino
# 523  0.112591  Arduino
# 563  0.107466  Arduino
# ['Arduino' 'Anime' 'Arduino']
# Arduino Arduino
# Arduino Arduino 40 42
#          dist    label
# 594  0.205950  Arduino
# 591  0.156240  Arduino
# 592  0.155670  Arduino
# 539  0.154167  Arduino
# 568  0.133749  Arduino
# ['Arduino' 'Arduino' 'Arduino']
# Arduino Arduino
# Arduino Arduino 41 43
#          dist       label
# 475  0.133334     Arduino
# 525  0.130612     Arduino
# 494  0.130313     Arduino
# 173  0.125637  3d_Printer
# 416  0.084587     Arduino
# ['Arduino' 'Arduino' 'Arduino']
# Arduino Arduino
# Arduino Arduino 42 44
#          dist    label
# 547  0.339039  Arduino
# 424  0.273653  Arduino
# 416  0.246858  Arduino
# 425  0.215391  Arduino
# 420  0.168674  Arduino
# ['Arduino' 'Arduino' 'Arduino']
# Arduino Arduino
# Arduino Arduino 43 45
#          dist       label
# 413  0.260201     Arduino
# 161  0.172516  3d_Printer
# 452  0.135375     Arduino
# 466  0.135345     Arduino
# 581  0.124312     Arduino
# ['Arduino' '3d_Printer' 'Arduino']
# Arduino Arduino
# Arduino Arduino 44 46
#          dist    label
# 460  0.218513  Arduino
# 244  0.182299    Anime
# 412  0.176288  Arduino
# 418  0.138027  Arduino
# 488  0.124109  Arduino
# ['Arduino' 'Anime' 'Arduino']
# Arduino Arduino
# Arduino Arduino 45 47
#          dist    label
# 592  0.316164  Arduino
# 568  0.272468  Arduino
# 578  0.239395  Arduino
# 540  0.215341  Arduino
# 557  0.187568  Arduino
# ['Arduino' 'Arduino' 'Arduino']
# Arduino Arduino
# Arduino Arduino 46 48
#          dist    label
# 473  0.135203  Arduino
# 475  0.129124  Arduino
# 494  0.117766  Arduino
# 527  0.116528  Arduino
# 525  0.111650  Arduino
# ['Arduino' 'Arduino' 'Arduino']
# Arduino Arduino
# Arduino Arduino 47 49
#          dist    label
# 540  0.298026  Arduino
# 578  0.285745  Arduino
# 534  0.268240  Arduino
# 555  0.209410  Arduino
# 562  0.186592  Arduino
# ['Arduino' 'Arduino' 'Arduino']
# Arduino Arduino
# Arduino Arduino 48 50
#          dist    label
# 506  0.300748  Arduino
# 592  0.202894  Arduino
# 563  0.183170  Arduino
# 508  0.172738  Arduino
# 523  0.171494  Arduino
# ['Arduino' 'Arduino' 'Arduino']
# Arduino Arduino
# Arduino Arduino 49 51
#          dist    label
# 530  0.267793  Arduino
# 592  0.240009  Arduino
# 529  0.231500  Arduino
# 596  0.230443  Arduino
# 462  0.221413  Arduino
# ['Arduino' 'Arduino' 'Arduino']
# Arduino Arduino
# Arduino Arduino 50 52
#          dist    label
# 418  0.187758  Arduino
# 569  0.177891  Arduino
# 419  0.166791  Arduino
# 586  0.165377  Arduino
# 589  0.158479  Arduino
# ['Arduino' 'Arduino' 'Arduino']
# Arduino Arduino
# Arduino Arduino 51 53
#          dist    label
# 557  0.234404  Arduino
# 437  0.216535  Arduino
# 594  0.192811  Arduino
# 575  0.158549  Arduino
# 593  0.141940  Arduino
# ['Arduino' 'Arduino' 'Arduino']
# Arduino Arduino
# Arduino Arduino 52 54
#          dist       label
# 521  0.296104     Arduino
# 84   0.144952  3d_Printer
# 496  0.144815     Arduino
# 542  0.142848     Arduino
# 466  0.123445     Arduino
# ['Arduino' '3d_Printer' 'Arduino']
# Arduino Arduino
# Arduino Arduino 53 55
#          dist    label
# 592  0.411331  Arduino
# 568  0.315411  Arduino
# 578  0.284296  Arduino
# 557  0.277911  Arduino
# 591  0.236111  Arduino
# ['Arduino' 'Arduino' 'Arduino']
# Arduino Arduino
# Arduino Arduino 54 56
#          dist    label
# 427  0.279380  Arduino
# 593  0.246084  Arduino
# 557  0.244417  Arduino
# 570  0.230584  Arduino
# 511  0.213447  Arduino
# ['Arduino' 'Arduino' 'Arduino']
# Arduino Arduino
# Arduino Arduino 55 57
#          dist    label
# 592  0.440161  Arduino
# 568  0.366861  Arduino
# 591  0.347411  Arduino
# 594  0.286207  Arduino
# 557  0.246286  Arduino
# ['Arduino' 'Arduino' 'Arduino']
# Arduino Arduino
# Arduino Arduino 56 58
#          dist    label
# 547  0.264254  Arduino
# 510  0.089009  Arduino
# 424  0.088871  Arduino
# 428  0.088152  Arduino
# 344  0.086826    Anime
# ['Arduino' 'Arduino' 'Arduino']
# Arduino Arduino
# Arduino Arduino 57 59
#          dist    label
# 558  0.248187  Arduino
# 460  0.206120  Arduino
# 419  0.172599  Arduino
# 422  0.134365  Arduino
# 563  0.107085  Arduino
# ['Arduino' 'Arduino' 'Arduino']
# Arduino Arduino
# Arduino Arduino 58 60
# accuray 0.9666666666666667
# Time : 18.94967555999756
#           dist       label
# 189  11.224972  3d_Printer
# 66   11.269428  3d_Printer
# 101  11.445523  3d_Printer
# 64   11.489125  3d_Printer
# 23   11.532563  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 1 1
#           dist       label
# 193  11.704700  3d_Printer
# 66   12.409674  3d_Printer
# 189  13.076697  3d_Printer
# 72   13.190906  3d_Printer
# 195  13.228757  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 2 2
#           dist       label
# 189  14.177447  3d_Printer
# 3    15.652476  3d_Printer
# 106  15.811388  3d_Printer
# 15   15.874508  3d_Printer
# 355  15.905974       Anime
# ['3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 3 3
# ...
# 528  5.916080     Arduino
# 355  5.916080       Anime
# 378  6.164414       Anime
# 119  6.164414  3d_Printer
# ['3d_Printer' 'Arduino' 'Anime' 'Anime' '3d_Printer']
# 3d_Printer Arduino
#           dist    label
# 540  11.874342  Arduino
# 578  12.041595  Arduino
# 415  12.083046  Arduino
# 528  12.165525  Arduino
# 580  12.165525  Arduino
# ['Arduino' 'Arduino' 'Arduino' 'Arduino' 'Arduino']
# Arduino Arduino
# Arduino Arduino 42 50
#          dist    label
# 533  9.055385  Arduino
# 572  9.110434  Arduino
# 478  9.219544  Arduino
# 415  9.273618  Arduino
# 445  9.273618  Arduino
# ['Arduino' 'Arduino' 'Arduino' 'Arduino' 'Arduino']
# Arduino Arduino
# Arduino Arduino 43 51
#           dist    label
# 592  32.264532  Arduino
# 568  32.542280  Arduino
# 462  33.406586  Arduino
# 578  33.496268  Arduino
# 570  33.630343  Arduino
# ['Arduino' 'Arduino' 'Arduino' 'Arduino' 'Arduino']
# Arduino Arduino
# Arduino Arduino 44 52
#           dist       label
# 419  12.767145     Arduino
# 412  13.000000     Arduino
# 538  13.000000     Arduino
# 586  13.076697     Arduino
# 5    13.076697  3d_Printer
# ['Arduino' 'Arduino' 'Arduino' 'Arduino' '3d_Printer']
# Arduino Arduino
# Arduino Arduino 45 53
#          dist    label
# 415  6.557439  Arduino
# 528  6.557439  Arduino
# 355  6.708204    Anime
# 437  6.708204  Arduino
# 571  6.708204  Arduino
# ['Arduino' 'Arduino' 'Anime' 'Arduino' 'Arduino']
# Arduino Arduino
# Arduino Arduino 46 54
#           dist       label
# 140  20.074860  3d_Printer
# 84   20.099751  3d_Printer
# 586  20.124612     Arduino
# 0    20.149442  3d_Printer
# 117  20.174241  3d_Printer
# ['3d_Printer' '3d_Printer' 'Arduino' '3d_Printer' '3d_Printer']
# 3d_Printer Arduino
#           dist    label
# 592  26.589472  Arduino
# 568  29.546573  Arduino
# 557  30.315013  Arduino
# 578  31.080541  Arduino
# 575  31.320920  Arduino
# ['Arduino' 'Arduino' 'Arduino' 'Arduino' 'Arduino']
# Arduino Arduino
# Arduino Arduino 47 56
#           dist    label
# 437  13.379088  Arduino
# 557  13.674794  Arduino
# 435  13.928388  Arduino
# 455  13.928388  Arduino
# 415  13.964240  Arduino
# ['Arduino' 'Arduino' 'Arduino' 'Arduino' 'Arduino']
# Arduino Arduino
# Arduino Arduino 48 57
#           dist    label
# 591  89.972218  Arduino
# 592  90.138782  Arduino
# 568  96.171721  Arduino
# 553  97.989795  Arduino
# 557  98.412398  Arduino
# ['Arduino' 'Arduino' 'Arduino' 'Arduino' 'Arduino']
# Arduino Arduino
# Arduino Arduino 49 58
#           dist       label
# 355   9.848858       Anime
# 571   9.949874     Arduino
# 162  10.000000  3d_Printer
# 119  10.000000  3d_Printer
# 378  10.000000       Anime
# ['Anime' 'Arduino' '3d_Printer' '3d_Printer' 'Anime']
# Anime Arduino
#          dist    label
# 528  6.324555  Arduino
# 355  6.324555    Anime
# 415  6.324555  Arduino
# 571  6.324555  Arduino
# 412  6.480741  Arduino
# ['Arduino' 'Anime' 'Arduino' 'Arduino' 'Arduino']
# Arduino Arduino
# Arduino Arduino 50 60
# accuray 0.8333333333333334
# Time : 4.894683599472046
#      dist       label
# 355  61.0       Anime
# 23   62.0  3d_Printer
# 268  62.0       Anime
# 117  63.0  3d_Printer
# 5    63.0  3d_Printer
# ['Anime' '3d_Printer' 'Anime' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 1 1
#      dist       label
# 75   50.0  3d_Printer
# 355  52.0       Anime
# 4    52.0  3d_Printer
# 35   52.0  3d_Printer
# 27   53.0  3d_Printer
# ['3d_Printer' 'Anime' '3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 2 2
#      dist       label
# 355  72.0       Anime
# 27   73.0  3d_Printer
# 35   74.0  3d_Printer
# 7    74.0  3d_Printer
# 524  75.0     Arduino
# ['Anime' '3d_Printer' '3d_Printer' '3d_Printer' 'Arduino']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 3 3
#      dist       label
# 355  47.0       Anime
# 35   49.0  3d_Printer
# 119  50.0  3d_Printer
# 378  50.0       Anime
# 162  50.0  3d_Printer
# ['Anime' '3d_Printer' '3d_Printer' 'Anime' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 4 4
#      dist       label
# 355  28.0       Anime
# 571  30.0     Arduino
# 117  30.0  3d_Printer
# 162  31.0  3d_Printer
# 378  31.0       Anime
# ['Anime' 'Arduino' '3d_Printer' '3d_Printer' 'Anime']
# Anime 3d_Printer
#      dist       label
# 355  27.0       Anime
# 7    27.0  3d_Printer
# 35   27.0  3d_Printer
# 23   28.0  3d_Printer
# 119  28.0  3d_Printer
# ['Anime' '3d_Printer' '3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 5 6
#      dist       label
# 355  26.0       Anime
# 35   26.0  3d_Printer
# 162  27.0  3d_Printer
# 103  28.0  3d_Printer
# 378  29.0       Anime
# ['Anime' '3d_Printer' '3d_Printer' '3d_Printer' 'Anime']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 6 7
#      dist       label
# 355  10.0       Anime
# 117  12.0  3d_Printer
# 162  13.0  3d_Printer
# 378  13.0       Anime
# 119  13.0  3d_Printer
# ['Anime' '3d_Printer' '3d_Printer' 'Anime' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 7 8
#      dist       label
# 117  90.0  3d_Printer
# 355  90.0       Anime
# 545  91.0     Arduino
# 378  91.0       Anime
# 129  92.0  3d_Printer
# ['3d_Printer' 'Anime' 'Arduino' 'Anime' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 8 9
#      dist       label
# 355  31.0       Anime
# 35   31.0  3d_Printer
# 162  32.0  3d_Printer
# 119  32.0  3d_Printer
# 23   34.0  3d_Printer
# ['Anime' '3d_Printer' '3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 9 10
#      dist       label
# 7    23.0  3d_Printer
# 101  24.0  3d_Printer
# 161  24.0  3d_Printer
# 6    24.0  3d_Printer
# 355  25.0       Anime
# ['3d_Printer' '3d_Printer' '3d_Printer' '3d_Printer' 'Anime']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 10 11
#      dist       label
# 355  55.0       Anime
# 162  56.0  3d_Printer
# 119  56.0  3d_Printer
# 571  57.0     Arduino
# 5    57.0  3d_Printer
# ['Anime' '3d_Printer' '3d_Printer' 'Arduino' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 11 12
#      dist       label
# 6    92.0  3d_Printer
# 35   93.0  3d_Printer
# 7    93.0  3d_Printer
# 355  93.0       Anime
# 119  94.0  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer' 'Anime' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 12 13
#      dist       label
# 7    84.0  3d_Printer
# 27   85.0  3d_Printer
# 355  86.0       Anime
# 119  87.0  3d_Printer
# 412  87.0     Arduino
# ['3d_Printer' '3d_Printer' 'Anime' '3d_Printer' 'Arduino']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 13 14
#      dist       label
# 189  85.0  3d_Printer
# 4    86.0  3d_Printer
# 355  86.0       Anime
# 75   86.0  3d_Printer
# 119  87.0  3d_Printer
# ['3d_Printer' '3d_Printer' 'Anime' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 14 15
#      dist       label
# 355  53.0       Anime
# 27   54.0  3d_Printer
# 7    55.0  3d_Printer
# 111  55.0  3d_Printer
# 35   55.0  3d_Printer
# ['Anime' '3d_Printer' '3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 15 16
#      dist       label
# 7    43.0  3d_Printer
# 355  43.0       Anime
# 162  44.0  3d_Printer
# 528  45.0     Arduino
# 4    45.0  3d_Printer
# ['3d_Printer' 'Anime' '3d_Printer' 'Arduino' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 16 17
#      dist       label
# 355  64.0       Anime
# 35   66.0  3d_Printer
# 75   66.0  3d_Printer
# 545  67.0     Arduino
# 378  67.0       Anime
# ['Anime' '3d_Printer' '3d_Printer' 'Arduino' 'Anime']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 17 18
#       dist       label
# 191  101.0  3d_Printer
# 111  102.0  3d_Printer
# 35   102.0  3d_Printer
# 355  102.0       Anime
# 161  103.0  3d_Printer
# ['3d_Printer' '3d_Printer' '3d_Printer' 'Anime' '3d_Printer']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer 18 19
#      dist       label
# 355  27.0       Anime
# 119  28.0  3d_Printer
# 162  30.0  3d_Printer
# 161  30.0  3d_Printer
# 378  30.0       Anime
# ['Anime' '3d_Printer' '3d_Printer' '3d_Printer' 'Anime']
# 3d_Printer 3d_Printer
# 3d_Printer 3d_Printer
# ['Anime' '3d_Printer' '3d_Printer' 'Anime' '3d_Printer']
# 3d_Printer Anime
#      dist       label
# 355  24.0       Anime
# 306  26.0       Anime
# 4    26.0  3d_Printer
# 528  26.0     Arduino
# 7    26.0  3d_Printer
# ['Anime' 'Anime' '3d_Printer' 'Arduino' '3d_Printer']
# Anime Anime
# Anime Anime 28 35
#      dist    label
# 355  28.0    Anime
# 268  29.0    Anime
# 271  29.0    Anime
# 365  29.0    Anime
# 524  31.0  Arduino
# ['Anime' 'Anime' 'Anime' 'Anime' 'Arduino']
# Anime Anime
# Anime Anime 29 36
#      dist       label
# 355  26.0       Anime
# 306  28.0       Anime
# 162  29.0  3d_Printer
# 119  29.0  3d_Printer
# 378  29.0       Anime
# ['Anime' 'Anime' '3d_Printer' '3d_Printer' 'Anime']
# Anime Anime
# Anime Anime 30 37
#      dist       label
# 355  27.0       Anime
# 378  28.0       Anime
# 365  28.0       Anime
# 117  29.0  3d_Printer
# 162  30.0  3d_Printer
# ['Anime' 'Anime' 'Anime' '3d_Printer' '3d_Printer']
# Anime Anime
# Anime Anime 31 38
#       dist       label
# 306  109.0       Anime
# 117  111.0  3d_Printer
# 355  111.0       Anime
# 378  112.0       Anime
# 268  112.0       Anime
# ['Anime' '3d_Printer' 'Anime' 'Anime' 'Anime']
# Anime Anime
# Anime Anime 32 39
#      dist       label
# 355  19.0       Anime
# 545  22.0     Arduino
# 365  22.0       Anime
# 162  22.0  3d_Printer
# 268  22.0       Anime
# ['Anime' 'Arduino' 'Anime' '3d_Printer' 'Anime']
# Anime Anime
# Anime Anime 33 40
#      dist       label
# 355  13.0       Anime
# 35   15.0  3d_Printer
# 378  16.0       Anime
# 539  16.0     Arduino
# 162  16.0  3d_Printer
# ['Anime' '3d_Printer' 'Anime' 'Arduino' '3d_Printer']
# Anime Arduino
#      dist       label
# 415  33.0     Arduino
# 355  34.0       Anime
# 545  35.0     Arduino
# 528  36.0     Arduino
# 4    36.0  3d_Printer
# ['Arduino' 'Anime' 'Arduino' 'Arduino' '3d_Printer']
# Arduino Arduino
# Arduino Arduino 34 42
#      dist    label
# 539  75.0  Arduino
# 355  78.0    Anime
# 538  78.0  Arduino
# 524  79.0  Arduino
# 528  80.0  Arduino
# ['Arduino' 'Anime' 'Arduino' 'Arduino' 'Arduino']
# Arduino Arduino
# Arduino Arduino 35 43
#      dist       label
# 355  14.0       Anime
# 119  17.0  3d_Printer
# 162  17.0  3d_Printer
# 378  17.0       Anime
# 528  18.0     Arduino
# ['Anime' '3d_Printer' '3d_Printer' 'Anime' 'Arduino']
# 3d_Printer Arduino
#       dist       label
# 571  113.0     Arduino
# 581  116.0     Arduino
# 355  117.0       Anime
# 528  117.0     Arduino
# 119  118.0  3d_Printer
# ['Arduino' 'Arduino' 'Anime' 'Arduino' '3d_Printer']
# Arduino Arduino
# Arduino Arduino 36 45
#      dist       label
# 355  43.0       Anime
# 35   43.0  3d_Printer
# 415  44.0     Arduino
# 581  44.0     Arduino
# 528  45.0     Arduino
# ['Anime' '3d_Printer' 'Arduino' 'Arduino' 'Arduino']
# Arduino Arduino
# Arduino Arduino 37 46
#      dist       label
# 355  14.0       Anime
# 412  15.0     Arduino
# 35   16.0  3d_Printer
# 119  17.0  3d_Printer
# 27   17.0  3d_Printer
# ['Anime' 'Arduino' '3d_Printer' '3d_Printer' '3d_Printer']
# 3d_Printer Arduino
#      dist    label
# 415  67.0  Arduino
# 528  68.0  Arduino
# 355  68.0    Anime
# 545  69.0  Arduino
# 571  70.0  Arduino
# ['Arduino' 'Arduino' 'Anime' 'Arduino' 'Arduino']
# Arduino Arduino
# Arduino Arduino 38 48
#      dist       label
# 355  29.0       Anime
# 528  31.0     Arduino
# 7    31.0  3d_Printer
# 162  32.0  3d_Printer
# 545  32.0     Arduino
# ['Anime' 'Arduino' '3d_Printer' '3d_Printer' 'Arduino']
# Anime Arduino
#      dist    label
# 355  35.0    Anime
# 528  35.0  Arduino
# 539  36.0  Arduino
# 415  36.0  Arduino
# 571  37.0  Arduino
# ['Anime' 'Arduino' 'Arduino' 'Arduino' 'Arduino']
# Arduino Arduino
# Arduino Arduino 39 50
#      dist       label
# 533  38.0     Arduino
# 355  39.0       Anime
# 539  40.0     Arduino
# 412  40.0     Arduino
# 35   41.0  3d_Printer
# ['Arduino' 'Anime' 'Arduino' 'Arduino' '3d_Printer']
# Arduino Arduino
# Arduino Arduino 40 51
#      dist    label
# 355  60.0    Anime
# 545  61.0  Arduino
# 539  61.0  Arduino
# 524  61.0  Arduino
# 528  62.0  Arduino
# ['Anime' 'Arduino' 'Arduino' 'Arduino' 'Arduino']
# Arduino Arduino
# Arduino Arduino 41 52
#      dist    label
# 355  67.0    Anime
# 533  68.0  Arduino
# 586  68.0  Arduino
# 412  68.0  Arduino
# 571  69.0  Arduino
# ['Anime' 'Arduino' 'Arduino' 'Arduino' 'Arduino']
# Arduino Arduino
# Arduino Arduino 42 53
#      dist       label
# 355  25.0       Anime
# 528  25.0     Arduino
# 415  26.0     Arduino
# 571  27.0     Arduino
# 117  27.0  3d_Printer
# ['Anime' 'Arduino' 'Arduino' 'Arduino' '3d_Printer']
# Arduino Arduino
# Arduino Arduino 43 54
#      dist       label
# 355  97.0       Anime
# 268  98.0       Anime
# 528  99.0     Arduino
# 538  99.0     Arduino
# 117  99.0  3d_Printer
# ['Anime' 'Anime' 'Arduino' 'Arduino' '3d_Printer']
# Anime Arduino
#      dist    label
# 578  85.0  Arduino
# 533  86.0  Arduino
# 355  87.0    Anime
# 528  87.0  Arduino
# 580  87.0  Arduino
# ['Arduino' 'Arduino' 'Anime' 'Arduino' 'Arduino']
# Arduino Arduino
# Arduino Arduino 44 56
#      dist    label
# 355  43.0    Anime
# 539  44.0  Arduino
# 306  45.0    Anime
# 528  45.0  Arduino
# 538  45.0  Arduino
# ['Anime' 'Arduino' 'Anime' 'Arduino' 'Arduino']
# Arduino Arduino
# Arduino Arduino 45 57
#       dist    label
# 539  132.0  Arduino
# 568  133.0  Arduino
# 538  133.0  Arduino
# 355  133.0    Anime
# 571  133.0  Arduino
# ['Arduino' 'Arduino' 'Arduino' 'Anime' 'Arduino']
# Arduino Arduino
# Arduino Arduino 46 58
#      dist       label
# 355  48.0       Anime
# 571  50.0     Arduino
# 545  51.0     Arduino
# 162  51.0  3d_Printer
# 119  51.0  3d_Printer
# ['Anime' 'Arduino' 'Arduino' '3d_Printer' '3d_Printer']
# Arduino Arduino
# Arduino Arduino 47 59
#      dist       label
# 355  28.0       Anime
# 571  30.0     Arduino
# 35   30.0  3d_Printer
# 528  30.0     Arduino
# 27   31.0  3d_Printer
# ['Anime' 'Arduino' '3d_Printer' 'Arduino' '3d_Printer']
# Anime Arduino
# accuray 0.7833333333333333
# Time : 5.943868398666382

# %%
print(acc_log)
# Out:
# ********************************************************************************************
# '3d_Printer','Anime','Arduino'
# stem:none,re:findall,minor_remove:3
# 'no_topic','traindocpertopic','train_doc','testdocpertopic','test_doc','wordmap'
# 3,200,600,20,60,'7387'
# ********************************************************************************************
# 'k','method','accuracy','time'
# 1,'cos',0.9333333333333333,19.126810312271118
# 1,'euc',0.75,4.6693198680877686
# 1,'hum',0.5833333333333334,5.831116199493408
# 3,'cos',0.9666666666666667,18.94967555999756
# 3,'euc',0.8333333333333334,4.775836706161499
# 3,'hum',0.7666666666666667,5.964364767074585
# 5,'cos',0.9666666666666667,18.952943563461304
# 5,'euc',0.8333333333333334,4.894683599472046
# 5,'hum',0.7833333333333333,5.943868398666382

# %%
print(len(vectors))
print(len(vct_labels))
vects=np.array(vectors>0,dtype=np.uint8)
print(len(vects))
print(n)
# Out:
# 600
# 600
# 600
# 60

# %%
from matplotlib import pyplot as plt
vct=[vectors[12][:500]]
test=vectors[15][:498]
dis=eucl_dis(test,vct)
print(vct)
print(test)
print(dis[0][0])
x=range(0,500)
xt=range(0,498)
plt.plot(x,vct[0],xt,test)
plt.show
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-63234f6ac4ef> in <module>
#       2 vct=[vectors[12][:500]]
#       3 test=vectors[15][:498]
# ----> 4 dis=eucl_dis(test,vct)
#       5 print(vct)
#       6 print(test)
#
# TypeError: eucl_dis() missing 1 required positional argument: 'vct_labels'

# %%
from matplotlib import pyplot as plt
max_docs_test=20
test_vector,true_lbs=vectorize_seq(topics,max_docs_test,wordmap,root_test)
#_test_vector=test_vector[0]
#_vectors=vectors[0]
#test_vect=np.array(_test_vector>0,dtype=np.int8)
#vects=np.array(_vectors>0,dtype=np.int8)
#x=range(len(vects))
#dist=np.abs(test_vect-vects)
#sum_=np.sum(dist)
#print(sum_,dist[:10])

#plt.plot(x,vects)
#plt.show()
#plt.plot(x,test_vect)
#plt.show()
#plt.plot(x,dist)
#plt.show()
h_dists=humm_dis(test_vector[45],vectors,vct_labels)
h_df=pd.DataFrame(h_dists,columns=['dist','label'])
h_df=h_df.sort_values('dist',ascending=True)
print(h_df)

# %%
def eucl_dis(test_vector,vectors):
    h_dists=[]
    for vector in vectors:
        vect=np.array(vector[:-2])
        vect[vect>1]=1
        label=vector[-1]
        test_vect=np.array(test_vector)
        dist=np.abs(vect-test_vect)
        #dist=np.sum(dist)
        h_dists.append([dist,label])
    return h_dists
test_vector=vectors[0][:-2]
vecto=[vectors[0],vectors[1]]
h_dists=cos_dis(test_vector,vecto)
#h_df=pd.DataFrame(h_dists)
#h_df=h_df.sort_values(0)
print(h_dists)
#print((vectors[15]))

# %%
for i in range(len(vectors)):
    vct=vectors[i][:-2]
    if np.sum(vct)==0:
        break
print(i,word_list[185])

# %%
raw='I am hasib\n,i "am" a student() so? @i do& my-duties! porp. and' 
#text=re.sub('\n',' ',raw)
text=raw.lower()
text=re.sub('[^a-z0-9]',' ',text)
#text=re.sub('-',' ',text)
#text=re.sub('[\'"]','',text)
#text=re.sub('[()?.@*#&!,$+]','',text)
#print(text.split(' '))

# %%
dt=np.ones((2,3))
print(dt)
dts=np.sum(dt,axis=1)
print(dts)
# Out:
# [[1. 1. 1.]
#  [1. 1. 1.]]
# [3. 3.]
